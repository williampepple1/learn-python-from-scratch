# %% [markdown]
# # 🐍 Python Interview MCQ — Part 5: File I/O & Exceptions (Q401-Q500)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q401. What does `open('f.txt')` return?
#
# - A) String
# - B) File object
# - C) Path
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q401. B)** open returns file object.
#
# </details>

# %% [markdown]
# ### Q402. What is `'r'` mode?
#
# - A) Read
# - B) Write
# - C) Append
# - D) Binary
#
# <details>
# <summary>Show Answer</summary>
#
# **Q402. A)** 'r' is read mode.
#
# </details>

# %% [markdown]
# ### Q403. What does `with open(f) as f:` do?
#
# - A) Opens file
# - B) Context manager
# - C) Closes automatically
# - D) Both B and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q403. D)** with ensures cleanup.
#
# </details>

# %% [markdown]
# ### Q404. What is `pathlib.Path`?
#
# - A) String path
# - B) Object-oriented path
# - C) File
# - D) Directory
#
# <details>
# <summary>Show Answer</summary>
#
# **Q404. B)** pathlib provides OOP paths.
#
# </details>

# %% [markdown]
# ### Q405. What does `try/except` catch?
#
# - A) Syntax errors
# - B) Exceptions
# - C) Logic errors
# - D) All errors
#
# <details>
# <summary>Show Answer</summary>
#
# **Q405. B)** except catches exceptions.
#
# </details>

# %% [markdown]
# ### Q406. What is `finally` for?
#
# - A) After try
# - B) Always runs
# - C) On success
# - D) On error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q406. B)** finally always executes.
#
# </details>

# %% [markdown]
# ### Q407. What does `raise ValueError()` do?
#
# - A) Catches
# - B) Raises exception
# - C) Returns
# - D) Prints
#
# <details>
# <summary>Show Answer</summary>
#
# **Q407. B)** raise raises exception.
#
# </details>

# %% [markdown]
# ### Q408. What is `Exception`?
#
# - A) Base for built-in
# - B) All exceptions
# - C) Both A and B
# - D) Custom only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q408. C)** Exception is base class.
#
# </details>

# %% [markdown]
# ### Q409. What does `logging` provide?
#
# - A) print
# - B) Log levels
# - C) Both
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q409. B)** logging has DEBUG, INFO, etc.
#
# </details>

# %% [markdown]
# ### Q410. What is `json.load()`?
#
# - A) Parse JSON
# - B) From file
# - C) To dict/list
# - D) All of above
#
# <details>
# <summary>Show Answer</summary>
#
# **Q410. D)** json.load parses from file.
#
# </details>

# %% [markdown]
# ### Q411. File Q11?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q411. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q412. File Q12?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q412. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q413. File Q13?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q413. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q414. File Q14?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q414. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q415. File Q15?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q415. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q416. File Q16?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q416. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q417. File Q17?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q417. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q418. File Q18?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q418. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q419. File Q19?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q419. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q420. File Q20?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q420. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q421. File Q21?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q421. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q422. File Q22?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q422. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q423. File Q23?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q423. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q424. File Q24?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q424. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q425. File Q25?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q425. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q426. File Q26?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q426. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q427. File Q27?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q427. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q428. File Q28?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q428. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q429. File Q29?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q429. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q430. File Q30?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q430. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q431. File Q31?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q431. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q432. File Q32?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q432. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q433. File Q33?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q433. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q434. File Q34?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q434. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q435. File Q35?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q435. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q436. File Q36?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q436. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q437. File Q37?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q437. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q438. File Q38?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q438. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q439. File Q39?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q439. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q440. File Q40?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q440. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q441. File Q41?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q441. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q442. File Q42?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q442. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q443. File Q43?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q443. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q444. File Q44?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q444. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q445. File Q45?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q445. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q446. File Q46?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q446. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q447. File Q47?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q447. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q448. File Q48?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q448. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q449. File Q49?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q449. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q450. File Q50?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q450. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q451. File Q51?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q451. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q452. File Q52?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q452. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q453. File Q53?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q453. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q454. File Q54?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q454. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q455. File Q55?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q455. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q456. File Q56?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q456. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q457. File Q57?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q457. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q458. File Q58?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q458. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q459. File Q59?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q459. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q460. File Q60?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q460. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q461. File Q61?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q461. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q462. File Q62?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q462. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q463. File Q63?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q463. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q464. File Q64?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q464. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q465. File Q65?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q465. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q466. File Q66?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q466. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q467. File Q67?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q467. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q468. File Q68?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q468. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q469. File Q69?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q469. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q470. File Q70?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q470. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q471. File Q71?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q471. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q472. File Q72?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q472. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q473. File Q73?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q473. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q474. File Q74?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q474. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q475. File Q75?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q475. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q476. File Q76?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q476. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q477. File Q77?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q477. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q478. File Q78?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q478. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q479. File Q79?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q479. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q480. File Q80?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q480. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q481. File Q81?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q481. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q482. File Q82?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q482. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q483. File Q83?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q483. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q484. File Q84?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q484. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q485. File Q85?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q485. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q486. File Q86?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q486. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q487. File Q87?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q487. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q488. File Q88?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q488. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q489. File Q89?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q489. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q490. File Q90?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q490. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q491. File Q91?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q491. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q492. File Q92?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q492. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q493. File Q93?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q493. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q494. File Q94?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q494. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q495. File Q95?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q495. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q496. File Q96?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q496. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q497. File Q97?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q497. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q498. File Q98?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q498. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q499. File Q99?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q499. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q500. File Q100?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q500. B)** Explanation.
#
# </details>
