# %% [markdown]
# # 🐍 Python Interview MCQ — Part 9: Data Science & NumPy/Pandas (Q801–Q900)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q801. What does `np.array([1,2,3])` create?
#
# - A) NumPy array
# - B) List
# - C) Tuple
# - D) Series
#
# <details>
# <summary>Show Answer</summary>
#
# **Q801. A)** array() creates ndarray.
#
# </details>

# %% [markdown]
# ### Q802. What is `arr.dtype`?
#
# - A) Element type
# - B) Shape
# - C) Size
# - D) Length
#
# <details>
# <summary>Show Answer</summary>
#
# **Q802. A)** dtype is the data type of elements.
#
# </details>

# %% [markdown]
# ### Q803. What is NumPy broadcasting?
#
# - A) Shape expansion for ops
# - B) Copy only
# - C) Resize
# - D) Iteration
#
# <details>
# <summary>Show Answer</summary>
#
# **Q803. A)** Broadcasting expands dimensions for operations.
#
# </details>

# %% [markdown]
# ### Q804. What does `arr[1:3]` on 1D array return?
#
# - A) Slice of array
# - B) Single element
# - C) Copy
# - D) View typically
#
# <details>
# <summary>Show Answer</summary>
#
# **Q804. D)** Slicing returns view (no copy).
#
# </details>

# %% [markdown]
# ### Q805. What are vectorized operations?
#
# - A) Element-wise without Python loop
# - B) Loop-based
# - C) Single element
# - D) String ops
#
# <details>
# <summary>Show Answer</summary>
#
# **Q805. A)** Vectorized uses C-level loops.
#
# </details>

# %% [markdown]
# ### Q806. What does `np.dot(a, b)` do?
#
# - A) Matrix multiplication
# - B) Element-wise multiply
# - C) Dot product
# - D) A and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q806. D)** dot does dot product / matrix multiply.
#
# </details>

# %% [markdown]
# ### Q807. What is `pd.Series`?
#
# - A) 1D labeled array
# - B) 2D only
# - C) List wrapper
# - D) Dict
#
# <details>
# <summary>Show Answer</summary>
#
# **Q807. A)** Series is 1D with index.
#
# </details>

# %% [markdown]
# ### Q808. What is `pd.DataFrame`?
#
# - A) 2D labeled structure
# - B) Matrix
# - C) Table
# - D) All
#
# <details>
# <summary>Show Answer</summary>
#
# **Q808. A)** DataFrame has rows and columns with labels.
#
# </details>

# %% [markdown]
# ### Q809. What does `df.groupby('col')` return?
#
# - A) GroupBy object
# - B) Grouped DataFrame
# - C) List of groups
# - D) Aggregated result
#
# <details>
# <summary>Show Answer</summary>
#
# **Q809. A)** groupby returns GroupBy object.
#
# </details>

# %% [markdown]
# ### Q810. What does `pd.merge(left, right)` do?
#
# - A) Join DataFrames
# - B) Concatenate
# - C) Append
# - D) Replace
#
# <details>
# <summary>Show Answer</summary>
#
# **Q810. A)** merge does SQL-like join.
#
# </details>

# %% [markdown]
# ### Q811. What does `df.pivot_table` do?
#
# - A) Reshape with aggregation
# - B) Transpose only
# - C) Sort
# - D) Filter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q811. A)** pivot_table reshapes with aggregation.
#
# </details>

# %% [markdown]
# ### Q812. What does `pd.to_datetime` do?
#
# - A) Parse to datetime
# - B) Format only
# - C) Current time
# - D) Timestamp
#
# <details>
# <summary>Show Answer</summary>
#
# **Q812. A)** Converts to datetime64.
#
# </details>

# %% [markdown]
# ### Q813. What does `plt.plot(x, y)` do?
#
# - A) Line plot
# - B) Scatter
# - C) Bar
# - D) Histogram
#
# <details>
# <summary>Show Answer</summary>
#
# **Q813. A)** plot creates line plot.
#
# </details>

# %% [markdown]
# ### Q814. What is data cleaning?
#
# - A) Fix missing, invalid data
# - B) Delete all
# - C) Format only
# - D) Visualize
#
# <details>
# <summary>Show Answer</summary>
#
# **Q814. A)** Cleaning handles missing, outliers, types.
#
# </details>

# %% [markdown]
# ### Q815. What does `df.isna()` return?
#
# - A) Bool mask of NaN
# - B) Count of NaN
# - C) Dropped rows
# - D) Filled values
#
# <details>
# <summary>Show Answer</summary>
#
# **Q815. A)** isna() returns boolean DataFrame.
#
# </details>

# %% [markdown]
# ### Q816. What does `pd.read_csv` return?
#
# - A) DataFrame
# - B) String
# - C) List
# - D) File
#
# <details>
# <summary>Show Answer</summary>
#
# **Q816. A)** read_csv parses CSV to DataFrame.
#
# </details>

# %% [markdown]
# ### Q817. What does `pd.read_json` do?
#
# - A) Parse JSON to DataFrame
# - B) Write JSON
# - C) Validate JSON
# - D) Load string
#
# <details>
# <summary>Show Answer</summary>
#
# **Q817. A)** read_json parses JSON to DataFrame.
#
# </details>

# %% [markdown]
# ### Q818. What is scikit-learn?
#
# - A) ML library
# - B) Data only
# - C) Visualization
# - D) Database
#
# <details>
# <summary>Show Answer</summary>
#
# **Q818. A)** sklearn provides ML algorithms.
#
# </details>

# %% [markdown]
# ### Q819. What does `arr.shape` return?
#
# - A) Tuple of dimensions
# - B) Int
# - C) List
# - D) Array
#
# <details>
# <summary>Show Answer</summary>
#
# **Q819. A)** shape is (n_rows, n_cols) for 2D.
#
# </details>

# %% [markdown]
# ### Q820. What does `df.fillna(0)` do?
#
# - A) Replace NaN with 0
# - B) Drop NaN
# - C) Count NaN
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q820. A)** fillna fills missing values.
#
# </details>

# %% [markdown]
# ### Q821. What does `np.zeros((2,3))` create?
#
# - A) 2x3 array of zeros
# - B) 2 or 3 zeros
# - C) List
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q821. A)** zeros(shape) creates array of zeros.
#
# </details>

# %% [markdown]
# ### Q822. What is `arr.T`?
#
# - A) Transpose
# - B) Type
# - C) Total
# - D) Transform
#
# <details>
# <summary>Show Answer</summary>
#
# **Q822. A)** T is transpose attribute.
#
# </details>

# %% [markdown]
# ### Q823. What does `df.dropna()` do?
#
# - A) Drop rows/cols with NaN
# - B) Fill NaN
# - C) Count NaN
# - D) Replace NaN
#
# <details>
# <summary>Show Answer</summary>
#
# **Q823. A)** dropna removes missing values.
#
# </details>

# %% [markdown]
# ### Q824. What does `np.arange(0, 10, 2)` produce?
#
# - A) [0,2,4,6,8]
# - B) [0,2,4,6,8,10]
# - C) range object
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q824. A)** arange with step 2.
#
# </details>

# %% [markdown]
# ### Q825. What is `df.loc`?
#
# - A) Label-based indexing
# - B) Position-based
# - C) Boolean
# - D) Slice
#
# <details>
# <summary>Show Answer</summary>
#
# **Q825. A)** loc uses labels.
#
# </details>

# %% [markdown]
# ### Q826. What does `np.linspace(0, 1, 5)` produce?
#
# - A) 5 evenly spaced values
# - B) 5 random
# - C) [0,1]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q826. A)** linspace(0,1,5) = [0, 0.25, 0.5, 0.75, 1].
#
# </details>

# %% [markdown]
# ### Q827. What does `df.iloc` use?
#
# - A) Integer position
# - B) Labels
# - C) Boolean
# - D) Names
#
# <details>
# <summary>Show Answer</summary>
#
# **Q827. A)** iloc uses integer indices.
#
# </details>

# %% [markdown]
# ### Q828. What does `arr.reshape(2, -1)` mean?
#
# - A) 2 rows, infer cols
# - B) 2 cols
# - C) Error
# - D) Flatten
#
# <details>
# <summary>Show Answer</summary>
#
# **Q828. A)** -1 infers from size.
#
# </details>

# %% [markdown]
# ### Q829. What does `df.agg(['mean','sum'])` do?
#
# - A) Multiple aggregations
# - B) Single agg
# - C) Filter
# - D) Transform
#
# <details>
# <summary>Show Answer</summary>
#
# **Q829. A)** agg applies multiple functions.
#
# </details>

# %% [markdown]
# ### Q830. What does `np.concatenate([a,b])` do?
#
# - A) Join arrays
# - B) Merge
# - C) Append
# - D) Stack
#
# <details>
# <summary>Show Answer</summary>
#
# **Q830. A)** Concatenate along axis (default 0).
#
# </details>

# %% [markdown]
# ### Q831. What is `df.duplicated()`?
#
# - A) Bool mask of duplicates
# - B) Drop duplicates
# - C) Count duplicates
# - D) Unique values
#
# <details>
# <summary>Show Answer</summary>
#
# **Q831. A)** Returns boolean Series.
#
# </details>

# %% [markdown]
# ### Q832. What does `arr.astype(float)` do?
#
# - A) Convert dtype
# - B) Round
# - C) Cast only
# - D) Copy
#
# <details>
# <summary>Show Answer</summary>
#
# **Q832. A)** Converts to float dtype.
#
# </details>

# %% [markdown]
# ### Q833. What does `df.value_counts()` return?
#
# - A) Count per unique value
# - B) Total count
# - C) Unique values
# - D) Frequency
#
# <details>
# <summary>Show Answer</summary>
#
# **Q833. A)** Series of counts per value.
#
# </details>

# %% [markdown]
# ### Q834. What does `np.where(cond, x, y)` do?
#
# - A) Choose x or y by cond
# - B) Filter
# - C) Find indices
# - D) Replace
#
# <details>
# <summary>Show Answer</summary>
#
# **Q834. A)** Where cond True: x, else y.
#
# </details>

# %% [markdown]
# ### Q835. What is `df.describe()`?
#
# - A) Summary statistics
# - B) First rows
# - C) Info
# - D) Shape
#
# <details>
# <summary>Show Answer</summary>
#
# **Q835. A)** count, mean, std, min, max, etc.
#
# </details>

# %% [markdown]
# ### Q836. What does `arr.flatten()` return?
#
# - A) 1D copy
# - B) View
# - C) Same shape
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q836. A)** flatten returns 1D copy.
#
# </details>

# %% [markdown]
# ### Q837. What does `df.sort_values('col')` do?
#
# - A) Sort by column
# - B) Sort index
# - C) Reorder
# - D) Rank
#
# <details>
# <summary>Show Answer</summary>
#
# **Q837. A)** Sorts rows by column values.
#
# </details>

# %% [markdown]
# ### Q838. What does `np.unique(arr)` return?
#
# - A) Sorted unique values
# - B) Counts
# - C) Indices
# - D) First occurrence
#
# <details>
# <summary>Show Answer</summary>
#
# **Q838. A)** unique returns sorted unique elements.
#
# </details>

# %% [markdown]
# ### Q839. What is `df.columns`?
#
# - A) Column index
# - B) Column names
# - C) Both
# - D) Row names
#
# <details>
# <summary>Show Answer</summary>
#
# **Q839. C)** Index of column labels.
#
# </details>

# %% [markdown]
# ### Q840. What does `arr.sum(axis=1)` do?
#
# - A) Sum across columns
# - B) Sum across rows
# - C) Total sum
# - D) Sum axis
#
# <details>
# <summary>Show Answer</summary>
#
# **Q840. A)** axis=1: sum each row.
#
# </details>

# %% [markdown]
# ### Q841. What does `df.rename(columns={})` do?
#
# - A) Rename columns
# - B) Rename index
# - C) Replace values
# - D) Sort
#
# <details>
# <summary>Show Answer</summary>
#
# **Q841. A)** Maps old names to new.
#
# </details>

# %% [markdown]
# ### Q842. What does `np.random.rand(2,3)` produce?
#
# - A) 2x3 random [0,1)
# - B) 2 or 3 random
# - C) Integers
# - D) Normal dist
#
# <details>
# <summary>Show Answer</summary>
#
# **Q842. A)** rand(d0,d1,...) uniform [0,1).
#
# </details>

# %% [markdown]
# ### Q843. What is `df.index`?
#
# - A) Row labels
# - B) Column labels
# - C) Position
# - D) Names
#
# <details>
# <summary>Show Answer</summary>
#
# **Q843. A)** Index of row labels.
#
# </details>

# %% [markdown]
# ### Q844. What does `arr.max()` return?
#
# - A) Max value
# - B) Index of max
# - C) Row max
# - D) Column max
#
# <details>
# <summary>Show Answer</summary>
#
# **Q844. A)** max() returns maximum element.
#
# </details>

# %% [markdown]
# ### Q845. What does `df.apply(func)` do?
#
# - A) Apply func to each col/row
# - B) Apply to whole
# - C) Map
# - D) Transform
#
# <details>
# <summary>Show Answer</summary>
#
# **Q845. A)** apply runs function on axis.
#
# </details>

# %% [markdown]
# ### Q846. What does `np.eye(3)` create?
#
# - A) 3x3 identity
# - B) 3 elements
# - C) Eye shape
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q846. A)** Identity matrix.
#
# </details>

# %% [markdown]
# ### Q847. What does `df.query('col > 0')` do?
#
# - A) Filter rows
# - B) Select col
# - C) Query DB
# - D) Sort
#
# <details>
# <summary>Show Answer</summary>
#
# **Q847. A)** Filter using expression string.
#
# </details>

# %% [markdown]
# ### Q848. What does `arr.mean()` return?
#
# - A) Mean of elements
# - B) Median
# - C) Mode
# - D) Std
#
# <details>
# <summary>Show Answer</summary>
#
# **Q848. A)** Arithmetic mean.
#
# </details>

# %% [markdown]
# ### Q849. What is `df.pivot`?
#
# - A) Reshape without agg
# - B) With aggregation
# - C) Transpose
# - D) Melt
#
# <details>
# <summary>Show Answer</summary>
#
# **Q849. A)** pivot reshapes; pivot_table aggregates.
#
# </details>

# %% [markdown]
# ### Q850. What does `np.vstack([a,b])` do?
#
# - A) Stack vertically
# - B) Stack horizontally
# - C) Concatenate
# - D) Merge
#
# <details>
# <summary>Show Answer</summary>
#
# **Q850. A)** Vertical stack (rows).
#
# </details>

# %% [markdown]
# ### Q851. What does `df.melt` do?
#
# - A) Wide to long
# - B) Long to wide
# - C) Merge
# - D) Reshape
#
# <details>
# <summary>Show Answer</summary>
#
# **Q851. A)** Unpivots columns to rows.
#
# </details>

# %% [markdown]
# ### Q852. What does `arr.std()` return?
#
# - A) Standard deviation
# - B) Variance
# - C) Mean
# - D) Range
#
# <details>
# <summary>Show Answer</summary>
#
# **Q852. A)** Sample std by default.
#
# </details>

# %% [markdown]
# ### Q853. What does `df.join(other)` do?
#
# - A) Join on index
# - B) Merge on column
# - C) Concatenate
# - D) Append
#
# <details>
# <summary>Show Answer</summary>
#
# **Q853. A)** Join on index by default.
#
# </details>

# %% [markdown]
# ### Q854. What does `np.hstack([a,b])` do?
#
# - A) Stack horizontally
# - B) Stack vertically
# - C) Concatenate axis=0
# - D) Merge
#
# <details>
# <summary>Show Answer</summary>
#
# **Q854. A)** Horizontal stack (columns).
#
# </details>

# %% [markdown]
# ### Q855. What does `df.assign(new_col=...)` do?
#
# - A) Add column, return new df
# - B) Modify in place
# - C) Replace
# - D) Append
#
# <details>
# <summary>Show Answer</summary>
#
# **Q855. A)** Returns new DataFrame with column.
#
# </details>

# %% [markdown]
# ### Q856. What does `arr.argmax()` return?
#
# - A) Index of max
# - B) Max value
# - C) Indices
# - D) Position
#
# <details>
# <summary>Show Answer</summary>
#
# **Q856. A)** Flat index of maximum.
#
# </details>

# %% [markdown]
# ### Q857. What does `df.corr()` compute?
#
# - A) Correlation matrix
# - B) Covariance
# - C) Count
# - D) Sum
#
# <details>
# <summary>Show Answer</summary>
#
# **Q857. A)** Pearson correlation between columns.
#
# </details>

# %% [markdown]
# ### Q858. What does `np.clip(arr, 0, 1)` do?
#
# - A) Clip values to [0,1]
# - B) Remove outliers
# - C) Round
# - D) Replace
#
# <details>
# <summary>Show Answer</summary>
#
# **Q858. A)** Values outside range become bound.
#
# </details>

# %% [markdown]
# ### Q859. What does `df.head()` return?
#
# - A) First 5 rows
# - B) First row
# - C) Last 5
# - D) Random 5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q859. A)** Default 5 rows.
#
# </details>

# %% [markdown]
# ### Q860. What does `arr[::-1]` do on 1D?
#
# - A) Reverse
# - B) Copy
# - C) Sort
# - D) Flip
#
# <details>
# <summary>Show Answer</summary>
#
# **Q860. A)** Step -1 reverses.
#
# </details>

# %% [markdown]
# ### Q861. What does `df.tail(3)` return?
#
# - A) Last 3 rows
# - B) First 3
# - C) Random 3
# - D) 3 cols
#
# <details>
# <summary>Show Answer</summary>
#
# **Q861. A)** Last n rows.
#
# </details>

# %% [markdown]
# ### Q862. What does `np.percentile(arr, 50)` approximate?
#
# - A) Median
# - B) Mean
# - C) 50th value
# - D) Midpoint
#
# <details>
# <summary>Show Answer</summary>
#
# **Q862. A)** 50th percentile ≈ median.
#
# </details>

# %% [markdown]
# ### Q863. What does `df.reset_index()` do?
#
# - A) Index to column, new default index
# - B) Clear index
# - C) Sort index
# - D) Set index
#
# <details>
# <summary>Show Answer</summary>
#
# **Q863. A)** Moves index to column.
#
# </details>

# %% [markdown]
# ### Q864. What does `arr.ravel()` return?
#
# - A) 1D view if possible
# - B) Always copy
# - C) 2D
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q864. A)** Flattened view when possible.
#
# </details>

# %% [markdown]
# ### Q865. What does `df.set_index('col')` do?
#
# - A) Use col as index
# - B) Add index
# - C) Replace
# - D) Sort
#
# <details>
# <summary>Show Answer</summary>
#
# **Q865. A)** Sets column as index.
#
# </details>

# %% [markdown]
# ### Q866. What does `np.nan` represent?
#
# - A) Not a Number
# - B) None
# - C) Zero
# - D) Missing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q866. A)** IEEE 754 NaN.
#
# </details>

# %% [markdown]
# ### Q867. What does `df.dtypes` show?
#
# - A) Column dtypes
# - B) Shape
# - C) Memory
# - D) Index
#
# <details>
# <summary>Show Answer</summary>
#
# **Q867. A)** Data type per column.
#
# </details>

# %% [markdown]
# ### Q868. What does `arr.copy()` do?
#
# - A) Deep copy
# - B) View
# - C) Reference
# - D) Shallow
#
# <details>
# <summary>Show Answer</summary>
#
# **Q868. A)** Copy of array.
#
# </details>

# %% [markdown]
# ### Q869. What does `df.merge` default join?
#
# - A) Inner
# - B) Left
# - C) Outer
# - D) Right
#
# <details>
# <summary>Show Answer</summary>
#
# **Q869. A)** merge defaults to inner join.
#
# </details>

# %% [markdown]
# ### Q870. What does `np.all(arr)` return?
#
# - A) True if all truthy
# - B) First element
# - C) Count
# - D) Any
#
# <details>
# <summary>Show Answer</summary>
#
# **Q870. A)** Logical AND over elements.
#
# </details>

# %% [markdown]
# ### Q871. What does `df.replace(old, new)` do?
#
# - A) Replace values
# - B) Rename
# - C) Substitute
# - D) Update
#
# <details>
# <summary>Show Answer</summary>
#
# **Q871. A)** Replaces old with new.
#
# </details>

# %% [markdown]
# ### Q872. What does `arr.any()` return?
#
# - A) True if any truthy
# - B) First truthy
# - C) Count
# - D) All
#
# <details>
# <summary>Show Answer</summary>
#
# **Q872. A)** Logical OR over elements.
#
# </details>

# %% [markdown]
# ### Q873. What does `df.nunique()` return?
#
# - A) Count of unique per column
# - B) Unique values
# - C) Total unique
# - D) Distinct
#
# <details>
# <summary>Show Answer</summary>
#
# **Q873. A)** Number of unique per column.
#
# </details>

# %% [markdown]
# ### Q874. What does `np.expand_dims(arr, axis)` do?
#
# - A) Add dimension
# - B) Remove dimension
# - C) Resize
# - D) Broadcast
#
# <details>
# <summary>Show Answer</summary>
#
# **Q874. A)** Inserts new axis.
#
# </details>

# %% [markdown]
# ### Q875. What does `df.sample(n=5)` do?
#
# - A) Random 5 rows
# - B) First 5
# - C) Last 5
# - D) Every 5th
#
# <details>
# <summary>Show Answer</summary>
#
# **Q875. A)** Random sample of rows.
#
# </details>

# %% [markdown]
# ### Q876. What does `np.squeeze(arr)` do?
#
# - A) Remove length-1 dims
# - B) Add dims
# - C) Flatten
# - D) Reshape
#
# <details>
# <summary>Show Answer</summary>
#
# **Q876. A)** Removes singleton dimensions.
#
# </details>

# %% [markdown]
# ### Q877. What does `df.info()` show?
#
# - A) Dtypes, non-null counts
# - B) Summary stats
# - C) First rows
# - D) Shape only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q877. A)** Column dtypes, non-null, memory.
#
# </details>

# %% [markdown]
# ### Q878. What does `np.tile(arr, (2,3))` do?
#
# - A) Repeat arr 2x3
# - B) Resize
# - C) Stack
# - D) Copy
#
# <details>
# <summary>Show Answer</summary>
#
# **Q878. A)** Repeats array in block pattern.
#
# </details>

# %% [markdown]
# ### Q879. What does `df.drop(columns=['x'])` do?
#
# - A) Remove column
# - B) Drop rows
# - C) Delete
# - D) Filter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q879. A)** Drops specified columns.
#
# </details>

# %% [markdown]
# ### Q880. What does `np.logical_and(a, b)` return?
#
# - A) Element-wise AND
# - B) Single bool
# - C) Array or scalar
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q880. A)** Logical AND element-wise.
#
# </details>

# %% [markdown]
# ### Q881. What does `df.astype({'col': int})` do?
#
# - A) Convert column dtype
# - B) Convert all
# - C) Assert type
# - D) Validate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q881. A)** Converts specified columns.
#
# </details>

# %% [markdown]
# ### Q882. What does `np.broadcast_arrays(a, b)` return?
#
# - A) List of broadcasted arrays
# - B) Single array
# - C) Error if incompatible
# - D) Stacked
#
# <details>
# <summary>Show Answer</summary>
#
# **Q882. A)** Returns arrays broadcast to same shape.
#
# </details>

# %% [markdown]
# ### Q883. What does `df.explode('col')` do?
#
# - A) Expand list col to rows
# - B) Split
# - C) Flatten
# - D) Unnest
#
# <details>
# <summary>Show Answer</summary>
#
# **Q883. A)** Each list element becomes a row.
#
# </details>

# %% [markdown]
# ### Q884. What does `np.einsum` do?
#
# - A) Einstein summation
# - B) Element sum
# - C) Sum axis
# - D) Dot product
#
# <details>
# <summary>Show Answer</summary>
#
# **Q884. A)** Generalized tensor operations.
#
# </details>

# %% [markdown]
# ### Q885. What does `df.at[i, 'col']` do?
#
# - A) Fast scalar access
# - B) Slice
# - C) Boolean
# - D) Label
#
# <details>
# <summary>Show Answer</summary>
#
# **Q885. A)** Single value by label (fast).
#
# </details>

# %% [markdown]
# ### Q886. What does `np.cumsum(arr)` return?
#
# - A) Cumulative sum
# - B) Total sum
# - C) Running mean
# - D) Prefix sum
#
# <details>
# <summary>Show Answer</summary>
#
# **Q886. A)** Cumulative sum array.
#
# </details>

# %% [markdown]
# ### Q887. What does `df.memory_usage()` return?
#
# - A) Bytes per column
# - B) Total bytes
# - C) MB
# - D) Rows
#
# <details>
# <summary>Show Answer</summary>
#
# **Q887. A)** Memory per column.
#
# </details>

# %% [markdown]
# ### Q888. What is the difference between Pandas `apply()` and `map()`?
#
# - A) apply works on DataFrame/Series; map is for Series element-wise
# - B) They are identical
# - C) map is faster for DataFrames
# - D) apply is deprecated
#
# <details>
# <summary>Show Answer</summary>
#
# **Q888. A)** apply runs on axis; map is Series element-wise mapping.
#
# </details>

# %% [markdown]
# ### Q889. What does `np.where(condition, x, y)` return?
#
# - A) Indices where condition is True
# - B) Array with x where condition True, else y
# - C) Boolean mask only
# - D) Single value
#
# <details>
# <summary>Show Answer</summary>
#
# **Q889. B)** where returns element from x or y based on condition.
#
# </details>

# %% [markdown]
# ### Q890. What does Pandas `rolling(window=5)` do?
#
# - A) Reshape to 5 columns
# - B) Shift by 5 rows
# - C) Sliding window of size 5 for aggregation
# - D) Sample every 5th row
#
# <details>
# <summary>Show Answer</summary>
#
# **Q890. C)** rolling creates sliding windows for mean, sum, etc.
#
# </details>

# %% [markdown]
# ### Q891. What does `np.random.seed(42)` do?
#
# - A) Sets random state for reproducibility
# - B) Generates 42 random numbers
# - C) Seeds only for integers
# - D) Deprecated in NumPy
#
# <details>
# <summary>Show Answer</summary>
#
# **Q891. A)** seed makes random sequences reproducible (use Generator in modern NumPy).
#
# </details>

# %% [markdown]
# ### Q892. What is Pandas categorical dtype?
#
# - A) Memory-efficient storage for repeated categories
# - B) Continuous numeric type
# - C) Datetime type
# - D) String type
#
# <details>
# <summary>Show Answer</summary>
#
# **Q892. A)** Categorical stores categories as codes, saving memory.
#
# </details>

# %% [markdown]
# ### Q893. What do `np.save` and `np.load` do?
#
# - A) Save/load JSON
# - B) Save/load arrays in binary .npy format
# - C) Save to CSV
# - D) Compress only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q893. B)** save/load use NumPy binary format for arrays.
#
# </details>

# %% [markdown]
# ### Q894. How does Pandas handle time zones?
#
# - A) Ignores time zones
# - B) Uses `tz_localize` and `tz_convert`
# - C) Only UTC
# - D) No support
#
# <details>
# <summary>Show Answer</summary>
#
# **Q894. B)** tz_localize assigns TZ; tz_convert converts between TZs.
#
# </details>

# %% [markdown]
# ### Q895. What does `plt.subplots(2, 3)` return?
#
# - A) Single axes
# - B) 2x3 grid of axes and figure
# - C) List of figures
# - D) 6 separate figures
#
# <details>
# <summary>Show Answer</summary>
#
# **Q895. B)** subplots(nrows, ncols) returns (fig, axes_array).
#
# </details>

# %% [markdown]
# ### Q896. What does Pandas `.str` accessor provide?
#
# - A) Vectorized string methods on Series
# - B) Numeric operations
# - C) Date operations
# - D) Index access
#
# <details>
# <summary>Show Answer</summary>
#
# **Q896. A)** .str gives vectorized string methods (lower, split, replace, etc.).
#
# </details>

# %% [markdown]
# ### Q897. What does NumPy `einsum` do?
#
# - A) Element-wise sum
# - B) Einstein summation for tensor operations
# - C) Sum along axis
# - D) Matrix inverse
#
# <details>
# <summary>Show Answer</summary>
#
# **Q897. B)** einsum expresses dot, outer, trace, etc. via subscript notation.
#
# </details>

# %% [markdown]
# ### Q898. What does `pd.crosstab` compute?
#
# - A) Correlation matrix
# - B) Pivot table
# - C) Cross-tabulation (frequency table) of two or more factors
# - D) Merge
#
# <details>
# <summary>Show Answer</summary>
#
# **Q898. C)** crosstab builds frequency table from two or more columns.
#
# </details>

# %% [markdown]
# ### Q899. What is the difference between normalization and standardization?
#
# - A) Same thing
# - B) Normalization scales to [0,1]; standardization uses mean and std
# - C) Only standardization exists
# - D) Normalization is for images only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q899. B)** Normalization: min-max to [0,1]; Standardization: (x - mean) / std.
#
# </details>

# %% [markdown]
# ### Q900. What do Pandas `eval()` and `query()` do?
#
# - A) Evaluate string expressions for filtering/assignment
# - B) Run Python code
# - C) SQL queries only
# - D) Deprecated
#
# <details>
# <summary>Show Answer</summary>
#
# **Q900. A)** eval/query evaluate string expressions for faster operations.
#
# </details>
