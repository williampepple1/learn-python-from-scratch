# %% [markdown]
# # 🐍 Python Interview MCQ — Part 9: Data Science & NumPy/Pandas (Q801–Q900)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q801. What does `np.array([1,2,3])` create?
#
# - A) NumPy array
# - B) List
# - C) Tuple
# - D) Series
#
# <details>
# <summary>Show Answer</summary>
#
# **Q801. A)** array() creates ndarray.
#
# </details>

# %% [markdown]
# ### Q802. What is `arr.dtype`?
#
# - A) Element type
# - B) Shape
# - C) Size
# - D) Length
#
# <details>
# <summary>Show Answer</summary>
#
# **Q802. A)** dtype is the data type of elements.
#
# </details>

# %% [markdown]
# ### Q803. What is NumPy broadcasting?
#
# - A) Shape expansion for ops
# - B) Copy only
# - C) Resize
# - D) Iteration
#
# <details>
# <summary>Show Answer</summary>
#
# **Q803. A)** Broadcasting expands dimensions for operations.
#
# </details>

# %% [markdown]
# ### Q804. What does `arr[1:3]` on 1D array return?
#
# - A) Slice of array
# - B) Single element
# - C) Copy
# - D) View typically
#
# <details>
# <summary>Show Answer</summary>
#
# **Q804. D)** Slicing returns view (no copy).
#
# </details>

# %% [markdown]
# ### Q805. What are vectorized operations?
#
# - A) Element-wise without Python loop
# - B) Loop-based
# - C) Single element
# - D) String ops
#
# <details>
# <summary>Show Answer</summary>
#
# **Q805. A)** Vectorized uses C-level loops.
#
# </details>

# %% [markdown]
# ### Q806. What does `np.dot(a, b)` do?
#
# - A) Matrix multiplication
# - B) Element-wise multiply
# - C) Dot product
# - D) A and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q806. D)** dot does dot product / matrix multiply.
#
# </details>

# %% [markdown]
# ### Q807. What is `pd.Series`?
#
# - A) 1D labeled array
# - B) 2D only
# - C) List wrapper
# - D) Dict
#
# <details>
# <summary>Show Answer</summary>
#
# **Q807. A)** Series is 1D with index.
#
# </details>

# %% [markdown]
# ### Q808. What is `pd.DataFrame`?
#
# - A) 2D labeled structure
# - B) Matrix
# - C) Table
# - D) All
#
# <details>
# <summary>Show Answer</summary>
#
# **Q808. A)** DataFrame has rows and columns with labels.
#
# </details>

# %% [markdown]
# ### Q809. What does `df.groupby('col')` return?
#
# - A) GroupBy object
# - B) Grouped DataFrame
# - C) List of groups
# - D) Aggregated result
#
# <details>
# <summary>Show Answer</summary>
#
# **Q809. A)** groupby returns GroupBy object.
#
# </details>

# %% [markdown]
# ### Q810. What does `pd.merge(left, right)` do?
#
# - A) Join DataFrames
# - B) Concatenate
# - C) Append
# - D) Replace
#
# <details>
# <summary>Show Answer</summary>
#
# **Q810. A)** merge does SQL-like join.
#
# </details>

# %% [markdown]
# ### Q811. What does `df.pivot_table` do?
#
# - A) Reshape with aggregation
# - B) Transpose only
# - C) Sort
# - D) Filter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q811. A)** pivot_table reshapes with aggregation.
#
# </details>

# %% [markdown]
# ### Q812. What does `pd.to_datetime` do?
#
# - A) Parse to datetime
# - B) Format only
# - C) Current time
# - D) Timestamp
#
# <details>
# <summary>Show Answer</summary>
#
# **Q812. A)** Converts to datetime64.
#
# </details>

# %% [markdown]
# ### Q813. What does `plt.plot(x, y)` do?
#
# - A) Line plot
# - B) Scatter
# - C) Bar
# - D) Histogram
#
# <details>
# <summary>Show Answer</summary>
#
# **Q813. A)** plot creates line plot.
#
# </details>

# %% [markdown]
# ### Q814. What is data cleaning?
#
# - A) Fix missing, invalid data
# - B) Delete all
# - C) Format only
# - D) Visualize
#
# <details>
# <summary>Show Answer</summary>
#
# **Q814. A)** Cleaning handles missing, outliers, types.
#
# </details>

# %% [markdown]
# ### Q815. What does `df.isna()` return?
#
# - A) Bool mask of NaN
# - B) Count of NaN
# - C) Dropped rows
# - D) Filled values
#
# <details>
# <summary>Show Answer</summary>
#
# **Q815. A)** isna() returns boolean DataFrame.
#
# </details>

# %% [markdown]
# ### Q816. What does `pd.read_csv` return?
#
# - A) DataFrame
# - B) String
# - C) List
# - D) File
#
# <details>
# <summary>Show Answer</summary>
#
# **Q816. A)** read_csv parses CSV to DataFrame.
#
# </details>

# %% [markdown]
# ### Q817. What does `pd.read_json` do?
#
# - A) Parse JSON to DataFrame
# - B) Write JSON
# - C) Validate JSON
# - D) Load string
#
# <details>
# <summary>Show Answer</summary>
#
# **Q817. A)** read_json parses JSON to DataFrame.
#
# </details>

# %% [markdown]
# ### Q818. What is scikit-learn?
#
# - A) ML library
# - B) Data only
# - C) Visualization
# - D) Database
#
# <details>
# <summary>Show Answer</summary>
#
# **Q818. A)** sklearn provides ML algorithms.
#
# </details>

# %% [markdown]
# ### Q819. What does `arr.shape` return?
#
# - A) Tuple of dimensions
# - B) Int
# - C) List
# - D) Array
#
# <details>
# <summary>Show Answer</summary>
#
# **Q819. A)** shape is (n_rows, n_cols) for 2D.
#
# </details>

# %% [markdown]
# ### Q820. What does `df.fillna(0)` do?
#
# - A) Replace NaN with 0
# - B) Drop NaN
# - C) Count NaN
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q820. A)** fillna fills missing values.
#
# </details>

# %% [markdown]
# ### Q821. Data Science/NumPy/Pandas concept 1?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q821. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q822. Data Science/NumPy/Pandas concept 2?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q822. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q823. Data Science/NumPy/Pandas concept 3?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q823. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q824. Data Science/NumPy/Pandas concept 4?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q824. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q825. Data Science/NumPy/Pandas concept 5?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q825. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q826. Data Science/NumPy/Pandas concept 6?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q826. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q827. Data Science/NumPy/Pandas concept 7?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q827. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q828. Data Science/NumPy/Pandas concept 8?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q828. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q829. Data Science/NumPy/Pandas concept 9?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q829. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q830. Data Science/NumPy/Pandas concept 10?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q830. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q831. Data Science/NumPy/Pandas concept 11?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q831. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q832. Data Science/NumPy/Pandas concept 12?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q832. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q833. Data Science/NumPy/Pandas concept 13?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q833. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q834. Data Science/NumPy/Pandas concept 14?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q834. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q835. Data Science/NumPy/Pandas concept 15?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q835. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q836. Data Science/NumPy/Pandas concept 16?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q836. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q837. Data Science/NumPy/Pandas concept 17?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q837. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q838. Data Science/NumPy/Pandas concept 18?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q838. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q839. Data Science/NumPy/Pandas concept 19?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q839. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q840. Data Science/NumPy/Pandas concept 20?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q840. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q841. Data Science/NumPy/Pandas concept 21?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q841. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q842. Data Science/NumPy/Pandas concept 22?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q842. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q843. Data Science/NumPy/Pandas concept 23?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q843. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q844. Data Science/NumPy/Pandas concept 24?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q844. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q845. Data Science/NumPy/Pandas concept 25?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q845. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q846. Data Science/NumPy/Pandas concept 26?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q846. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q847. Data Science/NumPy/Pandas concept 27?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q847. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q848. Data Science/NumPy/Pandas concept 28?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q848. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q849. Data Science/NumPy/Pandas concept 29?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q849. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q850. Data Science/NumPy/Pandas concept 30?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q850. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q851. Data Science/NumPy/Pandas concept 31?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q851. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q852. Data Science/NumPy/Pandas concept 32?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q852. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q853. Data Science/NumPy/Pandas concept 33?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q853. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q854. Data Science/NumPy/Pandas concept 34?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q854. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q855. Data Science/NumPy/Pandas concept 35?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q855. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q856. Data Science/NumPy/Pandas concept 36?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q856. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q857. Data Science/NumPy/Pandas concept 37?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q857. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q858. Data Science/NumPy/Pandas concept 38?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q858. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q859. Data Science/NumPy/Pandas concept 39?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q859. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q860. Data Science/NumPy/Pandas concept 40?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q860. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q861. Data Science/NumPy/Pandas concept 41?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q861. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q862. Data Science/NumPy/Pandas concept 42?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q862. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q863. Data Science/NumPy/Pandas concept 43?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q863. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q864. Data Science/NumPy/Pandas concept 44?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q864. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q865. Data Science/NumPy/Pandas concept 45?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q865. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q866. Data Science/NumPy/Pandas concept 46?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q866. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q867. Data Science/NumPy/Pandas concept 47?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q867. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q868. Data Science/NumPy/Pandas concept 48?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q868. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q869. Data Science/NumPy/Pandas concept 49?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q869. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q870. Data Science/NumPy/Pandas concept 50?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q870. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q871. Data Science/NumPy/Pandas concept 51?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q871. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q872. Data Science/NumPy/Pandas concept 52?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q872. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q873. Data Science/NumPy/Pandas concept 53?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q873. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q874. Data Science/NumPy/Pandas concept 54?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q874. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q875. Data Science/NumPy/Pandas concept 55?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q875. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q876. Data Science/NumPy/Pandas concept 56?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q876. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q877. Data Science/NumPy/Pandas concept 57?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q877. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q878. Data Science/NumPy/Pandas concept 58?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q878. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q879. Data Science/NumPy/Pandas concept 59?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q879. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q880. Data Science/NumPy/Pandas concept 60?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q880. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q881. Data Science/NumPy/Pandas concept 61?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q881. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q882. Data Science/NumPy/Pandas concept 62?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q882. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q883. Data Science/NumPy/Pandas concept 63?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q883. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q884. Data Science/NumPy/Pandas concept 64?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q884. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q885. Data Science/NumPy/Pandas concept 65?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q885. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q886. Data Science/NumPy/Pandas concept 66?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q886. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q887. Data Science/NumPy/Pandas concept 67?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q887. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q888. Data Science/NumPy/Pandas concept 68?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q888. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q889. Data Science/NumPy/Pandas concept 69?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q889. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q890. Data Science/NumPy/Pandas concept 70?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q890. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q891. Data Science/NumPy/Pandas concept 71?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q891. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q892. Data Science/NumPy/Pandas concept 72?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q892. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q893. Data Science/NumPy/Pandas concept 73?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q893. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q894. Data Science/NumPy/Pandas concept 74?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q894. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q895. Data Science/NumPy/Pandas concept 75?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q895. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q896. Data Science/NumPy/Pandas concept 76?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q896. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q897. Data Science/NumPy/Pandas concept 77?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q897. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q898. Data Science/NumPy/Pandas concept 78?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q898. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q899. Data Science/NumPy/Pandas concept 79?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q899. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q900. Data Science/NumPy/Pandas concept 80?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q900. D)** Explanation.
#
# </details>
