# %% [markdown]
# # 🐍 Python Interview MCQ — Part 10: Advanced Topics & Mixed (Q901–Q1000)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q901. What does `asyncio.run(main())` do?
#
# - A) Run coroutine
# - B) Create event loop
# - C) Both
# - D) Thread
#
# <details>
# <summary>Show Answer</summary>
#
# **Q901. C)** Creates loop, runs coroutine, closes.
#
# </details>

# %% [markdown]
# ### Q902. What is GIL?
#
# - A) Global Interpreter Lock
# - B) Thread lock
# - C) Process lock
# - D) Import lock
#
# <details>
# <summary>Show Answer</summary>
#
# **Q902. A)** GIL allows one thread to execute Python bytecode.
#
# </details>

# %% [markdown]
# ### Q903. What does `threading` share?
#
# - A) Memory space
# - B) Nothing
# - C) Files only
# - D) CPU only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q903. A)** Threads share same memory.
#
# </details>

# %% [markdown]
# ### Q904. What does `multiprocessing` provide?
#
# - A) Separate processes
# - B) Shared memory
# - C) Same as threading
# - D) Async only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q904. A)** Processes have separate memory.
#
# </details>

# %% [markdown]
# ### Q905. What does `concurrent.futures.ThreadPoolExecutor` do?
#
# - A) Thread pool
# - B) Process pool
# - C) Async
# - D) Single thread
#
# <details>
# <summary>Show Answer</summary>
#
# **Q905. A)** ThreadPoolExecutor manages thread pool.
#
# </details>

# %% [markdown]
# ### Q906. What does `gc.collect()` do?
#
# - A) Run garbage collection
# - B) Delete all
# - C) Count objects
# - D) Disable GC
#
# <details>
# <summary>Show Answer</summary>
#
# **Q906. A)** collect() runs full GC.
#
# </details>

# %% [markdown]
# ### Q907. What does `cProfile.run('func()')` do?
#
# - A) Profile execution
# - B) Time only
# - C) Count calls
# - D) Debug
#
# <details>
# <summary>Show Answer</summary>
#
# **Q907. A)** cProfile profiles CPU time.
#
# </details>

# %% [markdown]
# ### Q908. What does `timeit.timeit` do?
#
# - A) Measure execution time
# - B) Profile
# - C) Debug
# - D) Log
#
# <details>
# <summary>Show Answer</summary>
#
# **Q908. A)** timeit measures small code snippets.
#
# </details>

# %% [markdown]
# ### Q909. What is Singleton pattern?
#
# - A) One instance only
# - B) One method
# - C) One class
# - D) One module
#
# <details>
# <summary>Show Answer</summary>
#
# **Q909. A)** Singleton ensures single instance.
#
# </details>

# %% [markdown]
# ### Q910. What is Factory pattern?
#
# - A) Create objects via factory
# - B) Build only
# - C) Import
# - D) Init
#
# <details>
# <summary>Show Answer</summary>
#
# **Q910. A)** Factory creates objects without specifying exact class.
#
# </details>

# %% [markdown]
# ### Q911. What is Observer pattern?
#
# - A) Notify subscribers
# - B) Watch only
# - C) Event loop
# - D) Callback
#
# <details>
# <summary>Show Answer</summary>
#
# **Q911. A)** Observers notified on subject change.
#
# </details>

# %% [markdown]
# ### Q912. What does SOLID S mean?
#
# - A) Single Responsibility
# - B) Simple
# - C) Static
# - D) Small
#
# <details>
# <summary>Show Answer</summary>
#
# **Q912. A)** One class, one reason to change.
#
# </details>

# %% [markdown]
# ### Q913. What do type hints do?
#
# - A) Annotate types
# - B) Enforce types
# - C) Both
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q913. A)** Hints are optional; no runtime enforcement.
#
# </details>

# %% [markdown]
# ### Q914. What does `mypy` do?
#
# - A) Static type check
# - B) Run code
# - C) Format
# - D) Test
#
# <details>
# <summary>Show Answer</summary>
#
# **Q914. A)** mypy checks types statically.
#
# </details>

# %% [markdown]
# ### Q915. What does `re.match` do?
#
# - A) Match at start
# - B) Match anywhere
# - C) Replace
# - D) Split
#
# <details>
# <summary>Show Answer</summary>
#
# **Q915. A)** match checks from beginning of string.
#
# </details>

# %% [markdown]
# ### Q916. What does `re.search` do?
#
# - A) Match anywhere
# - B) Match start only
# - C) Find all
# - D) Replace
#
# <details>
# <summary>Show Answer</summary>
#
# **Q916. A)** search finds first match anywhere.
#
# </details>

# %% [markdown]
# ### Q917. What is `__pycache__`?
#
# - A) Bytecode cache
# - B) Source cache
# - C) Import cache
# - D) Temp files
#
# <details>
# <summary>Show Answer</summary>
#
# **Q917. A)** Stores .pyc compiled bytecode.
#
# </details>

# %% [markdown]
# ### Q918. What does `-O` flag do?
#
# - A) Optimize bytecode
# - B) Debug
# - C) Verbose
# - D) Fast
#
# <details>
# <summary>Show Answer</summary>
#
# **Q918. A)** Removes asserts, optimizes.
#
# </details>

# %% [markdown]
# ### Q919. What is SQL injection?
#
# - A) Malicious SQL in input
# - B) DB error
# - C) Query only
# - D) Connection
#
# <details>
# <summary>Show Answer</summary>
#
# **Q919. A)** Injecting SQL via user input.
#
# </details>

# %% [markdown]
# ### Q920. Advanced/Mixed concept 1?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q920. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q921. Advanced/Mixed concept 2?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q921. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q922. Advanced/Mixed concept 3?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q922. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q923. Advanced/Mixed concept 4?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q923. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q924. Advanced/Mixed concept 5?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q924. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q925. Advanced/Mixed concept 6?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q925. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q926. Advanced/Mixed concept 7?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q926. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q927. Advanced/Mixed concept 8?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q927. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q928. Advanced/Mixed concept 9?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q928. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q929. Advanced/Mixed concept 10?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q929. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q930. Advanced/Mixed concept 11?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q930. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q931. Advanced/Mixed concept 12?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q931. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q932. Advanced/Mixed concept 13?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q932. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q933. Advanced/Mixed concept 14?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q933. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q934. Advanced/Mixed concept 15?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q934. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q935. Advanced/Mixed concept 16?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q935. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q936. Advanced/Mixed concept 17?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q936. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q937. Advanced/Mixed concept 18?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q937. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q938. Advanced/Mixed concept 19?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q938. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q939. Advanced/Mixed concept 20?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q939. D)** Explanation.
#
# </details>

# %% [markdown]
# ###