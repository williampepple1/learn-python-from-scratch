# %% [markdown]
# # 🐍 Python Interview MCQ — Part 10: Advanced Topics & Mixed (Q901–Q1000)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q901. What does `asyncio.run(main())` do?
#
# - A) Run coroutine
# - B) Create event loop
# - C) Both
# - D) Thread
#
# <details>
# <summary>Show Answer</summary>
#
# **Q901. C)** Creates loop, runs coroutine, closes.
#
# </details>

# %% [markdown]
# ### Q902. What is GIL?
#
# - A) Global Interpreter Lock
# - B) Thread lock
# - C) Process lock
# - D) Import lock
#
# <details>
# <summary>Show Answer</summary>
#
# **Q902. A)** GIL allows one thread to execute Python bytecode.
#
# </details>

# %% [markdown]
# ### Q903. What does `threading` share?
#
# - A) Memory space
# - B) Nothing
# - C) Files only
# - D) CPU only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q903. A)** Threads share same memory.
#
# </details>

# %% [markdown]
# ### Q904. What does `multiprocessing` provide?
#
# - A) Separate processes
# - B) Shared memory
# - C) Same as threading
# - D) Async only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q904. A)** Processes have separate memory.
#
# </details>

# %% [markdown]
# ### Q905. What does `concurrent.futures.ThreadPoolExecutor` do?
#
# - A) Thread pool
# - B) Process pool
# - C) Async
# - D) Single thread
#
# <details>
# <summary>Show Answer</summary>
#
# **Q905. A)** ThreadPoolExecutor manages thread pool.
#
# </details>

# %% [markdown]
# ### Q906. What does `gc.collect()` do?
#
# - A) Run garbage collection
# - B) Delete all
# - C) Count objects
# - D) Disable GC
#
# <details>
# <summary>Show Answer</summary>
#
# **Q906. A)** collect() runs full GC.
#
# </details>

# %% [markdown]
# ### Q907. What does `cProfile.run('func()')` do?
#
# - A) Profile execution
# - B) Time only
# - C) Count calls
# - D) Debug
#
# <details>
# <summary>Show Answer</summary>
#
# **Q907. A)** cProfile profiles CPU time.
#
# </details>

# %% [markdown]
# ### Q908. What does `timeit.timeit` do?
#
# - A) Measure execution time
# - B) Profile
# - C) Debug
# - D) Log
#
# <details>
# <summary>Show Answer</summary>
#
# **Q908. A)** timeit measures small code snippets.
#
# </details>

# %% [markdown]
# ### Q909. What is Singleton pattern?
#
# - A) One instance only
# - B) One method
# - C) One class
# - D) One module
#
# <details>
# <summary>Show Answer</summary>
#
# **Q909. A)** Singleton ensures single instance.
#
# </details>

# %% [markdown]
# ### Q910. What is Factory pattern?
#
# - A) Create objects via factory
# - B) Build only
# - C) Import
# - D) Init
#
# <details>
# <summary>Show Answer</summary>
#
# **Q910. A)** Factory creates objects without specifying exact class.
#
# </details>

# %% [markdown]
# ### Q911. What is Observer pattern?
#
# - A) Notify subscribers
# - B) Watch only
# - C) Event loop
# - D) Callback
#
# <details>
# <summary>Show Answer</summary>
#
# **Q911. A)** Observers notified on subject change.
#
# </details>

# %% [markdown]
# ### Q912. What does SOLID S mean?
#
# - A) Single Responsibility
# - B) Simple
# - C) Static
# - D) Small
#
# <details>
# <summary>Show Answer</summary>
#
# **Q912. A)** One class, one reason to change.
#
# </details>

# %% [markdown]
# ### Q913. What do type hints do?
#
# - A) Annotate types
# - B) Enforce types
# - C) Both
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q913. A)** Hints are optional; no runtime enforcement.
#
# </details>

# %% [markdown]
# ### Q914. What does `mypy` do?
#
# - A) Static type check
# - B) Run code
# - C) Format
# - D) Test
#
# <details>
# <summary>Show Answer</summary>
#
# **Q914. A)** mypy checks types statically.
#
# </details>

# %% [markdown]
# ### Q915. What does `re.match` do?
#
# - A) Match at start
# - B) Match anywhere
# - C) Replace
# - D) Split
#
# <details>
# <summary>Show Answer</summary>
#
# **Q915. A)** match checks from beginning of string.
#
# </details>

# %% [markdown]
# ### Q916. What does `re.search` do?
#
# - A) Match anywhere
# - B) Match start only
# - C) Find all
# - D) Replace
#
# <details>
# <summary>Show Answer</summary>
#
# **Q916. A)** search finds first match anywhere.
#
# </details>

# %% [markdown]
# ### Q917. What is `__pycache__`?
#
# - A) Bytecode cache
# - B) Source cache
# - C) Import cache
# - D) Temp files
#
# <details>
# <summary>Show Answer</summary>
#
# **Q917. A)** Stores .pyc compiled bytecode.
#
# </details>

# %% [markdown]
# ### Q918. What does `-O` flag do?
#
# - A) Optimize bytecode
# - B) Debug
# - C) Verbose
# - D) Fast
#
# <details>
# <summary>Show Answer</summary>
#
# **Q918. A)** Removes asserts, optimizes.
#
# </details>

# %% [markdown]
# ### Q919. What is SQL injection?
#
# - A) Malicious SQL in input
# - B) DB error
# - C) Query only
# - D) Connection
#
# <details>
# <summary>Show Answer</summary>
#
# **Q919. A)** Injecting SQL via user input.
#
# </details>

# %% [markdown]
# ### Q920. What does `asyncio.create_task(coro)` do?
#
# - A) Schedule coroutine
# - B) Run immediately
# - C) Wait for result
# - D) Cancel
#
# <details>
# <summary>Show Answer</summary>
#
# **Q920. A)** Schedules coro, returns Task.
#
# </details>

# %% [markdown]
# ### Q921. Does GIL affect multiprocessing?
#
# - A) No, separate interpreters
# - B) Yes
# - C) Only on Windows
# - D) Sometimes
#
# <details>
# <summary>Show Answer</summary>
#
# **Q921. A)** Each process has own GIL.
#
# </details>

# %% [markdown]
# ### Q922. What does `ProcessPoolExecutor` provide?
#
# - A) Process pool
# - B) Thread pool
# - C) Async
# - D) Single process
#
# <details>
# <summary>Show Answer</summary>
#
# **Q922. A)** ProcessPoolExecutor for CPU-bound work.
#
# </details>

# %% [markdown]
# ### Q923. What does `concurrent.futures.as_completed` yield?
#
# - A) Futures as they complete
# - B) All at end
# - C) In order
# - D) First only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q923. A)** Iterator over completed futures.
#
# </details>

# %% [markdown]
# ### Q924. What triggers GC?
#
# - A) Allocation, thresholds
# - B) Manual only
# - C) Timer
# - D) Never
#
# <details>
# <summary>Show Answer</summary>
#
# **Q924. A)** Automatic when thresholds exceeded.
#
# </details>

# %% [markdown]
# ### Q925. What does `cProfile` output?
#
# - A) Per-function stats
# - B) Total time only
# - C) Memory
# - D) Calls count only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q925. A)** ncalls, tottime, cumtime per function.
#
# </details>

# %% [markdown]
# ### Q926. What does `timeit.repeat` return?
#
# - A) List of timings
# - B) Single value
# - C) Mean
# - D) Min
#
# <details>
# <summary>Show Answer</summary>
#
# **Q926. A)** Multiple runs, returns list.
#
# </details>

# %% [markdown]
# ### Q927. What is Factory Method pattern?
#
# - A) Method creates objects
# - B) Class creates
# - C) Module creates
# - D) Init creates
#
# <details>
# <summary>Show Answer</summary>
#
# **Q927. A)** Factory method in class for object creation.
#
# </details>

# %% [markdown]
# ### Q928. What is Strategy pattern?
#
# - A) Interchangeable algorithms
# - B) Single algorithm
# - C) Fixed strategy
# - D) Config
#
# <details>
# <summary>Show Answer</summary>
#
# **Q928. A)** Encapsulates algorithm, interchangeable.
#
# </details>

# %% [markdown]
# ### Q929. What does SOLID O mean?
#
# - A) Open/Closed
# - B) Object
# - C) Optional
# - D) Override
#
# <details>
# <summary>Show Answer</summary>
#
# **Q929. A)** Open for extension, closed for modification.
#
# </details>

# %% [markdown]
# ### Q930. What does `typing.Optional[int]` mean?
#
# - A) int or None
# - B) int only
# - C) Optional type
# - D) Default int
#
# <details>
# <summary>Show Answer</summary>
#
# **Q930. A)** Union[int, None].
#
# </details>

# %% [markdown]
# ### Q931. What does `mypy --strict` do?
#
# - A) Stricter checks
# - B) Ignore errors
# - C) Warn only
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q931. A)** Enables stricter type checking.
#
# </details>

# %% [markdown]
# ### Q932. What does `re.findall(pattern, s)` return?
#
# - A) List of matches
# - B) First match
# - C) Match object
# - D) Iterator
#
# <details>
# <summary>Show Answer</summary>
#
# **Q932. A)** All non-overlapping matches.
#
# </details>

# %% [markdown]
# ### Q933. What does `re.sub(pattern, repl, s)` do?
#
# - A) Replace matches
# - B) Find
# - C) Split
# - D) Match
#
# <details>
# <summary>Show Answer</summary>
#
# **Q933. A)** Replaces pattern with repl.
#
# </details>

# %% [markdown]
# ### Q934. What does `-OO` do?
#
# - A) Remove docstrings too
# - B) Same as -O
# - C) Debug
# - D) Optimize more
#
# <details>
# <summary>Show Answer</summary>
#
# **Q934. A)** Removes docstrings in addition to -O.
#
# </details>

# %% [markdown]
# ### Q935. What prevents SQL injection?
#
# - A) Parameterized queries
# - B) Validation only
# - C) Escaping
# - D) Both A and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q935. A)** Use ? or %s placeholders, never concatenate.
#
# </details>

# %% [markdown]
# ### Q936. What does `asyncio.gather(*coros)` return?
#
# - A) List of results
# - B) First result
# - C) None
# - D) Task
#
# <details>
# <summary>Show Answer</summary>
#
# **Q936. A)** Runs all, returns list of results.
#
# </details>

# %% [markdown]
# ### Q937. What does GIL prevent?
#
# - A) True parallel Python bytecode
# - B) Threading
# - C) Multiprocessing
# - D) Async
#
# <details>
# <summary>Show Answer</summary>
#
# **Q937. A)** Only one thread runs Python at a time.
#
# </details>

# %% [markdown]
# ### Q938. What does `threading.Lock` provide?
#
# - A) Mutual exclusion
# - B) Async lock
# - C) Process lock
# - D) File lock
#
# <details>
# <summary>Show Answer</summary>
#
# **Q938. A)** Mutex for thread synchronization.
#
# </details>

# %% [markdown]
# ### Q939. What does `multiprocessing.Queue` do?
#
# - A) IPC between processes
# - B) Thread queue
# - C) Async queue
# - D) Task queue
#
# <details>
# <summary>Show Answer</summary>
#
# **Q939. A)** Queue for process communication.
#
# </details>

# %% [markdown]
# ### Q940. What does `future.result()` do?
#
# - A) Block for result
# - B) Return immediately
# - C) Cancel
# - D) Check status
#
# <details>
# <summary>Show Answer</summary>
#
# **Q940. A)** Blocks until done, returns value.
#
# </details>

# %% [markdown]
# ### Q941. What does `gc.disable()` do?
#
# - A) Turn off automatic GC
# - B) Delete all
# - C) Pause
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q941. A)** Disables automatic collection.
#
# </details>

# %% [markdown]
# ### Q942. What does `pstats.Stats` provide?
#
# - A) Profile analysis
# - B) Raw data
# - C) Sorting
# - D) Filtering
#
# <details>
# <summary>Show Answer</summary>
#
# **Q942. A)** Analyze cProfile output.
#
# </details>

# %% [markdown]
# ### Q943. What does `timeit.default_timer` use?
#
# - A) time.perf_counter
# - B) time.time
# - C) Platform-specific
# - D) Both A and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q943. D)** Best available timer.
#
# </details>

# %% [markdown]
# ### Q944. What is Adapter pattern?
#
# - A) Wrap incompatible interface
# - B) Adapt data
# - C) Convert format
# - D) Transform
#
# <details>
# <summary>Show Answer</summary>
#
# **Q944. A)** Adapts one interface to another.
#
# </details>

# %% [markdown]
# ### Q945. What is Template Method pattern?
#
# - A) Skeleton with hooks
# - B) Jinja template
# - C) Base class only
# - D) Override all
#
# <details>
# <summary>Show Answer</summary>
#
# **Q945. A)** Defines skeleton, subclasses fill steps.
#
# </details>

# %% [markdown]
# ### Q946. What does SOLID L mean?
#
# - A) Liskov Substitution
# - B) List
# - C) Load
# - D) Lock
#
# <details>
# <summary>Show Answer</summary>
#
# **Q946. A)** Subtypes must be substitutable.
#
# </details>

# %% [markdown]
# ### Q947. What does `typing.Union[A, B]` mean?
#
# - A) A or B
# - B) A and B
# - C) Either
# - D) Both
#
# <details>
# <summary>Show Answer</summary>
#
# **Q947. A)** Value of type A or B.
#
# </details>

# %% [markdown]
# ### Q948. What does `mypy` not do?
#
# - A) Runtime type check
# - B) Static analysis
# - C) Type inference
# - D) Error report
#
# <details>
# <summary>Show Answer</summary>
#
# **Q948. A)** mypy is static only.
#
# </details>

# %% [markdown]
# ### Q949. What does `re.compile(pattern)` return?
#
# - A) Pattern object
# - B) List
# - C) String
# - D) Match
#
# <details>
# <summary>Show Answer</summary>
#
# **Q949. A)** Compiled regex for reuse.
#
# </details>

# %% [markdown]
# ### Q950. What does `re.split(pattern, s)` return?
#
# - A) List of strings
# - B) Split count
# - C) Iterator
# - D) Match
#
# <details>
# <summary>Show Answer</summary>
#
# **Q950. A)** Splits by pattern.
#
# </details>

# %% [markdown]
# ### Q951. What is `__pycache__` used for?
#
# - A) Faster imports
# - B) Source backup
# - C) Cache data
# - D) Temp
#
# <details>
# <summary>Show Answer</summary>
#
# **Q951. A)** Stores .pyc for faster load.
#
# </details>

# %% [markdown]
# ### Q952. What is XSS?
#
# - A) Cross-site scripting
# - B) SQL injection
# - C) CSRF
# - D) CORS
#
# <details>
# <summary>Show Answer</summary>
#
# **Q952. A)** Injecting scripts via user input.
#
# </details>

# %% [markdown]
# ### Q953. What does `await` do?
#
# - A) Pause until coro completes
# - B) Run sync
# - C) Start task
# - D) Return
#
# <details>
# <summary>Show Answer</summary>
#
# **Q953. A)** Suspends until awaitable done.
#
# </details>

# %% [markdown]
# ### Q954. When is threading beneficial?
#
# - A) I/O-bound work
# - B) CPU-bound
# - C) Both
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q954. A)** GIL released during I/O.
#
# </details>

# %% [markdown]
# ### Q955. What does `Process` share with parent?
#
# - A) Nothing by default
# - B) Memory
# - C) Variables
# - D) Files
#
# <details>
# <summary>Show Answer</summary>
#
# **Q955. A)** Processes have separate memory.
#
# </details>

# %% [markdown]
# ### Q956. What does `executor.submit(f, *args)` return?
#
# - A) Future
# - B) Result
# - C) None
# - D) Task
#
# <details>
# <summary>Show Answer</summary>
#
# **Q956. A)** Future representing pending result.
#
# </details>

# %% [markdown]
# ### Q957. What does `gc.get_objects()` return?
#
# - A) All tracked objects
# - B) Garbage only
# - C) Count
# - D) References
#
# <details>
# <summary>Show Answer</summary>
#
# **Q957. A)** List of objects tracked by GC.
#
# </details>

# %% [markdown]
# ### Q958. What does `cProfile.run` accept?
#
# - A) Code string or callable
# - B) File only
# - C) Module only
# - D) Function only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q958. A)** String to exec or function to run.
#
# </details>

# %% [markdown]
# ### Q959. What does `timeit.Timer` allow?
#
# - A) Custom setup
# - B) Only stmt
# - C) No setup
# - D) Single run
#
# <details>
# <summary>Show Answer</summary>
#
# **Q959. A)** setup and stmt parameters.
#
# </details>

# %% [markdown]
# ### Q960. What is Builder pattern?
#
# - A) Stepwise object construction
# - B) Build all
# - C) Factory
# - D) Init
#
# <details>
# <summary>Show Answer</summary>
#
# **Q960. A)** Constructs complex objects step by step.
#
# </details>

# %% [markdown]
# ### Q961. What is Command pattern?
#
# - A) Encapsulate request as object
# - B) CLI command
# - C) Function
# - D) Method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q961. A)** Request encapsulated for undo/redo.
#
# </details>

# %% [markdown]
# ### Q962. What does SOLID I mean?
#
# - A) Interface Segregation
# - B) Import
# - C) Instance
# - D) Init
#
# <details>
# <summary>Show Answer</summary>
#
# **Q962. A)** Many specific interfaces over one general.
#
# </details>

# %% [markdown]
# ### Q963. What does `typing.List[str]` mean?
#
# - A) List of str
# - B) List type
# - C) Generic list
# - D) Type only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q963. A)** list containing strings.
#
# </details>

# %% [markdown]
# ### Q964. What does `# type: ignore` do?
#
# - A) Suppress mypy error
# - B) Add type
# - C) Remove type
# - D) Comment
#
# <details>
# <summary>Show Answer</summary>
#
# **Q964. A)** Tells mypy to ignore next line.
#
# </details>

# %% [markdown]
# ### Q965. What does `re.fullmatch` require?
#
# - A) Whole string match
# - B) Partial
# - C) Start match
# - D) Any match
#
# <details>
# <summary>Show Answer</summary>
#
# **Q965. A)** Pattern must match entire string.
#
# </details>

# %% [markdown]
# ### Q966. What does `re.IGNORECASE` do?
#
# - A) Case-insensitive match
# - B) Ignore flags
# - C) Skip
# - D) Lowercase
#
# <details>
# <summary>Show Answer</summary>
#
# **Q966. A)** Case-insensitive matching.
#
# </details>

# %% [markdown]
# ### Q967. What does `sys.dont_write_bytecode` do?
#
# - A) Skip .pyc creation
# - B) Delete .pyc
# - C) Write source
# - D) Cache
#
# <details>
# <summary>Show Answer</summary>
#
# **Q967. A)** Prevents writing bytecode files.
#
# </details>

# %% [markdown]
# ### Q968. What is CSRF?
#
# - A) Cross-site request forgery
# - B) Cross-site scripting
# - C) SQL injection
# - D) CORS
#
# <details>
# <summary>Show Answer</summary>
#
# **Q968. A)** Unauthorized actions from user's session.
#
# </details>

# %% [markdown]
# ### Q969. What does `asyncio.sleep(0)` do?
#
# - A) Yield to event loop
# - B) Nothing
# - C) Block
# - D) Sleep forever
#
# <details>
# <summary>Show Answer</summary>
#
# **Q969. A)** Yields control, allows other tasks.
#
# </details>

# %% [markdown]
# ### Q970. What does GIL allow?
#
# - A) One Python thread at a time
# - B) Multiple threads
# - C) No threads
# - D) Parallel threads
#
# <details>
# <summary>Show Answer</summary>
#
# **Q970. A)** Single-threaded execution of bytecode.
#
# </details>

# %% [markdown]
# ### Q971. What does `threading.Event` provide?
#
# - A) Signal between threads
# - B) Lock
# - C) Queue
# - D) Timer
#
# <details>
# <summary>Show Answer</summary>
#
# **Q971. A)** wait/set/clear for signaling.
#
# </details>

# %% [markdown]
# ### Q972. What does `multiprocessing.Pool` provide?
#
# - A) Process pool
# - B) Thread pool
# - C) Queue
# - D) Pipe
#
# <details>
# <summary>Show Answer</summary>
#
# **Q972. A)** Pool of worker processes.
#
# </details>

# %% [markdown]
# ### Q973. What does `future.add_done_callback(fn)` do?
#
# - A) Call fn when done
# - B) Add result
# - C) Cancel
# - D) Wait
#
# <details>
# <summary>Show Answer</summary>
#
# **Q973. A)** Registers callback for completion.
#
# </details>

# %% [markdown]
# ### Q974. What does `gc.get_referrers(obj)` return?
#
# - A) Objects referencing obj
# - B) Objects obj references
# - C) Count
# - D) All
#
# <details>
# <summary>Show Answer</summary>
#
# **Q974. A)** Objects that reference obj.
#
# </details>

# %% [markdown]
# ### Q975. What does `pstats.sort_stats('cumulative')` do?
#
# - A) Sort by cumulative time
# - B) Sort by name
# - C) Sort by calls
# - D) No sort
#
# <details>
# <summary>Show Answer</summary>
#
# **Q975. A)** Sorts profile by cumtime.
#
# </details>

# %% [markdown]
# ### Q976. What does `timeit` default number?
#
# - A) 1,000,000
# - B) 1,000
# - C) 100
# - D) 10
#
# <details>
# <summary>Show Answer</summary>
#
# **Q976. A)** Default repeat count for stmt.
#
# </details>

# %% [markdown]
# ### Q977. What is Facade pattern?
#
# - A) Simplify complex subsystem
# - B) Front-end
# - C) Interface
# - D) Wrapper
#
# <details>
# <summary>Show Answer</summary>
#
# **Q977. A)** Simple interface to complex system.
#
# </details>

# %% [markdown]
# ### Q978. What is Decorator pattern (OOP)?
#
# - A) Add behavior to object
# - B) Python decorator
# - C) Function wrapper
# - D) Class decorator
#
# <details>
# <summary>Show Answer</summary>
#
# **Q978. A)** Wraps object to add responsibilities.
#
# </details>

# %% [markdown]
# ### Q979. What does SOLID D mean?
#
# - A) Dependency Inversion
# - B) Data
# - C) Default
# - D) Delegate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q979. A)** Depend on abstractions, not concretions.
#
# </details>

# %% [markdown]
# ### Q980. What does `typing.Dict[str, int]` mean?
#
# - A) Dict mapping str to int
# - B) Dict type
# - C) Generic
# - D) Type hint
#
# <details>
# <summary>Show Answer</summary>
#
# **Q980. A)** dict with str keys, int values.
#
# </details>

# %% [markdown]
# ### Q981. What does `mypy --no-incremental` do?
#
# - A) Full check each run
# - B) No check
# - C) Faster
# - D) Incremental
#
# <details>
# <summary>Show Answer</summary>
#
# **Q981. A)** Disables incremental mode.
#
# </details>

# %% [markdown]
# ### Q982. What does `re.match` return if no match?
#
# - A) None
# - B) Empty string
# - C) False
# - D) Raise
#
# <details>
# <summary>Show Answer</summary>
#
# **Q982. A)** Returns None when no match.
#
# </details>

# %% [markdown]
# ### Q983. What does `re.MULTILINE` affect?
#
# - A) ^ and $ match line boundaries
# - B) Dot matches newline
# - C) Case
# - D) Greedy
#
# <details>
# <summary>Show Answer</summary>
#
# **Q983. A)** ^/$ match per line.
#
# </details>

# %% [markdown]
# ### Q984. What does `importlib.util.find_spec` return?
#
# - A) ModuleSpec or None
# - B) Module
# - C) Path
# - D) Loader
#
# <details>
# <summary>Show Answer</summary>
#
# **Q984. A)** Finds module without importing.
#
# </details>

# %% [markdown]
# ### Q985. What is path traversal?
#
# - A) Access files outside intended dir
# - B) Directory listing
# - C) File read
# - D) Path injection
#
# <details>
# <summary>Show Answer</summary>
#
# **Q985. A)** .. in path to escape directory.
#
# </details>

# %% [markdown]
# ### Q986. What does `async with` require?
#
# - A) Async context manager
# - B) Sync CM
# - C) Any CM
# - D) ContextVar
#
# <details>
# <summary>Show Answer</summary>
#
# **Q986. A)** Object with __aenter__/__aexit__.
#
# </details>

# %% [markdown]
# ### Q987. What does `threading.local()` provide?
#
# - A) Thread-local storage
# - B) Global
# - C) Shared
# - D) Process-local
#
# <details>
# <summary>Show Answer</summary>
#
# **Q987. A)** Separate data per thread.
#
# </details>

# %% [markdown]
# ### Q988. What does `multiprocessing.Manager` provide?
#
# - A) Shared objects across processes
# - B) Process manager
# - C) Pool manager
# - D) Queue manager
#
# <details>
# <summary>Show Answer</summary>
#
# **Q988. A)** Proxy objects for shared state.
#
# </details>

# %% [markdown]
# ### Q989. What does `concurrent.futures.wait` return?
#
# - A) Done and not_done sets
# - B) Results
# - C) First
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q989. A)** Returns (done_futures, not_done_futures).
#
# </details>

# %% [markdown]
# ### Q990. What does `gc.is_tracked(obj)` return?
#
# - A) True if GC tracks obj
# - B) If garbage
# - C) Reference count
# - D) Generation
#
# <details>
# <summary>Show Answer</summary>
#
# **Q990. A)** Whether object is tracked.
#
# </details>

# %% [markdown]
# ### Q991. What does `memory_profiler` show?
#
# - A) Memory usage over time
# - B) CPU only
# - C) Line count
# - D) Calls
#
# <details>
# <summary>Show Answer</summary>
#
# **Q991. A)** Line-by-line memory profiling.
#
# </details>

# %% [markdown]
# ### Q992. What does `tracemalloc` provide?
#
# - A) Memory allocation tracking
# - B) CPU profile
# - C) GC stats
# - D) Object count
#
# <details>
# <summary>Show Answer</summary>
#
# **Q992. A)** Tracks memory allocations.
#
# </details>

# %% [markdown]
# ### Q993. What is Proxy pattern?
#
# - A) Surrogate for another object
# - B) Network proxy
# - C) Delegate
# - D) Wrapper
#
# <details>
# <summary>Show Answer</summary>
#
# **Q993. A)** Controls access to real object.
#
# </details>

# %% [markdown]
# ### Q994. What is Chain of Responsibility?
#
# - A) Pass request along chain
# - B) Single handler
# - C) Pipeline
# - D) Middleware
#
# <details>
# <summary>Show Answer</summary>
#
# **Q994. A)** Request passed to chain of handlers.
#
# </details>

# %% [markdown]
# ### Q995. What does `typing.Callable[[int], str]` mean?
#
# - A) Function int -> str
# - B) Callable class
# - C) Method
# - D) Lambda
#
# <details>
# <summary>Show Answer</summary>
#
# **Q995. A)** Takes int, returns str.
#
# </details>

# %% [markdown]
# ### Q996. What does `from __future__ import annotations` do?
#
# - A) Defer annotation evaluation
# - B) Enable annotations
# - C) Import annotations
# - D) String annotations
#
# <details>
# <summary>Show Answer</summary>
#
# **Q996. A)** Annotations become strings, no runtime eval.
#
# </details>

# %% [markdown]
# ### Q997. What does `re.DOTALL` do?
#
# - A) Dot matches newline
# - B) Match all
# - C) Single line
# - D) Multiline
#
# <details>
# <summary>Show Answer</summary>
#
# **Q997. A)** . matches any char including newline.
#
# </details>

# %% [markdown]
# ### Q998. What does `re.VERBOSE` allow?
#
# - A) Whitespace, comments in pattern
# - B) Verbose output
# - C) Long pattern
# - D) Debug
#
# <details>
# <summary>Show Answer</summary>
#
# **Q998. A)** Ignores whitespace, allows # comments.
#
# </details>

# %% [markdown]
# ### Q999. What does `sys.setprofile` set?
#
# - A) Profiler for function calls
# - B) Trace
# - C) Debug
# - D) Hook
#
# <details>
# <summary>Show Answer</summary>
#
# **Q999. A)** Global profiler callback.
#
# </details>

# %% [markdown]
# ### Q1000. What is input validation?
#
# - A) Check/sanitize user input
# - B) Type check
# - C) Parse only
# - D) Format
#
# <details>
# <summary>Show Answer</summary>
#
# **Q1000. A)** Validate before use.
#
# </details>
