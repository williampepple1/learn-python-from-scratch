# %% [markdown]
# # 🐍 Python Interview MCQ — Part 4: Functional Programming & Iterators (Q301–Q400)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q301. What does `lambda x: x*2` return?
#
# - A) Function
# - B) 2
# - C) x*2
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q301. A)** lambda creates anonymous function.
#
# </details>

# %% [markdown]
# ### Q302. What is `map(str, [1,2,3])`?
#
# - A) ['1','2','3']
# - B) map object
# - C) str
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q302. B)** map returns iterator.
#
# </details>

# %% [markdown]
# ### Q303. What does `filter(None, [0,1,2])` return?
#
# - A) [1,2]
# - B) filter object
# - C) [0,1,2]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q303. B)** filter returns iterator.
#
# </details>

# %% [markdown]
# ### Q304. What is `reduce` from functools?
#
# - A) Reduces to single value
# - B) Filter
# - C) Map
# - D) Sort
#
# <details>
# <summary>Show Answer</summary>
#
# **Q304. A)** reduce folds iterable.
#
# </details>

# %% [markdown]
# ### Q305. What does `zip([1,2],[3,4])` return?
#
# - A) [(1,3),(2,4)]
# - B) zip object
# - C) [1,2,3,4]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q305. B)** zip returns iterator.
#
# </details>

# %% [markdown]
# ### Q306. What is `enumerate(['a','b'])`?
#
# - A) [(0,'a'),(1,'b')]
# - B) enumerate object
# - C) ['a','b']
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q306. B)** enumerate returns iterator.
#
# </details>

# %% [markdown]
# ### Q307. What does `any([False,True])` return?
#
# - A) False
# - B) True
# - C) 1
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q307. B)** any() True if any truthy.
#
# </details>

# %% [markdown]
# ### Q308. What is `all([True,False])`?
#
# - A) True
# - B) False
# - C) 0
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q308. B)** all() False if any falsy.
#
# </details>

# %% [markdown]
# ### Q309. What does `sorted([3,1,2])` return?
#
# - A) [1,2,3]
# - B) None
# - C) [3,1,2]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q309. A)** sorted returns new list.
#
# </details>

# %% [markdown]
# ### Q310. What is `reversed([1,2,3])`?
#
# - A) [3,2,1]
# - B) reverse iterator
# - C) None
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q310. B)** reversed returns iterator.
#
# </details>

# %% [markdown]
# ### Q311. What does `from functools import reduce` provide?
#
# - A) reduce function
# - B) Reduce module
# - C) Built-in
# - D) Import
#
# <details>
# <summary>Show Answer</summary>
#
# **Q311. A)** functools.reduce folds iterable.
#
# </details>

# %% [markdown]
# ### Q312. What is `(x for x in range(3))`?
#
# - A) Generator expr
# - B) List
# - C) Tuple
# - D) Range
#
# <details>
# <summary>Show Answer</summary>
#
# **Q312. A)** Parentheses create generator expression.
#
# </details>

# %% [markdown]
# ### Q313. What does `yield` do?
#
# - A) Pause and return
# - B) Return
# - C) Stop
# - D) Break
#
# <details>
# <summary>Show Answer</summary>
#
# **Q313. A)** yield pauses and returns value.
#
# </details>

# %% [markdown]
# ### Q314. What is `itertools.chain`?
#
# - A) Chain iterables
# - B) Link
# - C) Connect
# - D) Merge
#
# <details>
# <summary>Show Answer</summary>
#
# **Q314. A)** chain chains iterables together.
#
# </details>

# %% [markdown]
# ### Q315. What does `functools.partial` do?
#
# - A) Fix some args
# - B) Partial apply
# - C) Both
# - D) Curry
#
# <details>
# <summary>Show Answer</summary>
#
# **Q315. C)** partial fixes function arguments.
#
# </details>

# %% [markdown]
# ### Q316. What is a closure?
#
# - A) Function with captured vars
# - B) Nested function
# - C) Both
# - D) Lambda
#
# <details>
# <summary>Show Answer</summary>
#
# **Q316. C)** Closure captures enclosing scope.
#
# </details>

# %% [markdown]
# ### Q317. What does `{x: x**2 for x in range(3)}` produce?
#
# - A) {0:0,1:1,2:4}
# - B) Dict comp
# - C) Both
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q317. C)** Dict comprehension.
#
# </details>

# %% [markdown]
# ### Q318. What is `{x for x in 'ab'}`?
#
# - A) {'a','b'}
# - B) Set comp
# - C) Both
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q318. C)** Set comprehension.
#
# </details>

# %% [markdown]
# ### Q319. Functional: lambda, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q319. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q320. unctional: lambda, m?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q320. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q321. nctional: lambda, ma?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q321. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q322. ctional: lambda, map?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q322. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q323. tional: lambda, map,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q323. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q324. ional: lambda, map, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q324. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q325. onal: lambda, map, f?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q325. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q326. nal: lambda, map, fi?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q326. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q327. al: lambda, map, fil?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q327. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q328. l: lambda, map, filt?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q328. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q329. : lambda, map, filte?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q329. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q330.  lambda, map, filter?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q330. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q331. lambda, map, filter,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q331. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q332. ambda, map, filter, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q332. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q333. mbda, map, filter, r?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q333. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q334. bda, map, filter, re?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q334. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q335. da, map, filter, red?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q335. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q336. a, map, filter, redu?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q336. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q337. , map, filter, reduc?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q337. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q338.  map, filter, reduce?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q338. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q339. map, filter, reduce,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q339. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q340. ap, filter, reduce, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q340. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q341. p, filter, reduce, z?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q341. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q342. , filter, reduce, zi?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q342. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q343.  filter, reduce, zip?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q343. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q344. filter, reduce, zip,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q344. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q345. ilter, reduce, zip, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q345. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q346. lter, reduce, zip, e?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q346. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q347. ter, reduce, zip, en?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q347. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q348. er, reduce, zip, enu?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q348. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q349. r, reduce, zip, enum?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q349. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q350. , reduce, zip, enume?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q350. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q351.  reduce, zip, enumer?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q351. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q352. reduce, zip, enumera?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q352. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q353. educe, zip, enumerat?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q353. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q354. duce, zip, enumerate?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q354. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q355. uce, zip, enumerate,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q355. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q356. ce, zip, enumerate, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q356. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q357. e, zip, enumerate, g?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q357. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q358. , zip, enumerate, ge?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q358. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q359.  zip, enumerate, gen?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q359. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q360. zip, enumerate, gene?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q360. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q361. ip, enumerate, gener?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q361. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q362. p, enumerate, genera?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q362. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q363. , enumerate, generat?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q363. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q364.  enumerate, generato?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q364. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q365. enumerate, generator?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q365. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q366. numerate, generators?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q366. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q367. umerate, generators?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q367. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q368. merate, generators?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q368. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q369. Functional: lambda, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q369. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q370. unctional: lambda, m?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q370. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q371. nctional: lambda, ma?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q371. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q372. ctional: lambda, map?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q372. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q373. tional: lambda, map,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q373. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q374. ional: lambda, map, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q374. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q375. onal: lambda, map, f?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q375. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q376. nal: lambda, map, fi?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q376. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q377. al: lambda, map, fil?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q377. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q378. l: lambda, map, filt?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q378. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q379. : lambda, map, filte?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q379. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q380.  lambda, map, filter?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q380. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q381. lambda, map, filter,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q381. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q382. ambda, map, filter, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q382. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q383. mbda, map, filter, r?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q383. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q384. bda, map, filter, re?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q384. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q385. da, map, filter, red?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q385. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q386. a, map, filter, redu?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q386. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q387. , map, filter, reduc?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q387. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q388.  map, filter, reduce?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q388. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q389. map, filter, reduce,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q389. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q390. ap, filter, reduce, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q390. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q391. p, filter, reduce, z?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q391. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q392. , filter, reduce, zi?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q392. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q393.  filter, reduce, zip?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q393. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q394. filter, reduce, zip,?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q394. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q395. ilter, reduce, zip, ?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q395. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q396. lter, reduce, zip, e?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q396. B)** FP concept.
#
# </details>

# %% [markdown]
# ### Q397. ter, reduce, zip, en?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q397. C)** FP concept.
#
# </details>

# %% [markdown]
# ### Q398. er, reduce, zip, enu?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q398. D)** FP concept.
#
# </details>

# %% [markdown]
# ### Q399. r, reduce, zip, enum?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q399. A)** FP concept.
#
# </details>

# %% [markdown]
# ### Q400. , reduce, zip, enume?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q400. B)** FP concept.
#
# </details>
