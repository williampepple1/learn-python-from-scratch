# %% [markdown]
# # 🐍 Python Interview MCQ — Part 3: OOP & Classes (Q201-Q300)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q201. What does `__init__` do?
#
# - A) Constructor
# - B) Destructor
# - C) Static method
# - D) Class method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q201. A)** __init__ initializes instance.
#
# </details>

# %% [markdown]
# ### Q202. What is `self` in a method?
#
# - A) Keyword
# - B) Reference to instance
# - C) Class name
# - D) Module
#
# <details>
# <summary>Show Answer</summary>
#
# **Q202. B)** self refers to the instance.
#
# </details>

# %% [markdown]
# ### Q203. What does `@classmethod` do?
#
# - A) Makes static
# - B) Receives class as first arg
# - C) Private method
# - D) Abstract
#
# <details>
# <summary>Show Answer</summary>
#
# **Q203. B)** classmethod gets cls as first arg.
#
# </details>

# %% [markdown]
# ### Q204. What is `@staticmethod`?
#
# - A) No self or cls
# - B) Class only
# - C) Instance only
# - D) Abstract
#
# <details>
# <summary>Show Answer</summary>
#
# **Q204. A)** staticmethod has no implicit args.
#
# </details>

# %% [markdown]
# ### Q205. What does `@property` do?
#
# - A) Makes attribute read-only
# - B) Defines getter/setter
# - C) Class attribute
# - D) Private
#
# <details>
# <summary>Show Answer</summary>
#
# **Q205. B)** property creates getter/setter.
#
# </details>

# %% [markdown]
# ### Q206. What is `__str__` for?
#
# - A) repr
# - B) Human-readable string
# - C) str type
# - D) Comparison
#
# <details>
# <summary>Show Answer</summary>
#
# **Q206. B)** __str__ for str() and print().
#
# </details>

# %% [markdown]
# ### Q207. What does `__repr__` return?
#
# - A) Human string
# - B) Unambiguous repr
# - C) str
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q207. B)** __repr__ should be unambiguous.
#
# </details>

# %% [markdown]
# ### Q208. What is `__len__`?
#
# - A) Length method
# - B) len() calls it
# - C) Both A and B
# - D) Iterator
#
# <details>
# <summary>Show Answer</summary>
#
# **Q208. C)** __len__ implements len().
#
# </details>

# %% [markdown]
# ### Q209. What does `__eq__` do?
#
# - A) Assignment
# - B) Implements ==
# - C) Equality check
# - D) Both B and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q209. D)** __eq__ implements ==.
#
# </details>

# %% [markdown]
# ### Q210. What is `__add__`?
#
# - A) Addition only
# - B) Implements +
# - C) Increment
# - D) Append
#
# <details>
# <summary>Show Answer</summary>
#
# **Q210. B)** __add__ implements + operator.
#
# </details>

# %% [markdown]
# ### Q211. What is inheritance?
#
# - A) Subclass gets parent attributes
# - B) Copy class
# - C) Import
# - D) Override only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q211. A)** Inheritance allows subclass to inherit.
#
# </details>

# %% [markdown]
# ### Q212. What does super() do?
#
# - A) Call parent method
# - B) Return parent proxy
# - C) Both
# - D) Create parent
#
# <details>
# <summary>Show Answer</summary>
#
# **Q212. C)** super() returns proxy to call parent.
#
# </details>

# %% [markdown]
# ### Q213. What is MRO?
#
# - A) Method resolution order
# - B) Multiple return
# - C) Module order
# - D) Method order
#
# <details>
# <summary>Show Answer</summary>
#
# **Q213. A)** MRO determines lookup order.
#
# </details>

# %% [markdown]
# ### Q214. What is multiple inheritance?
#
# - A) One parent
# - B) Multiple base classes
# - C) Many methods
# - D) Many instances
#
# <details>
# <summary>Show Answer</summary>
#
# **Q214. B)** Class inherits from multiple bases.
#
# </details>

# %% [markdown]
# ### Q215. What is ABC?
#
# - A) Abstract Base Class
# - B) Alphabet
# - C) Base only
# - D) Abstract method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q215. A)** ABC defines abstract base classes.
#
# </details>

# %% [markdown]
# ### Q216. What is duck typing?
#
# - A) Type by behavior
# - B) Static typing
# - C) Type checking
# - D) Inheritance
#
# <details>
# <summary>Show Answer</summary>
#
# **Q216. A)** Use by behavior not type.
#
# </details>

# %% [markdown]
# ### Q217. What are dataclasses?
#
# - A) Auto __init__
# - B) Data containers
# - C) Both
# - D) Database
#
# <details>
# <summary>Show Answer</summary>
#
# **Q217. C)** dataclasses auto-generate __init__.
#
# </details>

# %% [markdown]
# ### Q218. What is __slots__?
#
# - A) Limit attributes
# - B) Save memory
# - C) Both
# - D) Private
#
# <details>
# <summary>Show Answer</summary>
#
# **Q218. C)** __slots__ restricts attributes.
#
# </details>

# %% [markdown]
# ### Q219. What is encapsulation?
#
# - A) Hide implementation
# - B) Bundling
# - C) Both
# - D) Inheritance
#
# <details>
# <summary>Show Answer</summary>
#
# **Q219. C)** Encapsulation bundles and hides.
#
# </details>

# %% [markdown]
# ### Q220. What is name mangling?
#
# - A) __attr to _Class__attr
# - B) Rename
# - C) Private
# - D) Encode
#
# <details>
# <summary>Show Answer</summary>
#
# **Q220. A)** Double underscore triggers mangling.
#
# </details>

# %% [markdown]
# ### Q221. What is __init__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q221. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q222. What is self in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q222. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q223. What is @classmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q223. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q224. What is @staticmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q224. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q225. What is @property in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q225. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q226. What is __str__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q226. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q227. What is __repr__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q227. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q228. What is __len__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q228. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q229. What is __eq__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q229. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q230. What is __add__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q230. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q231. What is inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q231. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q232. What is super() in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q232. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q233. What is MRO in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q233. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q234. What is multiple inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q234. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q235. What is ABC in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q235. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q236. What is duck typing in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q236. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q237. What is dataclasses in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q237. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q238. What is __slots__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q238. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q239. What is encapsulation in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q239. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q240. What is __init__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q240. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q241. What is self in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q241. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q242. What is @classmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q242. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q243. What is @staticmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q243. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q244. What is @property in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q244. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q245. What is __str__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q245. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q246. What is __repr__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q246. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q247. What is __len__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q247. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q248. What is __eq__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q248. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q249. What is __add__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q249. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q250. What is inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q250. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q251. What is super() in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q251. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q252. What is MRO in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q252. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q253. What is multiple inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q253. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q254. What is ABC in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q254. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q255. What is duck typing in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q255. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q256. What is dataclasses in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q256. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q257. What is __slots__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q257. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q258. What is encapsulation in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q258. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q259. What is __init__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q259. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q260. What is self in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q260. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q261. What is @classmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q261. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q262. What is @staticmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q262. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q263. What is @property in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q263. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q264. What is __str__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q264. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q265. What is __repr__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q265. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q266. What is __len__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q266. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q267. What is __eq__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q267. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q268. What is __add__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q268. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q269. What is inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q269. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q270. What is super() in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q270. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q271. What is MRO in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q271. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q272. What is multiple inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q272. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q273. What is ABC in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q273. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q274. What is duck typing in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q274. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q275. What is dataclasses in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q275. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q276. What is __slots__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q276. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q277. What is encapsulation in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q277. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q278. What is __init__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q278. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q279. What is self in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q279. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q280. What is @classmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q280. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q281. What is @staticmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q281. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q282. What is @property in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q282. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q283. What is __str__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q283. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q284. What is __repr__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q284. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q285. What is __len__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q285. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q286. What is __eq__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q286. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q287. What is __add__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q287. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q288. What is inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q288. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q289. What is super() in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q289. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q290. What is MRO in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q290. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q291. What is multiple inheritance in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q291. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q292. What is ABC in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q292. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q293. What is duck typing in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q293. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q294. What is dataclasses in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q294. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q295. What is __slots__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q295. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q296. What is encapsulation in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q296. D)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q297. What is __init__ in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q297. A)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q298. What is self in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q298. B)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q299. What is @classmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q299. C)** OOP concept.
#
# </details>

# %% [markdown]
# ### Q300. What is @staticmethod in Python OOP?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q300. D)** OOP concept.
#
# </details>
