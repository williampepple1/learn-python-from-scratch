# %% [markdown]
# # 🐍 Python Interview MCQ — Part 1: Basics & Syntax (Q1–Q100)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q1. What is Python primarily known for?
#
# - A) Being the fastest programming language
# - B) Readability and clean syntax
# - C) Exclusively for web development
# - D) Compiled-only execution
#
# <details>
# <summary>Show Answer</summary>
#
# **Q1. B)** Python emphasizes code readability with its clear, expressive syntax. It's interpreted, not compiled, and is used across many domains.
#
# </details>

# %% [markdown]
# ### Q2. Which organization maintains the Python language?
#
# - A) Mozilla Foundation
# - B) Python Software Foundation
# - C) Open Source Initiative
# - D) Linux Foundation
#
# <details>
# <summary>Show Answer</summary>
#
# **Q2. B)** The Python Software Foundation (PSF) maintains and oversees Python development.
#
# </details>

# %% [markdown]
# ### Q3. What does PEP 8 define?
#
# - A) Python Enhancement Proposals only
# - B) Style guide for Python code
# - C) Python package manager
# - D) Python execution model
#
# <details>
# <summary>Show Answer</summary>
#
# **Q3. B)** PEP 8 is the official style guide for Python code, covering formatting, naming conventions, and best practices.
#
# </details>

# %% [markdown]
# ### Q4. What is the output of `print(type(3.14))`?
#
# - A) int
# - B) float
# - C) decimal
# - D) number
#
# <details>
# <summary>Show Answer</summary>
#
# **Q4. B)** 3.14 is a float literal. The type() function returns <class 'float'>.
#
# </details>

# %% [markdown]
# ### Q5. Which is NOT a valid Python variable name?
#
# - A) _private
# - B) 2nd_value
# - C) value_2
# - D) value2
#
# <details>
# <summary>Show Answer</summary>
#
# **Q5. B)** Variable names cannot start with a digit. 2nd_value is invalid.
#
# </details>

# %% [markdown]
# ### Q6. What does `10 // 3` evaluate to?
#
# - A) 3.333...
# - B) 3
# - C) 3.0
# - D) 4
#
# <details>
# <summary>Show Answer</summary>
#
# **Q6. B)** The // operator performs floor division, returning an integer (3) when both operands are integers.
#
# </details>

# %% [markdown]
# ### Q7. What is `bool(0)` in Python?
#
# - A) True
# - B) False
# - C) 0
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q7. B)** In Python, 0 is falsy. bool(0) returns False.
#
# </details>

# %% [markdown]
# ### Q8. What does `id(x)` return?
#
# - A) The type of x
# - B) Memory address/identity of object x
# - C) The value of x
# - D) Length of x
#
# <details>
# <summary>Show Answer</summary>
#
# **Q8. B)** id() returns the unique integer identity (memory address) of an object.
#
# </details>

# %% [markdown]
# ### Q9. Which keyword is used to define a function?
#
# - A) func
# - B) def
# - C) function
# - D) define
#
# <details>
# <summary>Show Answer</summary>
#
# **Q9. B)** Python uses the def keyword to define functions.
#
# </details>

# %% [markdown]
# ### Q10. What is the output of `print(2 ** 3)`?
#
# - A) 6
# - B) 8
# - C) 9
# - D) 23
#
# <details>
# <summary>Show Answer</summary>
#
# **Q10. B)** ** is the exponentiation operator. 2 ** 3 = 8.
#
# </details>

# %% [markdown]
# ### Q11. Which is the correct way to write a multi-line comment?
#
# - A) /* comment */
# - B) '''comment''' or """comment"""
# - C) // comment
# - D) # comment (only for single line)
#
# <details>
# <summary>Show Answer</summary>
#
# **Q11. B)** Python uses triple quotes (''' or """) for multi-line strings, often used as docstrings/comments.
#
# </details>

# %% [markdown]
# ### Q12. What does `'hello' == "hello"` evaluate to?
#
# - A) False
# - B) True
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q12. B)** Single and double quotes create equivalent strings. They compare equal.
#
# </details>

# %% [markdown]
# ### Q13. What is `None` in Python?
#
# - A) Same as 0
# - B) A singleton object representing absence of value
# - C) An empty string
# - D) False
#
# <details>
# <summary>Show Answer</summary>
#
# **Q13. B)** None is a built-in singleton representing the absence of a value. It's not 0, '', or False.
#
# </details>

# %% [markdown]
# ### Q14. What does `isinstance(5, int)` return?
#
# - A) 5
# - B) True
# - C) int
# - D) False
#
# <details>
# <summary>Show Answer</summary>
#
# **Q14. B)** isinstance(obj, type) returns True if obj is an instance of type (or a subclass).
#
# </details>

# %% [markdown]
# ### Q15. Which operator has highest precedence: `*`, `+`, `**`, `()`?
#
# - A) *
# - B) +
# - C) **
# - D) ()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q15. D)** Parentheses () have the highest precedence, then **, then * and /, then + and -.
#
# </details>

# %% [markdown]
# ### Q16. What is the output of `print(1 != 1.0)`?
#
# - A) True
# - B) False
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q16. B)** 1 and 1.0 are equal in value (==), so 1 != 1.0 is False.
#
# </details>

# %% [markdown]
# ### Q17. What does `input()` return?
#
# - A) An integer
# - B) A string
# - C) Depends on user input
# - D) A float
#
# <details>
# <summary>Show Answer</summary>
#
# **Q17. B)** input() always returns a string. You must convert to int/float if needed.
#
# </details>

# %% [markdown]
# ### Q18. Which is NOT a Python keyword?
#
# - A) lambda
# - B) async
# - C) null
# - D) yield
#
# <details>
# <summary>Show Answer</summary>
#
# **Q18. C)** Python uses None, not null. null is not a keyword.
#
# </details>

# %% [markdown]
# ### Q19. What does `print(sep='-', 'a', 'b', 'c')` do?
#
# - A) Prints a-b-c
# - B) SyntaxError
# - C) Prints a b c
# - D) Prints abc
#
# <details>
# <summary>Show Answer</summary>
#
# **Q19. B)** Keyword arguments must come after positional arguments. This causes a SyntaxError.
#
# </details>

# %% [markdown]
# ### Q20. What is `type(True)`?
#
# - A) int
# - B) bool
# - C) boolean
# - D) Boolean
#
# <details>
# <summary>Show Answer</summary>
#
# **Q20. B)** True and False are of type bool. In Python, bool is a subclass of int.
#
# </details>

# %% [markdown]
# ### Q21. What does `10 % 3` return?
#
# - A) 1
# - B) 3
# - C) 0
# - D) 3.33
#
# <details>
# <summary>Show Answer</summary>
#
# **Q21. A)** % is the modulo operator. 10 % 3 = 1 (remainder of 10 divided by 3).
#
# </details>

# %% [markdown]
# ### Q22. Which converts a string to an integer?
#
# - A) int(str)
# - B) integer(str)
# - C) parse.Int(str)
# - D) str.to_int()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q22. A)** int() converts a string to an integer, e.g., int('42') -> 42.
#
# </details>

# %% [markdown]
# ### Q23. What is the output of `print(2 + 3 * 4)`?
#
# - A) 20
# - B) 14
# - C) 24
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q23. B)** Multiplication has higher precedence: 3 * 4 = 12, then 2 + 12 = 14.
#
# </details>

# %% [markdown]
# ### Q24. What does `and` return when both operands are truthy?
#
# - A) True
# - B) The second operand
# - C) The first operand
# - D) 1
#
# <details>
# <summary>Show Answer</summary>
#
# **Q24. B)** and returns the first falsy value, or the last value if all are truthy. So it returns the second operand.
#
# </details>

# %% [markdown]
# ### Q25. What is `bool('')`?
#
# - A) True
# - B) False
# - C) 0
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q25. B)** Empty string is falsy in Python. bool('') returns False.
#
# </details>

# %% [markdown]
# ### Q26. Which symbol starts a single-line comment?
#
# - A) //
# - B) #
# - C) /*
# - D) --
#
# <details>
# <summary>Show Answer</summary>
#
# **Q26. B)** Python uses # for single-line comments.
#
# </details>

# %% [markdown]
# ### Q27. What does `print(end='')` do?
#
# - A) Prints nothing
# - B) Ends the program
# - C) Uses empty string instead of newline
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q27. C)** end='' overrides the default newline, so nothing is printed after the content.
#
# </details>

# %% [markdown]
# ### Q28. What is `1 < 2 < 3` equivalent to?
#
# - A) (1 < 2) and (2 < 3)
# - B) 1 < (2 < 3)
# - C) Chained comparison, not equivalent to and
# - D) SyntaxError
#
# <details>
# <summary>Show Answer</summary>
#
# **Q28. A)** Python allows chained comparisons: 1 < 2 < 3 is equivalent to (1 < 2) and (2 < 3).
#
# </details>

# %% [markdown]
# ### Q29. What does `~5` produce (bitwise NOT)?
#
# - A) -5
# - B) -6
# - C) 5
# - D) 4
#
# <details>
# <summary>Show Answer</summary>
#
# **Q29. B)** ~x = -(x+1). So ~5 = -6.
#
# </details>

# %% [markdown]
# ### Q30. Which is valid Python indentation?
#
# - A) Tabs and spaces mixed
# - B) 4 spaces (PEP 8)
# - C) 2 spaces only
# - D) No indentation required
#
# <details>
# <summary>Show Answer</summary>
#
# **Q30. B)** PEP 8 recommends 4 spaces. Mixing tabs and spaces can cause errors.
#
# </details>

# %% [markdown]
# ### Q31. What is `float('inf')`?
#
# - A) Error
# - B) Positive infinity
# - C) 0.0
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q31. B)** float('inf') represents positive infinity in Python.
#
# </details>

# %% [markdown]
# ### Q32. What does `x = y = 5` do?
#
# - A) Error
# - B) Assigns 5 to x and y
# - C) Compares x and y
# - D) Creates a tuple
#
# <details>
# <summary>Show Answer</summary>
#
# **Q32. B)** Chained assignment: both x and y are assigned the value 5.
#
# </details>

# %% [markdown]
# ### Q33. What is `0 or 5`?
#
# - A) 0
# - B) 5
# - C) True
# - D) False
#
# <details>
# <summary>Show Answer</summary>
#
# **Q33. B)** or returns the first truthy value. 0 is falsy, so it returns 5.
#
# </details>

# %% [markdown]
# ### Q34. Which operator checks identity?
#
# - A) ==
# - B) is
# - C) =
# - D) equals
#
# <details>
# <summary>Show Answer</summary>
#
# **Q34. B)** is checks if two variables refer to the same object (identity), not value equality.
#
# </details>

# %% [markdown]
# ### Q35. What does `print(1, 2, 3, sep=',')` output?
#
# - A) 1 2 3
# - B) 1,2,3
# - C) 123
# - D) 1, 2, 3
#
# <details>
# <summary>Show Answer</summary>
#
# **Q35. B)** sep=',' uses comma as separator between items: 1,2,3.
#
# </details>

# %% [markdown]
# ### Q36. What is `complex(1, 2)`?
#
# - A) 3
# - B) 1+2j
# - C) (1, 2)
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q36. B)** complex(real, imag) creates a complex number: 1+2j.
#
# </details>

# %% [markdown]
# ### Q37. Which is a valid way to get user input?
#
# - A) read()
# - B) input()
# - C) get_input()
# - D) scan()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q37. B)** input() is the built-in function for reading user input from stdin.
#
# </details>

# %% [markdown]
# ### Q38. What does `5 in [1, 2, 3, 4, 5]` return?
#
# - A) True
# - B) False
# - C) 5
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q38. A)** in checks membership. 5 is in the list, so it returns True.
#
# </details>

# %% [markdown]
# ### Q39. What is `2 << 1` (left shift)?
#
# - A) 1
# - B) 4
# - C) 3
# - D) 2
#
# <details>
# <summary>Show Answer</summary>
#
# **Q39. B)** Left shift by 1 multiplies by 2. 2 << 1 = 4.
#
# </details>

# %% [markdown]
# ### Q40. What does `round(2.5)` return in Python 3?
#
# - A) 2
# - B) 3
# - C) 2.0
# - D) 2.5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q40. A)** Python 3 uses banker's rounding (round half to even). round(2.5) = 2 because 2 is even.
#
# </details>

# %% [markdown]
# ### Q41. What does `abs(-7)` return?
#
# - A) -7
# - B) 7
# - C) 0
# - D) 7.0
#
# <details>
# <summary>Show Answer</summary>
#
# **Q41. B)** abs() returns the absolute value. abs(-7) = 7.
#
# </details>

# %% [markdown]
# ### Q42. Which creates an empty set?
#
# - A) {}
# - B) set()
# - C) []
# - D) empty_set()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q42. B)** {} creates an empty dict. set() creates an empty set.
#
# </details>

# %% [markdown]
# ### Q43. What is `max(1, 2, 3)`?
#
# - A) 1
# - B) 3
# - C) 6
# - D) [1,2,3]
#
# <details>
# <summary>Show Answer</summary>
#
# **Q43. B)** max() returns the largest argument: 3.
#
# </details>

# %% [markdown]
# ### Q44. What does `divmod(10, 3)` return?
#
# - A) 3.33
# - B) (3, 1)
# - C) 1
# - D) 3
#
# <details>
# <summary>Show Answer</summary>
#
# **Q44. B)** divmod(a, b) returns (a//b, a%b). divmod(10, 3) = (3, 1).
#
# </details>

# %% [markdown]
# ### Q45. What is `pow(2, 3)`?
#
# - A) 6
# - B) 8
# - C) 9
# - D) 5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q45. B)** pow(base, exp) returns base**exp. pow(2, 3) = 8.
#
# </details>

# %% [markdown]
# ### Q46. Which converts to string?
#
# - A) str(42)
# - B) toString(42)
# - C) string(42)
# - D) 42.str()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q46. A)** str() converts objects to their string representation.
#
# </details>

# %% [markdown]
# ### Q47. What does `'a' in 'abc'` return?
#
# - A) True
# - B) False
# - C) 1
# - D) 0
#
# <details>
# <summary>Show Answer</summary>
#
# **Q47. A)** in checks substring membership. 'a' is in 'abc'.
#
# </details>

# %% [markdown]
# ### Q48. What is `(1, 2)[0]`?
#
# - A) 0
# - B) 1
# - C) 2
# - D) (1,)
#
# <details>
# <summary>Show Answer</summary>
#
# **Q48. B)** Indexing: [0] gets the first element, which is 1.
#
# </details>

# %% [markdown]
# ### Q49. What does `not True` evaluate to?
#
# - A) True
# - B) False
# - C) None
# - D) 0
#
# <details>
# <summary>Show Answer</summary>
#
# **Q49. B)** not negates the boolean. not True = False.
#
# </details>

# %% [markdown]
# ### Q50. Which is the membership operator?
#
# - A) in
# - B) contains
# - C) member
# - D) has
#
# <details>
# <summary>Show Answer</summary>
#
# **Q50. A)** in (and not in) are the membership operators.
#
# </details>

# %% [markdown]
# ### Q51. What is `hex(255)`?
#
# - A) 255
# - B) '0xff'
# - C) 0xff
# - D) ff
#
# <details>
# <summary>Show Answer</summary>
#
# **Q51. B)** hex() returns a string representation: '0xff'.
#
# </details>

# %% [markdown]
# ### Q52. What does `ord('A')` return?
#
# - A) 65
# - B) 97
# - C) 'A'
# - D) 1
#
# <details>
# <summary>Show Answer</summary>
#
# **Q52. A)** ord() returns the Unicode code point. ord('A') = 65.
#
# </details>

# %% [markdown]
# ### Q53. What is `chr(97)`?
#
# - A) 97
# - B) 'a'
# - C) a
# - D) 96
#
# <details>
# <summary>Show Answer</summary>
#
# **Q53. B)** chr() returns the character for a Unicode code point. chr(97) = 'a'.
#
# </details>

# %% [markdown]
# ### Q54. What does `len('hello')` return?
#
# - A) 4
# - B) 5
# - C) 6
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q54. B)** len() returns the number of characters. 'hello' has 5 characters.
#
# </details>

# %% [markdown]
# ### Q55. Which is an augmented assignment?
#
# - A) x = x + 1
# - B) x += 1
# - C) x++
# - D) x =+ 1
#
# <details>
# <summary>Show Answer</summary>
#
# **Q55. B)** x += 1 is augmented assignment. Python has no x++.
#
# </details>

# %% [markdown]
# ### Q56. What is `1 and 0`?
#
# - A) 1
# - B) 0
# - C) True
# - D) False
#
# <details>
# <summary>Show Answer</summary>
#
# **Q56. B)** and returns the first falsy value. 1 is truthy, 0 is falsy, so it returns 0.
#
# </details>

# %% [markdown]
# ### Q57. What does `format(42, 'b')` return?
#
# - A) '42'
# - B) '101010'
# - C) 42
# - D) 101010
#
# <details>
# <summary>Show Answer</summary>
#
# **Q57. B)** format(n, 'b') converts to binary string. 42 in binary is 101010.
#
# </details>

# %% [markdown]
# ### Q58. What is `repr('hello')`?
#
# - A) hello
# - B) 'hello'
# - C) hello (no quotes)
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q58. B)** repr() returns a string that would yield an object with the same value. repr('hello') = "'hello'"
#
# </details>

# %% [markdown]
# ### Q59. What does `hash(1)` return?
#
# - A) 1
# - B) An integer hash value
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q59. B)** hash() returns the hash value of an object (an integer).
#
# </details>

# %% [markdown]
# ### Q60. Which built-in gets all attributes?
#
# - A) attrs()
# - B) dir()
# - C) attributes()
# - D) vars()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q60. B)** dir() returns the list of names in the current scope or object's attributes.
#
# </details>

# %% [markdown]
# ### Q61. What is `callable(print)`?
#
# - A) False
# - B) True
# - C) print
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q61. B)** callable() returns True if the object appears callable. print is a function.
#
# </details>

# %% [markdown]
# ### Q62. What does `globals()` return?
#
# - A) List of global names
# - B) Dict of global namespace
# - C) All variables
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q62. B)** globals() returns a dict representing the current global symbol table.
#
# </details>

# %% [markdown]
# ### Q63. What is `locals()`?
#
# - A) List of local names
# - B) Dict of local namespace
# - C) Current function
# - D) Module name
#
# <details>
# <summary>Show Answer</summary>
#
# **Q63. B)** locals() returns a dict of the current local symbol table.
#
# </details>

# %% [markdown]
# ### Q64. What does `__name__` equal when script is run directly?
#
# - A) '__main__'
# - B) 'main'
# - C) None
# - D) ''
#
# <details>
# <summary>Show Answer</summary>
#
# **Q64. A)** When run as main script, __name__ is '__main__'.
#
# </details>

# %% [markdown]
# ### Q65. What is `help(print)`?
#
# - A) Error
# - B) Prints help text for print
# - C) Returns docstring
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q65. B)** help() invokes the built-in help system. It displays help for print.
#
# </details>

# %% [markdown]
# ### Q66. What does `eval('2+3')` return?
#
# - A) '2+3'
# - B) 5
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q66. B)** eval() evaluates a string as a Python expression. eval('2+3') = 5.
#
# </details>

# %% [markdown]
# ### Q67. What is `exec('x=5')`?
#
# - A) Returns 5
# - B) Executes code, returns None
# - C) Error
# - D) Prints 5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q67. B)** exec() executes Python code. It returns None.
#
# </details>

# %% [markdown]
# ### Q68. What does `getattr(obj, 'x', 'default')` do?
#
# - A) Sets obj.x to 'default'
# - B) Gets obj.x or returns 'default' if missing
# - C) Checks if obj has x
# - D) Deletes obj.x
#
# <details>
# <summary>Show Answer</summary>
#
# **Q68. B)** getattr(object, name, default) returns the named attribute or default if not found.
#
# </details>

# %% [markdown]
# ### Q69. What is `hasattr(obj, 'x')`?
#
# - A) Gets obj.x
# - B) True if obj has attribute x
# - C) Sets obj.x
# - D) Deletes obj.x
#
# <details>
# <summary>Show Answer</summary>
#
# **Q69. B)** hasattr(obj, name) returns True if the object has the named attribute.
#
# </details>

# %% [markdown]
# ### Q70. What does `setattr(obj, 'x', 1)` do?
#
# - A) Gets obj.x
# - B) Sets obj.x = 1
# - C) Deletes obj.x
# - D) Checks obj.x
#
# <details>
# <summary>Show Answer</summary>
#
# **Q70. B)** setattr(object, name, value) sets the named attribute.
#
# </details>

# %% [markdown]
# ### Q71. What is `delattr(obj, 'x')`?
#
# - A) Gets obj.x
# - B) Deletes attribute x from obj
# - C) Sets obj.x = None
# - D) Checks obj.x
#
# <details>
# <summary>Show Answer</summary>
#
# **Q71. B)** delattr(object, name) deletes the named attribute.
#
# </details>

# %% [markdown]
# ### Q72. What does `isinstance(x, (int, float))` check?
#
# - A) x is int or float
# - B) x is tuple
# - C) x equals (int, float)
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q72. A)** isinstance() accepts a tuple of types. True if x is instance of any of them.
#
# </details>

# %% [markdown]
# ### Q73. What is `issubclass(bool, int)`?
#
# - A) False
# - B) True
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q73. B)** In Python, bool is a subclass of int. True and False are 1 and 0.
#
# </details>

# %% [markdown]
# ### Q74. What does `super()` do?
#
# - A) Calls parent method
# - B) Returns parent class proxy
# - C) Raises exception
# - D) Imports parent
#
# <details>
# <summary>Show Answer</summary>
#
# **Q74. B)** super() returns a proxy object that delegates to the parent class.
#
# </details>

# %% [markdown]
# ### Q75. What is `object` in Python?
#
# - A) Base class of all classes
# - B) A type
# - C) Built-in only
# - D) Deprecated
#
# <details>
# <summary>Show Answer</summary>
#
# **Q75. A)** object is the base class of all classes in Python 3.
#
# </details>

# %% [markdown]
# ### Q76. What does `type('MyClass', (), {})` create?
#
# - A) String
# - B) A new class dynamically
# - C) Tuple
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q76. B)** type(name, bases, dict) can create a new type/class dynamically.
#
# </details>

# %% [markdown]
# ### Q77. What is `vars()`?
#
# - A) Returns __dict__ of current scope
# - B) Returns all variables
# - C) Returns locals()
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q77. A)** vars() without args returns __dict__ of the current scope (like locals()).
#
# </details>

# %% [markdown]
# ### Q78. What does `breakpoint()` do?
#
# - A) Stops program
# - B) Drops into debugger
# - C) Prints break
# - D) Raises error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q78. B)** breakpoint() calls sys.breakpointhook(), typically starting the debugger.
#
# </details>

# %% [markdown]
# ### Q79. What is `license`?
#
# - A) Function
# - B) String with license text
# - C) Module
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q79. B)** license is a string containing the Python license text.
#
# </details>

# %% [markdown]
# ### Q80. What does `copyright` contain?
#
# - A) Copyright notice
# - B) License
# - C) Version
# - D) Authors
#
# <details>
# <summary>Show Answer</summary>
#
# **Q80. A)** copyright is a string with the copyright notice.
#
# </details>

# %% [markdown]
# ### Q81. What is `__builtins__`?
#
# - A) Module or dict of built-ins
# - B) List of keywords
# - C) Compiler
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q81. A)** __builtins__ is either the builtins module or its __dict__.
#
# </details>

# %% [markdown]
# ### Q82. What does `open` return?
#
# - A) String
# - B) File object/IO object
# - C) Path
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q82. B)** open() returns a file object (or file-like object).
#
# </details>

# %% [markdown]
# ### Q83. What is `sum([1,2,3])`?
#
# - A) 6
# - B) 123
# - C) [1,2,3]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q83. A)** sum() adds all items. sum([1,2,3]) = 6.
#
# </details>

# %% [markdown]
# ### Q84. What does `min([3,1,2])` return?
#
# - A) 3
# - B) 1
# - C) 2
# - D) [1,2,3]
#
# <details>
# <summary>Show Answer</summary>
#
# **Q84. B)** min() returns the smallest item: 1.
#
# </details>

# %% [markdown]
# ### Q85. What is `sorted([3,1,2])`?
#
# - A) [3,1,2]
# - B) [1,2,3]
# - C) (1,2,3)
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q85. B)** sorted() returns a new sorted list: [1, 2, 3].
#
# </details>

# %% [markdown]
# ### Q86. What does `reversed([1,2,3])` return?
#
# - A) [3,2,1]
# - B) list_reverseiterator object
# - C) (3,2,1)
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q86. B)** reversed() returns a reverse iterator, not a list. Use list(reversed(...)) for a list.
#
# </details>

# %% [markdown]
# ### Q87. What is `all([True, True, False])`?
#
# - A) True
# - B) False
# - C) [True, True, False]
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q87. B)** all() returns True only if all elements are truthy. One is False.
#
# </details>

# %% [markdown]
# ### Q88. What does `any([False, False, True])` return?
#
# - A) False
# - B) True
# - C) 3
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q88. B)** any() returns True if any element is truthy.
#
# </details>

# %% [markdown]
# ### Q89. What is `bin(10)`?
#
# - A) 10
# - B) '0b1010'
# - C) 1010
# - D) 0b1010
#
# <details>
# <summary>Show Answer</summary>
#
# **Q89. B)** bin() returns a binary string: '0b1010'.
#
# </details>

# %% [markdown]
# ### Q90. What does `oct(8)` return?
#
# - A) 8
# - B) '0o10'
# - C) 10
# - D) 0o10
#
# <details>
# <summary>Show Answer</summary>
#
# **Q90. B)** oct() returns an octal string: '0o10'.
#
# </details>

# %% [markdown]
# ### Q91. What is `bytes(3)`?
#
# - A) '333'
# - B) b'\x00\x00\x00'
# - C) 3
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q91. B)** bytes(n) creates a bytes object of n zero bytes.
#
# </details>

# %% [markdown]
# ### Q92. What does `bytearray([65,66,67])` produce?
#
# - A) b'ABC'
# - B) bytearray(b'ABC')
# - C) [65,66,67]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q92. B)** bytearray() creates a mutable bytearray. bytearray([65,66,67]) = bytearray(b'ABC').
#
# </details>

# %% [markdown]
# ### Q93. What is `memoryview(b'abc')`?
#
# - A) String
# - B) Memory view object
# - C) Bytes
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q93. B)** memoryview() creates a memory view object for buffer protocol access.
#
# </details>

# %% [markdown]
# ### Q94. What does `slice(1, 5)` create?
#
# - A) [1,2,3,4]
# - B) slice(1, 5, None)
# - C) Range
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q94. B)** slice() creates a slice object used for extended slicing.
#
# </details>

# %% [markdown]
# ### Q95. What is `range(3)`?
#
# - A) [0,1,2]
# - B) range(0, 3) - iterable
# - C) (0,1,2)
# - D) 3
#
# <details>
# <summary>Show Answer</summary>
#
# **Q95. B)** range(3) returns a range object (0, 1, 2), not a list.
#
# </details>

# %% [markdown]
# ### Q96. What does `list(range(2, 5))` produce?
#
# - A) [2, 3, 4]
# - B) [2, 5]
# - C) [2, 3, 4, 5]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q96. A)** range(2, 5) gives 2, 3, 4 (exclusive end).
#
# </details>

# %% [markdown]
# ### Q97. What is `tuple([1,2,3])`?
#
# - A) [1,2,3]
# - B) (1, 2, 3)
# - C) 1, 2, 3
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q97. B)** tuple() converts iterable to tuple. tuple([1,2,3]) = (1, 2, 3).
#
# </details>

# %% [markdown]
# ### Q98. What does `dict(a=1, b=2)` create?
#
# - A) {'a':1, 'b':2}
# - B) ['a','b']
# - C) (1,2)
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q98. A)** dict() with keyword args creates a dict: {'a': 1, 'b': 2}.
#
# </details>

# %% [markdown]
# ### Q99. What is `frozenset([1,2,3])`?
#
# - A) set([1,2,3])
# - B) Immutable set
# - C) frozen list
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q99. B)** frozenset creates an immutable set.
#
# </details>

# %% [markdown]
# ### Q100. What does `enumerate(['a','b'])` return?
#
# - A) [(0,'a'), (1,'b')]
# - B) enumerate object
# - C) ['a','b']
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q100. B)** enumerate() returns an enumerate object (iterator). list() it for [(0,'a'), (1,'b')].
#
# </details>
