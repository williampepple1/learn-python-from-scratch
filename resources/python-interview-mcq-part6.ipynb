# %% [markdown]
# # 🐍 Python Interview MCQ — Part 6: Modules, Packages & Standard Library (Q501–Q600)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q501. What does `__name__ == '__main__'` check?
#
# - A) Script run directly
# - B) Module imported
# - C) Both A and B
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q501. A)** True when script is executed directly, not imported.
#
# </details>

# %% [markdown]
# ### Q502. What is `__init__.py` used for?
#
# - A) Package marker
# - B) Package initialization
# - C) Both A and B
# - D) Module only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q502. C)** Marks directory as package and can run init code.
#
# </details>

# %% [markdown]
# ### Q503. What does `from . import foo` mean?
#
# - A) Absolute import
# - B) Relative import from same package
# - C) Import from parent
# - D) Import from root
#
# <details>
# <summary>Show Answer</summary>
#
# **Q503. B)** Dot means relative import within same package.
#
# </details>

# %% [markdown]
# ### Q504. Where does Python look for modules first?
#
# - A) sys.path
# - B) PYTHONPATH only
# - C) Current dir only
# - D) site-packages only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q504. A)** sys.path lists directories searched for imports.
#
# </details>

# %% [markdown]
# ### Q505. What does `os.path.join('a', 'b', 'c')` return on Windows?
#
# - A) 'a\\b\\c'
# - B) 'a/b/c'
# - C) 'a-b-c'
# - D) Depends on OS
#
# <details>
# <summary>Show Answer</summary>
#
# **Q505. D)** join uses OS-specific separator.
#
# </details>

# %% [markdown]
# ### Q506. What does `sys.argv[0]` contain?
#
# - A) First argument
# - B) Script name
# - C) Python path
# - D) Empty
#
# <details>
# <summary>Show Answer</summary>
#
# **Q506. B)** argv[0] is the script filename.
#
# </details>

# %% [markdown]
# ### Q507. What is `datetime.datetime.now()`?
#
# - A) Current date only
# - B) Current time only
# - C) Current date and time
# - D) UTC time
#
# <details>
# <summary>Show Answer</summary>
#
# **Q507. C)** now() returns current local datetime.
#
# </details>

# %% [markdown]
# ### Q508. What does `math.ceil(2.3)` return?
#
# - A) 2
# - B) 3
# - C) 2.0
# - D) 2.3
#
# <details>
# <summary>Show Answer</summary>
#
# **Q508. B)** ceil rounds up to nearest integer.
#
# </details>

# %% [markdown]
# ### Q509. What does `random.randint(1, 10)` include?
#
# - A) 1 only
# - B) 10 only
# - C) Both 1 and 10
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q509. C)** randint is inclusive on both ends.
#
# </details>

# %% [markdown]
# ### Q510. What is `collections.Counter('aab')`?
#
# - A) Counter({'a': 2, 'b': 1})
# - B) ['a','a','b']
# - C) 3
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q510. A)** Counter counts occurrences of each element.
#
# </details>

# %% [markdown]
# ### Q511. What does `defaultdict(int)` provide?
#
# - A) Default 0 for missing keys
# - B) Default 1
# - C) Raises KeyError
# - D) Returns None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q511. A)** defaultdict(int) uses int() = 0 for missing keys.
#
# </details>

# %% [markdown]
# ### Q512. What is `collections.deque`?
#
# - A) Double-ended queue
# - B) Stack only
# - C) List only
# - D) Set
#
# <details>
# <summary>Show Answer</summary>
#
# **Q512. A)** deque supports O(1) append/pop from both ends.
#
# </details>

# %% [markdown]
# ### Q513. What does `pathlib.Path('a/b').parent` return?
#
# - A) Path('a')
# - B) Path('a/b')
# - C) Path('.')
# - D) 'a'
#
# <details>
# <summary>Show Answer</summary>
#
# **Q513. A)** parent is the directory containing the path.
#
# </details>

# %% [markdown]
# ### Q514. What does `shutil.copy(src, dst)` do?
#
# - A) Copy file
# - B) Copy directory
# - C) Move file
# - D) Delete file
#
# <details>
# <summary>Show Answer</summary>
#
# **Q514. A)** shutil.copy copies a single file.
#
# </details>

# %% [markdown]
# ### Q515. What does `subprocess.run(['ls'])` return?
#
# - A) Output string
# - B) CompletedProcess
# - C) None
# - D) Exit code only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q515. B)** run() returns CompletedProcess instance.
#
# </details>

# %% [markdown]
# ### Q516. What is `venv` used for?
#
# - A) Virtual environment
# - B) Version control
# - C) Package manager
# - D) IDE
#
# <details>
# <summary>Show Answer</summary>
#
# **Q516. A)** venv creates isolated Python environments.
#
# </details>

# %% [markdown]
# ### Q517. What does `pip install -e .` do?
#
# - A) Editable install
# - B) Upgrade package
# - C) Uninstall
# - D) List packages
#
# <details>
# <summary>Show Answer</summary>
#
# **Q517. A)** Editable mode links to source for development.
#
# </details>

# %% [markdown]
# ### Q518. What is PyPI?
#
# - A) Python Package Index
# - B) Package installer
# - C) Virtual env
# - D) IDE
#
# <details>
# <summary>Show Answer</summary>
#
# **Q518. A)** PyPI is the default package repository.
#
# </details>

# %% [markdown]
# ### Q519. What does `import x as y` do?
#
# - A) Import x with alias y
# - B) Import y as x
# - C) Import both
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q519. A)** Binds imported module to name y.
#
# </details>

# %% [markdown]
# ### Q520. What is `sys.modules`?
#
# - A) Dict of loaded modules
# - B) List of paths
# - C) Module names
# - D) Import cache
#
# <details>
# <summary>Show Answer</summary>
#
# **Q520. A)** sys.modules maps module names to loaded modules.
#
# </details>

# %% [markdown]
# ### Q521. What does `os.environ.get('HOME')` return?
#
# - A) Current directory
# - B) Home directory path
# - C) Username
# - D) Always None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q521. B)** HOME env var contains user home path.
#
# </details>

# %% [markdown]
# ### Q522. What is `sys.exit(1)`?
#
# - A) Exit with code 1
# - B) Raise SystemExit
# - C) Both A and B
# - D) Pause program
#
# <details>
# <summary>Show Answer</summary>
#
# **Q522. C)** Raises SystemExit, non-zero indicates error.
#
# </details>

# %% [markdown]
# ### Q523. What does `datetime.timedelta(days=1)` represent?
#
# - A) 1 day duration
# - B) Current date
# - C) Tomorrow
# - D) Yesterday
#
# <details>
# <summary>Show Answer</summary>
#
# **Q523. A)** timedelta represents a duration.
#
# </details>

# %% [markdown]
# ### Q524. What is `math.isnan(x)` for?
#
# - A) Check if x is NaN
# - B) Convert to int
# - C) Round
# - D) Absolute value
#
# <details>
# <summary>Show Answer</summary>
#
# **Q524. A)** isnan returns True for NaN values.
#
# </details>

# %% [markdown]
# ### Q525. What does `random.choice([1,2,3])` return?
#
# - A) List
# - B) One element
# - C) Shuffled list
# - D) Index
#
# <details>
# <summary>Show Answer</summary>
#
# **Q525. B)** choice returns one random element.
#
# </details>

# %% [markdown]
# ### Q526. What is `OrderedDict` (Python 3.7+)?
#
# - A) dict preserves order
# - B) OrderedDict redundant
# - C) Both A and B
# - D) Only for sorting
#
# <details>
# <summary>Show Answer</summary>
#
# **Q526. C)** Regular dict is ordered since 3.7; OrderedDict still has extra methods.
#
# </details>

# %% [markdown]
# ### Q527. What does `Path('file.txt').exists()` return?
#
# - A) True if file exists
# - B) Always True
# - C) File content
# - D) Path object
#
# <details>
# <summary>Show Answer</summary>
#
# **Q527. A)** exists() checks if path exists on filesystem.
#
# </details>

# %% [markdown]
# ### Q528. What does `shutil.rmtree(path)` do?
#
# - A) Remove directory tree
# - B) Remove single file
# - C) Rename
# - D) Copy
#
# <details>
# <summary>Show Answer</summary>
#
# **Q528. A)** rmtree recursively deletes directory.
#
# </details>

# %% [markdown]
# ### Q529. What does `subprocess.run(..., capture_output=True)` do?
#
# - A) Capture stdout/stderr
# - B) Run in background
# - C) Pipe only
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q529. A)** capture_output=True captures output.
#
# </details>

# %% [markdown]
# ### Q530. What is `pip freeze`?
#
# - A) List installed packages
# - B) Stop pip
# - C) Install frozen
# - D) Upgrade all
#
# <details>
# <summary>Show Answer</summary>
#
# **Q530. A)** freeze outputs installed packages with versions.
#
# </details>

# %% [markdown]
# ### Q531. What does `from package import *` import?
#
# - A) All from __all__ or all public
# - B) Nothing
# - C) Only __init__
# - D) Private names
#
# <details>
# <summary>Show Answer</summary>
#
# **Q531. A)** Imports names in __all__ or non-underscore names.
#
# </details>

# %% [markdown]
# ### Q532. What is `__file__` in a module?
#
# - A) Path to module file
# - B) Filename only
# - C) Import path
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q532. A)** __file__ is the path of the current module.
#
# </details>

# %% [markdown]
# ### Q533. What does `os.getcwd()` return?
#
# - A) Current working directory
# - B) Script directory
# - C) Home directory
# - D) Temp directory
#
# <details>
# <summary>Show Answer</summary>
#
# **Q533. A)** getcwd returns current working directory.
#
# </details>

# %% [markdown]
# ### Q534. What does `sys.stdin` represent?
#
# - A) Standard input stream
# - B) File handle
# - C) Both A and B
# - D) Keyboard only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q534. C)** stdin is the standard input file object.
#
# </details>

# %% [markdown]
# ### Q535. What is `datetime.strptime('2024-01-15', '%Y-%m-%d')`?
#
# - A) Parse string to datetime
# - B) Format datetime
# - C) Current date
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q535. A)** strptime parses string to datetime.
#
# </details>

# %% [markdown]
# ### Q536. What does `math.inf` represent?
#
# - A) Positive infinity
# - B) Negative infinity
# - C) NaN
# - D) Max float
#
# <details>
# <summary>Show Answer</summary>
#
# **Q536. A)** math.inf is positive infinity.
#
# </details>

# %% [markdown]
# ### Q537. What does `random.shuffle(lst)` return?
#
# - A) Shuffled list
# - B) None
# - C) Original list
# - D) New list
#
# <details>
# <summary>Show Answer</summary>
#
# **Q537. B)** shuffle mutates in place, returns None.
#
# </details>

# %% [markdown]
# ### Q538. What is `Counter.most_common(2)`?
#
# - A) Top 2 most frequent
# - B) First 2 elements
# - C) Last 2
# - D) 2 random
#
# <details>
# <summary>Show Answer</summary>
#
# **Q538. A)** most_common(n) returns n most common.
#
# </details>

# %% [markdown]
# ### Q539. What does `defaultdict(list)` use for missing keys?
#
# - A) []
# - B) None
# - C) {}
# - D) Raises KeyError
#
# <details>
# <summary>Show Answer</summary>
#
# **Q539. A)** defaultdict(list) uses list() = [] for missing keys.
#
# </details>

# %% [markdown]
# ### Q540. What is `deque.popleft()`?
#
# - A) Remove from left
# - B) Remove from right
# - C) Peek left
# - D) Add left
#
# <details>
# <summary>Show Answer</summary>
#
# **Q540. A)** popleft removes and returns leftmost element.
#
# </details>

# %% [markdown]
# ### Q541. What does `Path('a/b/c.txt').suffix` return?
#
# - A) '.txt'
# - B) 'c.txt'
# - C) 'txt'
# - D) 'a/b'
#
# <details>
# <summary>Show Answer</summary>
#
# **Q541. A)** suffix is the file extension including dot.
#
# </details>

# %% [markdown]
# ### Q542. What does `shutil.move(src, dst)` do?
#
# - A) Move file/dir
# - B) Copy only
# - C) Rename only
# - D) Delete
#
# <details>
# <summary>Show Answer</summary>
#
# **Q542. A)** move can rename or relocate.
#
# </details>

# %% [markdown]
# ### Q543. What does `subprocess.Popen` return?
#
# - A) Process object
# - B) Output
# - C) Exit code
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q543. A)** Popen returns Popen instance for async control.
#
# </details>

# %% [markdown]
# ### Q544. What is `python -m venv myenv`?
#
# - A) Create venv named myenv
# - B) Activate venv
# - C) Delete venv
# - D) List venvs
#
# <details>
# <summary>Show Answer</summary>
#
# **Q544. A)** Creates virtual environment in myenv/.
#
# </details>

# %% [markdown]
# ### Q545. What does `pip install package==1.0.0` do?
#
# - A) Install exact version
# - B) Upgrade to latest
# - C) Uninstall
# - D) Check version
#
# <details>
# <summary>Show Answer</summary>
#
# **Q545. A)** == pins to exact version.
#
# </details>

# %% [markdown]
# ### Q546. What is `importlib.import_module(name)`?
#
# - A) Dynamic import
# - B) Reload module
# - C) List modules
# - D) Import path
#
# <details>
# <summary>Show Answer</summary>
#
# **Q546. A)** Dynamically imports module by string name.
#
# </details>

# %% [markdown]
# ### Q547. What does `os.path.abspath('x')` return?
#
# - A) Absolute path
# - B) Relative path
# - C) Resolved path
# - D) Canonical path
#
# <details>
# <summary>Show Answer</summary>
#
# **Q547. A)** abspath converts to absolute path.
#
# </details>

# %% [markdown]
# ### Q548. What does `sys.getsizeof(x)` return?
#
# - A) Object size in bytes
# - B) Length
# - C) Memory address
# - D) Type size
#
# <details>
# <summary>Show Answer</summary>
#
# **Q548. A)** getsizeof returns approximate size in bytes.
#
# </details>

# %% [markdown]
# ### Q549. What is `datetime.timezone.utc`?
#
# - A) UTC timezone
# - B) Local timezone
# - C) Offset only
# - D) DST info
#
# <details>
# <summary>Show Answer</summary>
#
# **Q549. A)** Represents UTC timezone.
#
# </details>

# %% [markdown]
# ### Q550. What does `math.gcd(12, 8)` return?
#
# - A) 4
# - B) 2
# - C) 96
# - D) 20
#
# <details>
# <summary>Show Answer</summary>
#
# **Q550. A)** gcd returns greatest common divisor.
#
# </details>

# %% [markdown]
# ### Q551. What does `random.sample([1,2,3], 2)` return?
#
# - A) 2 unique elements
# - B) 2 with replacement
# - C) List of 2 lists
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q551. A)** sample returns k unique elements.
#
# </details>

# %% [markdown]
# ### Q552. What is `Counter + Counter`?
#
# - A) Add counts
# - B) Merge keys
# - C) Error
# - D) Union
#
# <details>
# <summary>Show Answer</summary>
#
# **Q552. A)** Adding Counters sums counts per key.
#
# </details>

# %% [markdown]
# ### Q553. What does `defaultdict(lambda: 'default')` use?
#
# - A) 'default' for missing
# - B) None
# - C) Raises
# - D) 0
#
# <details>
# <summary>Show Answer</summary>
#
# **Q553. A)** lambda provides custom default factory.
#
# </details>

# %% [markdown]
# ### Q554. What is `deque(maxlen=3)`?
#
# - A) Bounded deque
# - B) Min length 3
# - C) Fixed size 3
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q554. A)** maxlen limits size; oldest dropped when full.
#
# </details>

# %% [markdown]
# ### Q555. What does `Path.iterdir()` return?
#
# - A) Iterator of paths
# - B) List of names
# - C) Single path
# - D) Generator
#
# <details>
# <summary>Show Answer</summary>
#
# **Q555. A)** iterdir yields child paths.
#
# </details>

# %% [markdown]
# ### Q556. What does `shutil.copytree(src, dst)` do?
#
# - A) Copy directory tree
# - B) Copy one file
# - C) Move tree
# - D) Merge trees
#
# <details>
# <summary>Show Answer</summary>
#
# **Q556. A)** copytree recursively copies directory.
#
# </details>

# %% [markdown]
# ### Q557. What does `subprocess.run(..., check=True)` do on non-zero exit?
#
# - A) Raise CalledProcessError
# - B) Return anyway
# - C) Retry
# - D) Ignore
#
# <details>
# <summary>Show Answer</summary>
#
# **Q557. A)** check=True raises on non-zero exit.
#
# </details>

# %% [markdown]
# ### Q558. What is `pip list`?
#
# - A) List installed packages
# - B) List available
# - C) List requirements
# - D) List versions
#
# <details>
# <summary>Show Answer</summary>
#
# **Q558. A)** list shows installed packages.
#
# </details>

# %% [markdown]
# ### Q559. What does `from .submodule import x` mean?
#
# - A) Relative import from submodule
# - B) Absolute import
# - C) Import parent
# - D) Import x from current
#
# <details>
# <summary>Show Answer</summary>
#
# **Q559. A)** Imports x from submodule in same package.
#
# </details>

# %% [markdown]
# ### Q560. What is `__package__`?
#
# - A) Package name of module
# - B) Import path
# - C) Both
# - D) Package dir
#
# <details>
# <summary>Show Answer</summary>
#
# **Q560. A)** __package__ is the package name.
#
# </details>

# %% [markdown]
# ### Q561. What does `os.listdir('.')` return?
#
# - A) List of names in dir
# - B) List of paths
# - C) Iterator
# - D) Single name
#
# <details>
# <summary>Show Answer</summary>
#
# **Q561. A)** listdir returns names (not full paths).
#
# </details>

# %% [markdown]
# ### Q562. What does `sys.version` contain?
#
# - A) Python version string
# - B) Version number only
# - C) Build info
# - D) All of above
#
# <details>
# <summary>Show Answer</summary>
#
# **Q562. A)** version is full version string.
#
# </details>

# %% [markdown]
# ### Q563. What is `datetime.datetime.utcnow()`?
#
# - A) Deprecated, use datetime.now(timezone.utc)
# - B) Current UTC
# - C) Both
# - D) Local time
#
# <details>
# <summary>Show Answer</summary>
#
# **Q563. C)** utcnow is deprecated; use timezone-aware.
#
# </details>

# %% [markdown]
# ### Q564. What does `math.sqrt(-1)` return?
#
# - A) ValueError
# - B) NaN
# - C) 0
# - D) 1j
#
# <details>
# <summary>Show Answer</summary>
#
# **Q564. B)** sqrt of negative returns float NaN.
#
# </details>

# %% [markdown]
# ### Q565. What does `random.seed(42)` do?
#
# - A) Reproducible randomness
# - B) Set max random
# - C) Initialize only once
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q565. A)** seed makes random sequence reproducible.
#
# </details>

# %% [markdown]
# ### Q566. What is `Counter.elements()`?
#
# - A) Iterator over elements by count
# - B) List of keys
# - C) Sum of counts
# - D) Unique elements
#
# <details>
# <summary>Show Answer</summary>
#
# **Q566. A)** elements() yields each element count times.
#
# </details>

# %% [markdown]
# ### Q567. What does `defaultdict(set)` use for missing keys?
#
# - A) set()
# - B) {}
# - C) None
# - D) []
#
# <details>
# <summary>Show Answer</summary>
#
# **Q567. A)** set() creates empty set.
#
# </details>

# %% [markdown]
# ### Q568. What is `deque.rotate(1)`?
#
# - A) Rotate right by 1
# - B) Rotate left
# - C) Sort
# - D) Reverse
#
# <details>
# <summary>Show Answer</summary>
#
# **Q568. A)** rotate(1) moves last to first.
#
# </details>

# %% [markdown]
# ### Q569. What does `Path.read_text()` return?
#
# - A) File content as str
# - B) Bytes
# - C) Lines list
# - D) File object
#
# <details>
# <summary>Show Answer</summary>
#
# **Q569. A)** read_text reads and decodes to string.
#
# </details>

# %% [markdown]
# ### Q570. What does `os.path.exists(path)` return?
#
# - A) True if path exists
# - B) Always bool
# - C) Both
# - D) Path object
#
# <details>
# <summary>Show Answer</summary>
#
# **Q570. C)** Returns True/False for existence.
#
# </details>

# %% [markdown]
# ### Q571. What does `sys.platform` contain?
#
# - A) OS identifier
# - B) Python version
# - C) Architecture
# - D) Compiler
#
# <details>
# <summary>Show Answer</summary>
#
# **Q571. A)** e.g. 'win32', 'linux', 'darwin'.
#
# </details>

# %% [markdown]
# ### Q572. What is `datetime.date.today()`?
#
# - A) Current date
# - B) Current datetime
# - C) Date string
# - D) Timestamp
#
# <details>
# <summary>Show Answer</summary>
#
# **Q572. A)** today() returns current date object.
#
# </details>

# %% [markdown]
# ### Q573. What does `math.floor(-2.3)` return?
#
# - A) -2
# - B) -3
# - C) -2.0
# - D) 2
#
# <details>
# <summary>Show Answer</summary>
#
# **Q573. B)** floor rounds down (toward -inf).
#
# </details>

# %% [markdown]
# ### Q574. What does `random.random()` return?
#
# - A) Float in [0, 1)
# - B) Int 0 or 1
# - C) Float in (0, 1]
# - D) Any float
#
# <details>
# <summary>Show Answer</summary>
#
# **Q574. A)** random() returns float in [0, 1).
#
# </details>

# %% [markdown]
# ### Q575. What is `collections.namedtuple`?
#
# - A) Tuple with named fields
# - B) Dict-like tuple
# - C) Both
# - D) Ordered dict
#
# <details>
# <summary>Show Answer</summary>
#
# **Q575. A)** namedtuple adds field names to tuple.
#
# </details>

# %% [markdown]
# ### Q576. What does `Path.glob('*.py')` return?
#
# - A) Iterator of matching paths
# - B) List
# - C) Single path
# - D) Bool
#
# <details>
# <summary>Show Answer</summary>
#
# **Q576. A)** glob yields paths matching pattern.
#
# </details>

# %% [markdown]
# ### Q577. What does `os.makedirs('a/b/c', exist_ok=True)` do?
#
# - A) Create dirs, no error if exists
# - B) Create only if not exists
# - C) Replace existing
# - D) Create single dir
#
# <details>
# <summary>Show Answer</summary>
#
# **Q577. A)** exist_ok=True avoids FileExistsError.
#
# </details>

# %% [markdown]
# ### Q578. What does `sys.executable` contain?
#
# - A) Python interpreter path
# - B) Script path
# - C) Module path
# - D) venv path
#
# <details>
# <summary>Show Answer</summary>
#
# **Q578. A)** Path to python executable.
#
# </details>

# %% [markdown]
# ### Q579. What is `datetime.timedelta.total_seconds()`?
#
# - A) Total seconds as float
# - B) Seconds component only
# - C) Days only
# - D) Integer seconds
#
# <details>
# <summary>Show Answer</summary>
#
# **Q579. A)** total_seconds returns duration in seconds.
#
# </details>

# %% [markdown]
# ### Q580. What does `math.pow(2, 3)` return?
#
# - A) 8.0
# - B) 8
# - C) 6
# - D) 9
#
# <details>
# <summary>Show Answer</summary>
#
# **Q580. A)** pow returns float (2**3 = 8.0).
#
# </details>

# %% [markdown]
# ### Q581. What does `random.uniform(1, 10)` return?
#
# - A) Float in [1, 10]
# - B) Int in [1, 10]
# - C) Float in (1, 10)
# - D) Always 5.5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q581. A)** uniform returns float in inclusive range.
#
# </details>

# %% [markdown]
# ### Q582. What is `collections.ChainMap`?
#
# - A) Dict-like view of multiple dicts
# - B) Chained list
# - C) Linked dict
# - D) Merge dicts
#
# <details>
# <summary>Show Answer</summary>
#
# **Q582. A)** ChainMap looks up in multiple dicts.
#
# </details>

# %% [markdown]
# ### Q583. What does `Path.write_text('hello')` do?
#
# - A) Write string to file
# - B) Append
# - C) Read first
# - D) Create dir only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q583. A)** write_text writes string, overwrites.
#
# </details>

# %% [markdown]
# ### Q584. What does `os.path.basename('/a/b/c.txt')` return?
#
# - A) 'c.txt'
# - B) '/a/b'
# - C) 'c'
# - D) 'a'
#
# <details>
# <summary>Show Answer</summary>
#
# **Q584. A)** basename is the final component.
#
# </details>

# %% [markdown]
# ### Q585. What does `sys.getrecursionlimit()` return?
#
# - A) Max recursion depth
# - B) Stack size
# - C) Call limit
# - D) Default 1000
#
# <details>
# <summary>Show Answer</summary>
#
# **Q585. A)** Default is typically 1000.
#
# </details>

# %% [markdown]
# ### Q586. What is `datetime.datetime.fromtimestamp(0)`?
#
# - A) Epoch in local time
# - B) Epoch in UTC
# - C) Current time
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q586. A)** fromtimestamp uses local timezone.
#
# </details>

# %% [markdown]
# ### Q587. What does `math.factorial(5)` return?
#
# - A) 120
# - B) 5
# - C) 15
# - D) 25
#
# <details>
# <summary>Show Answer</summary>
#
# **Q587. A)** 5! = 5*4*3*2*1 = 120.
#
# </details>

# %% [markdown]
# ### Q588. What does `random.getrandbits(8)` return?
#
# - A) Int with 8 random bits
# - B) Byte
# - C) Float
# - D) 8 random ints
#
# <details>
# <summary>Show Answer</summary>
#
# **Q588. A)** Returns int with k random bits.
#
# </details>

# %% [markdown]
# ### Q589. What is `collections.UserDict`?
#
# - A) Base for dict subclasses
# - B) User-defined dict
# - C) Both
# - D) Custom key type
#
# <details>
# <summary>Show Answer</summary>
#
# **Q589. A)** UserDict simplifies dict subclassing.
#
# </details>

# %% [markdown]
# ### Q590. What does `Path.mkdir(parents=True)` do?
#
# - A) Create parent dirs too
# - B) Create only parents
# - C) Ignore existing
# - D) Create single dir
#
# <details>
# <summary>Show Answer</summary>
#
# **Q590. A)** parents=True creates intermediate dirs.
#
# </details>

# %% [markdown]
# ### Q591. What does `os.chdir(path)` do?
#
# - A) Change current directory
# - B) Create directory
# - C) Check directory
# - D) List directory
#
# <details>
# <summary>Show Answer</summary>
#
# **Q591. A)** chdir changes cwd.
#
# </details>

# %% [markdown]
# ### Q592. What does `sys.getdefaultencoding()` return?
#
# - A) 'utf-8'
# - B) 'ascii'
# - C) Platform-dependent
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q592. A)** Default is utf-8 in Python 3.
#
# </details>

# %% [markdown]
# ### Q593. What is `datetime.datetime.combine(date, time)`?
#
# - A) Combine date and time
# - B) Split datetime
# - C) Compare
# - D) Format
#
# <details>
# <summary>Show Answer</summary>
#
# **Q593. A)** Creates datetime from date and time.
#
# </details>

# %% [markdown]
# ### Q594. What does `math.copysign(5, -1)` return?
#
# - A) -5.0
# - B) 5.0
# - C) -1
# - D) 5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q594. A)** copysign uses magnitude of first, sign of second.
#
# </details>

# %% [markdown]
# ### Q595. What does `random.gauss(0, 1)` return?
#
# - A) Gaussian random
# - B) Uniform
# - C) Integer
# - D) List
#
# <details>
# <summary>Show Answer</summary>
#
# **Q595. A)** gauss returns normal distribution sample.
#
# </details>

# %% [markdown]
# ### Q596. What is `functools.lru_cache`?
#
# - A) Memoization decorator
# - B) Cache module
# - C) LRU list
# - D) Memory cache
#
# <details>
# <summary>Show Answer</summary>
#
# **Q596. A)** lru_cache caches function results.
#
# </details>

# %% [markdown]
# ### Q597. What does `Path.resolve()` return?
#
# - A) Absolute resolved path
# - B) Relative path
# - C) Symlink target
# - D) String
#
# <details>
# <summary>Show Answer</summary>
#
# **Q597. A)** resolve() returns absolute path, resolving symlinks.
#
# </details>

# %% [markdown]
# ### Q598. What does `os.path.isfile(path)` return?
#
# - A) True if regular file
# - B) True if exists
# - C) File size
# - D) Extension
#
# <details>
# <summary>Show Answer</summary>
#
# **Q598. A)** isfile checks if path is regular file.
#
# </details>

# %% [markdown]
# ### Q599. What does `sys.path.insert(0, dir)` do?
#
# - A) Prepend dir to search path
# - B) Append dir
# - C) Replace path
# - D) Remove dir
#
# <details>
# <summary>Show Answer</summary>
#
# **Q599. A)** insert(0,...) adds at front of sys.path.
#
# </details>

# %% [markdown]
# ### Q600. What is `datetime.timezone(datetime.timedelta(hours=-5))`?
#
# - A) Fixed offset timezone
# - B) UTC
# - C) Local
# - D) DST-aware
#
# <details>
# <summary>Show Answer</summary>
#
# **Q600. A)** Fixed offset from UTC (e.g. EST).
#
# </details>
