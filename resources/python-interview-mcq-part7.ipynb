# %% [markdown]
# # 🐍 Python Interview MCQ — Part 7: Decorators, Generators & Metaprogramming (Q601–Q700)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q601. What does a decorator do?
#
# - A) Wrap/modify function
# - B) Delete function
# - C) Import function
# - D) Call function
#
# <details>
# <summary>Show Answer</summary>
#
# **Q601. A)** Decorator wraps and can modify function behavior.
#
# </details>

# %% [markdown]
# ### Q602. What does `functools.wraps(f)` preserve?
#
# - A) Original metadata
# - B) Function body
# - C) Return value
# - D) Arguments
#
# <details>
# <summary>Show Answer</summary>
#
# **Q602. A)** wraps copies __name__, __doc__, etc.
#
# </details>

# %% [markdown]
# ### Q603. What does `@property` create?
#
# - A) Getter for attribute
# - B) Setter only
# - C) Both getter and optional setter
# - D) Class method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q603. C)** property defines getter; setter/deleter optional.
#
# </details>

# %% [markdown]
# ### Q604. What is a descriptor?
#
# - A) Object with __get__/__set__/__delete__
# - B) Decorator
# - C) Property only
# - D) Method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q604. A)** Descriptor protocol: __get__, __set__, __delete__.
#
# </details>

# %% [markdown]
# ### Q605. What does `type()` with 3 args create?
#
# - A) New class dynamically
# - B) Instance
# - C) Type object
# - D) Metaclass
#
# <details>
# <summary>Show Answer</summary>
#
# **Q605. A)** type(name, bases, dict) creates a class.
#
# </details>

# %% [markdown]
# ### Q606. What is `__new__` vs `__init__`?
#
# - A) __new__ creates, __init__ initializes
# - B) Same thing
# - C) __init__ first
# - D) Only __init__ needed
#
# <details>
# <summary>Show Answer</summary>
#
# **Q606. A)** __new__ creates object; __init__ sets up.
#
# </details>

# %% [markdown]
# ### Q607. What does `__slots__` do?
#
# - A) Restrict instance attributes
# - B) Add attributes
# - C) Create slots
# - D) Reserve memory
#
# <details>
# <summary>Show Answer</summary>
#
# **Q607. A)** __slots__ limits allowed attributes, saves memory.
#
# </details>

# %% [markdown]
# ### Q608. What does `yield` do in a function?
#
# - A) Pause and return value
# - B) Return and stop
# - C) Raise exception
# - D) Break loop
#
# <details>
# <summary>Show Answer</summary>
#
# **Q608. A)** yield makes generator; pauses and yields value.
#
# </details>

# %% [markdown]
# ### Q609. What does `generator.send(x)` do?
#
# - A) Send value into yield
# - B) Send to next
# - C) Both
# - D) Raise error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q609. A)** send() passes value to yield expression.
#
# </details>

# %% [markdown]
# ### Q610. What does `generator.throw(exc)` do?
#
# - A) Raise exception in generator
# - B) Catch exception
# - C) Return exception
# - D) Ignore
#
# <details>
# <summary>Show Answer</summary>
#
# **Q610. A)** throw raises exception at yield point.
#
# </details>

# %% [markdown]
# ### Q611. What is `(x**2 for x in range(5))`?
#
# - A) Generator expression
# - B) List
# - C) Tuple
# - D) Set
#
# <details>
# <summary>Show Answer</summary>
#
# **Q611. A)** Parentheses create generator expression.
#
# </details>

# %% [markdown]
# ### Q612. What is `abc.ABC`?
#
# - A) Abstract base class
# - B) Abstract method
# - C) Base class only
# - D) Interface
#
# <details>
# <summary>Show Answer</summary>
#
# **Q612. A)** ABC is base for abstract classes.
#
# </details>

# %% [markdown]
# ### Q613. What does `__init_subclass__` do?
#
# - A) Hook when subclass is created
# - B) Initialize subclass
# - C) Call super
# - D) Register class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q613. A)** Called when class is subclassed.
#
# </details>

# %% [markdown]
# ### Q614. What is `__class_getitem__`?
#
# - A) Support cls[int]
# - B) Get class item
# - C) Generic type
# - D) Index class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q614. A)** Enables Class[int] syntax for generics.
#
# </details>

# %% [markdown]
# ### Q615. What does a decorator with args look like?
#
# - A) @decorator(arg)
# - B) @decorator
# - C) Both
# - D) decorator()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q615. A)** decorator(arg) returns actual decorator.
#
# </details>

# %% [markdown]
# ### Q616. What does `@staticmethod` do?
#
# - A) No self/cls
# - B) Class method
# - C) Instance only
# - D) Abstract
#
# <details>
# <summary>Show Answer</summary>
#
# **Q616. A)** staticmethod receives no implicit first arg.
#
# </details>

# %% [markdown]
# ### Q617. What is `__get__` in a descriptor?
#
# - A) Called on attribute access
# - B) Getter method
# - C) Both
# - D) Property
#
# <details>
# <summary>Show Answer</summary>
#
# **Q617. A)** __get__(self, instance, owner) on access.
#
# </details>

# %% [markdown]
# ### Q618. What is a metaclass?
#
# - A) Class of a class
# - B) Base class
# - C) Super class
# - D) Abstract class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q618. A)** Metaclass creates classes; type is default.
#
# </details>

# %% [markdown]
# ### Q619. What does `object.__new__(cls)` do?
#
# - A) Create instance
# - B) Initialize
# - C) Both
# - D) Return cls
#
# <details>
# <summary>Show Answer</summary>
#
# **Q619. A)** __new__ creates and returns new instance.
#
# </details>

# %% [markdown]
# ### Q620. What does `__slots__ = ['x']` prevent?
#
# - A) Adding other attributes
# - B) Using x
# - C) Inheritance
# - D) Methods
#
# <details>
# <summary>Show Answer</summary>
#
# **Q620. A)** Only x (and __dict__-like) allowed.
#
# </details>

# %% [markdown]
# ### Q621. What does a generator return?
#
# - A) Generator iterator
# - B) First value
# - C) List
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q621. A)** Generator function returns generator object.
#
# </details>

# %% [markdown]
# ### Q622. What does `next(gen)` do?
#
# - A) Advance to next yield
# - B) Get first only
# - C) Reset generator
# - D) Close generator
#
# <details>
# <summary>Show Answer</summary>
#
# **Q622. A)** next() advances to next yield.
#
# </details>

# %% [markdown]
# ### Q623. What is a coroutine?
#
# - A) async def function
# - B) Generator with send
# - C) Both
# - D) Thread
#
# <details>
# <summary>Show Answer</summary>
#
# **Q623. C)** async def creates coroutine; generators can emulate.
#
# </details>

# %% [markdown]
# ### Q624. What does `@abstractmethod` do?
#
# - A) Must override in subclass
# - B) Cannot call
# - C) Both
# - D) Optional override
#
# <details>
# <summary>Show Answer</summary>
#
# **Q624. A)** Abstract method must be implemented.
#
# </details>

# %% [markdown]
# ### Q625. What does `__init_subclass__(cls)` receive?
#
# - A) The new subclass
# - B) Parent class
# - C) Instance
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q625. A)** cls is the newly defined subclass.
#
# </details>

# %% [markdown]
# ### Q626. What does `list[int]` use?
#
# - A) __class_getitem__
# - B) __getitem__
# - C) __subscript__
# - D) Generic
#
# <details>
# <summary>Show Answer</summary>
#
# **Q626. A)** __class_getitem__ enables Class[args].
#
# </details>

# %% [markdown]
# ### Q627. What does `def dec(f): return f` do?
#
# - A) No-op decorator
# - B) Replace function
# - C) Delete function
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q627. A)** Returns same function unchanged.
#
# </details>

# %% [markdown]
# ### Q628. What does `@classmethod` receive as first arg?
#
# - A) cls
# - B) self
# - C) class
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q628. A)** classmethod gets class as first argument.
#
# </details>

# %% [markdown]
# ### Q629. What is `__set__` in a descriptor?
#
# - A) Called on assignment
# - B) Setter
# - C) Both
# - D) Property setter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q629. A)** __set__(self, instance, value) on assignment.
#
# </details>

# %% [markdown]
# ### Q630. What does `type.__new__` create?
#
# - A) New class
# - B) Instance
# - C) Metaclass
# - D) Object
#
# <details>
# <summary>Show Answer</summary>
#
# **Q630. A)** Metaclass __new__ creates the class object.
#
# </details>

# %% [markdown]
# ### Q631. When is `__new__` called?
#
# - A) Before __init__
# - B) After __init__
# - C) Instead of __init__
# - D) Never
#
# <details>
# <summary>Show Answer</summary>
#
# **Q631. A)** __new__ creates object; __init__ initializes it.
#
# </details>

# %% [markdown]
# ### Q632. What does `__slots__` save?
#
# - A) Memory
# - B) Speed
# - C) Both
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q632. C)** No __dict__ per instance saves memory.
#
# </details>

# %% [markdown]
# ### Q633. What does `yield from iter` do?
#
# - A) Delegate to sub-generator
# - B) Yield iter
# - C) Flatten
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q633. A)** yield from delegates to another generator.
#
# </details>

# %% [markdown]
# ### Q634. What does `gen.close()` do?
#
# - A) Raise GeneratorExit
# - B) Delete generator
# - C) Return None
# - D) Pause
#
# <details>
# <summary>Show Answer</summary>
#
# **Q634. A)** close() raises GeneratorExit in generator.
#
# </details>

# %% [markdown]
# ### Q635. What is `async def`?
#
# - A) Coroutine function
# - B) Generator
# - C) Thread
# - D) Process
#
# <details>
# <summary>Show Answer</summary>
#
# **Q635. A)** async def defines coroutine function.
#
# </details>

# %% [markdown]
# ### Q636. What does `ABC` prevent?
#
# - A) Instantiating with unimplemented abstract methods
# - B) Subclassing
# - C) Importing
# - D) Inheritance
#
# <details>
# <summary>Show Answer</summary>
#
# **Q636. A)** Cannot instantiate until abstract methods implemented.
#
# </details>

# %% [markdown]
# ### Q637. What does `__init_subclass__` replace?
#
# - A) Metaclass for simple cases
# - B) __init__
# - C) __new__
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **

#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q684. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q685. Decorator/Generator/Metaprogramming concept 47?
#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q685. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q686. Decorator/Generator/Metaprogramming concept 48?
#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q686. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q687. Decorator/Generator/Metaprogramming concept 49?
#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q687. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q688. Decorator/Generator/Metaprogramming concept 50?
#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q688. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q689. Decorator/Generator/Metaprogramming concept 51?
#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q689. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q690. Decorator/Generator/Metaprogramming concept 52?
#
# - A) Option A
# - B) Option B
# - C) Option C
# - D) Option D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q690. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q691. What does `@functools.lru_cache(maxsize=128)` do?
#
# - A) Cache up to 128 results
# - B) Cache all
# - C) No cache
# - D) Cache 128 bytes
#
# <details>
# <summary>Show Answer</summary>
#
# **Q691. A)** maxsize limits cache entries.
#
# </details>

# %% [markdown]
# ### Q692. What does `@property` setter look like?
#
# - A) @propname.setter
# - B) @setter
# - C) @property.setter
# - D) def set_prop
#
# <details>
# <summary>Show Answer</summary>
#
# **Q692. A)** Use @propname.setter for setter.
#
# </details>

# %% [markdown]
# ### Q693. What is `__delete__` in descriptor?
#
# - A) Called on del attr
# - B) Delete descriptor
# - C) Remove
# - D) Clear
#
# <details>
# <summary>Show Answer</summary>
#
# **Q693. A)** __delete__ called on del instance.attr.
#
# </details>

# %% [markdown]
# ### Q694. What is `type('MyClass', (), {})`?
#
# - A) Dynamic class
# - B) Type object
# - C) Instance
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q694. A)** Creates class with given name, bases, dict.
#
# </details>

# %% [markdown]
# ### Q695. What does `__new__` return?
#
# - A) New instance
# - B) None
# - C) cls
# - D) self
#
# <details>
# <summary>Show Answer</summary>
#
# **Q695. A)** __new__ must return new instance.
#
# </details>

# %% [markdown]
# ### Q696. Can you add attributes with __slots__?
#
# - A) Only listed ones
# - B) Any
# - C) None
# - D) Only in __init__
#
# <details>
# <summary>Show Answer</summary>
#
# **Q696. A)** Only attributes in __slots__ allowed.
#
# </details>

# %% [markdown]
# ### Q697. What does `for x in gen` do?
#
# - A) Iterate yielded values
# - B) Get generator
# - C) Call gen
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q697. A)** for loop consumes generator.
#
# </details>

# %% [markdown]
# ### Q698. What does `gen.__next__()` do?
#
# - A) Same as next(gen)
# - B) Reset
# - C) Close
# - D) Send
#
# <details>
# <summary>Show Answer</summary>
#
# **Q698. A)** __next__ is what next() calls.
#
# </details>

# %% [markdown]
# ### Q699. What is `@dataclass`?
#
# - A) Auto __init__, __repr__
# - B) Data only
# - C) Both
# - D) Frozen only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q699. C)** dataclass generates boilerplate.
#
# </details>

# %% [markdown]
# ### Q700. What does `__mro__` contain?
#
# - A) Method resolution order
# - B) Methods
# - C) Attributes
# - D) Parents
#
# <details>
# <summary>Show Answer</summary>
#
# **Q700. A)** __mro__ is resolution order tuple.
#
# </details>
