# %% [markdown]
# # 🐍 Python Interview MCQ — Part 7: Decorators, Generators & Metaprogramming (Q601–Q700)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q601. What does a decorator do?
#
# - A) Wrap/modify function
# - B) Delete function
# - C) Import function
# - D) Call function
#
# <details>
# <summary>Show Answer</summary>
#
# **Q601. A)** Decorator wraps and can modify function behavior.
#
# </details>

# %% [markdown]
# ### Q602. What does `functools.wraps(f)` preserve?
#
# - A) Original metadata
# - B) Function body
# - C) Return value
# - D) Arguments
#
# <details>
# <summary>Show Answer</summary>
#
# **Q602. A)** wraps copies __name__, __doc__, etc.
#
# </details>

# %% [markdown]
# ### Q603. What does `@property` create?
#
# - A) Getter for attribute
# - B) Setter only
# - C) Both getter and optional setter
# - D) Class method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q603. C)** property defines getter; setter/deleter optional.
#
# </details>

# %% [markdown]
# ### Q604. What is a descriptor?
#
# - A) Object with __get__/__set__/__delete__
# - B) Decorator
# - C) Property only
# - D) Method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q604. A)** Descriptor protocol: __get__, __set__, __delete__.
#
# </details>

# %% [markdown]
# ### Q605. What does `type()` with 3 args create?
#
# - A) New class dynamically
# - B) Instance
# - C) Type object
# - D) Metaclass
#
# <details>
# <summary>Show Answer</summary>
#
# **Q605. A)** type(name, bases, dict) creates a class.
#
# </details>

# %% [markdown]
# ### Q606. What is `__new__` vs `__init__`?
#
# - A) __new__ creates, __init__ initializes
# - B) Same thing
# - C) __init__ first
# - D) Only __init__ needed
#
# <details>
# <summary>Show Answer</summary>
#
# **Q606. A)** __new__ creates object; __init__ sets up.
#
# </details>

# %% [markdown]
# ### Q607. What does `__slots__` do?
#
# - A) Restrict instance attributes
# - B) Add attributes
# - C) Create slots
# - D) Reserve memory
#
# <details>
# <summary>Show Answer</summary>
#
# **Q607. A)** __slots__ limits allowed attributes, saves memory.
#
# </details>

# %% [markdown]
# ### Q608. What does `yield` do in a function?
#
# - A) Pause and return value
# - B) Return and stop
# - C) Raise exception
# - D) Break loop
#
# <details>
# <summary>Show Answer</summary>
#
# **Q608. A)** yield makes generator; pauses and yields value.
#
# </details>

# %% [markdown]
# ### Q609. What does `generator.send(x)` do?
#
# - A) Send value into yield
# - B) Send to next
# - C) Both
# - D) Raise error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q609. A)** send() passes value to yield expression.
#
# </details>

# %% [markdown]
# ### Q610. What does `generator.throw(exc)` do?
#
# - A) Raise exception in generator
# - B) Catch exception
# - C) Return exception
# - D) Ignore
#
# <details>
# <summary>Show Answer</summary>
#
# **Q610. A)** throw raises exception at yield point.
#
# </details>

# %% [markdown]
# ### Q611. What is `(x**2 for x in range(5))`?
#
# - A) Generator expression
# - B) List
# - C) Tuple
# - D) Set
#
# <details>
# <summary>Show Answer</summary>
#
# **Q611. A)** Parentheses create generator expression.
#
# </details>

# %% [markdown]
# ### Q612. What is `abc.ABC`?
#
# - A) Abstract base class
# - B) Abstract method
# - C) Base class only
# - D) Interface
#
# <details>
# <summary>Show Answer</summary>
#
# **Q612. A)** ABC is base for abstract classes.
#
# </details>

# %% [markdown]
# ### Q613. What does `__init_subclass__` do?
#
# - A) Hook when subclass is created
# - B) Initialize subclass
# - C) Call super
# - D) Register class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q613. A)** Called when class is subclassed.
#
# </details>

# %% [markdown]
# ### Q614. What is `__class_getitem__`?
#
# - A) Support cls[int]
# - B) Get class item
# - C) Generic type
# - D) Index class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q614. A)** Enables Class[int] syntax for generics.
#
# </details>

# %% [markdown]
# ### Q615. What does a decorator with args look like?
#
# - A) @decorator(arg)
# - B) @decorator
# - C) Both
# - D) decorator()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q615. A)** decorator(arg) returns actual decorator.
#
# </details>

# %% [markdown]
# ### Q616. What does `@staticmethod` do?
#
# - A) No self/cls
# - B) Class method
# - C) Instance only
# - D) Abstract
#
# <details>
# <summary>Show Answer</summary>
#
# **Q616. A)** staticmethod receives no implicit first arg.
#
# </details>

# %% [markdown]
# ### Q617. What is `__get__` in a descriptor?
#
# - A) Called on attribute access
# - B) Getter method
# - C) Both
# - D) Property
#
# <details>
# <summary>Show Answer</summary>
#
# **Q617. A)** __get__(self, instance, owner) on access.
#
# </details>

# %% [markdown]
# ### Q618. What is a metaclass?
#
# - A) Class of a class
# - B) Base class
# - C) Super class
# - D) Abstract class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q618. A)** Metaclass creates classes; type is default.
#
# </details>

# %% [markdown]
# ### Q619. What does `object.__new__(cls)` do?
#
# - A) Create instance
# - B) Initialize
# - C) Both
# - D) Return cls
#
# <details>
# <summary>Show Answer</summary>
#
# **Q619. A)** __new__ creates and returns new instance.
#
# </details>

# %% [markdown]
# ### Q620. What does `__slots__ = ['x']` prevent?
#
# - A) Adding other attributes
# - B) Using x
# - C) Inheritance
# - D) Methods
#
# <details>
# <summary>Show Answer</summary>
#
# **Q620. A)** Only x (and __dict__-like) allowed.
#
# </details>

# %% [markdown]
# ### Q621. What does a generator return?
#
# - A) Generator iterator
# - B) First value
# - C) List
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q621. A)** Generator function returns generator object.
#
# </details>

# %% [markdown]
# ### Q622. What does `next(gen)` do?
#
# - A) Advance to next yield
# - B) Get first only
# - C) Reset generator
# - D) Close generator
#
# <details>
# <summary>Show Answer</summary>
#
# **Q622. A)** next() advances to next yield.
#
# </details>

# %% [markdown]
# ### Q623. What is a coroutine?
#
# - A) async def function
# - B) Generator with send
# - C) Both
# - D) Thread
#
# <details>
# <summary>Show Answer</summary>
#
# **Q623. C)** async def creates coroutine; generators can emulate.
#
# </details>

# %% [markdown]
# ### Q624. What does `@abstractmethod` do?
#
# - A) Must override in subclass
# - B) Cannot call
# - C) Both
# - D) Optional override
#
# <details>
# <summary>Show Answer</summary>
#
# **Q624. A)** Abstract method must be implemented.
#
# </details>

# %% [markdown]
# ### Q625. What does `__init_subclass__(cls)` receive?
#
# - A) The new subclass
# - B) Parent class
# - C) Instance
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q625. A)** cls is the newly defined subclass.
#
# </details>

# %% [markdown]
# ### Q626. What does `list[int]` use?
#
# - A) __class_getitem__
# - B) __getitem__
# - C) __subscript__
# - D) Generic
#
# <details>
# <summary>Show Answer</summary>
#
# **Q626. A)** __class_getitem__ enables Class[args].
#
# </details>

# %% [markdown]
# ### Q627. What does `def dec(f): return f` do?
#
# - A) No-op decorator
# - B) Replace function
# - C) Delete function
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q627. A)** Returns same function unchanged.
#
# </details>

# %% [markdown]
# ### Q628. What does `@classmethod` receive as first arg?
#
# - A) cls
# - B) self
# - C) class
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q628. A)** classmethod gets class as first argument.
#
# </details>

# %% [markdown]
# ### Q629. What is `__set__` in a descriptor?
#
# - A) Called on assignment
# - B) Setter
# - C) Both
# - D) Property setter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q629. A)** __set__(self, instance, value) on assignment.
#
# </details>

# %% [markdown]
# ### Q630. What does `type.__new__` create?
#
# - A) New class
# - B) Instance
# - C) Metaclass
# - D) Object
#
# <details>
# <summary>Show Answer</summary>
#
# **Q630. A)** Metaclass __new__ creates the class object.
#
# </details>

# %% [markdown]
# ### Q631. When is `__new__` called?
#
# - A) Before __init__
# - B) After __init__
# - C) Instead of __init__
# - D) Never
#
# <details>
# <summary>Show Answer</summary>
#
# **Q631. A)** __new__ creates object; __init__ initializes it.
#
# </details>

# %% [markdown]
# ### Q632. What does `__slots__` save?
#
# - A) Memory
# - B) Speed
# - C) Both
# - D) Neither
#
# <details>
# <summary>Show Answer</summary>
#
# **Q632. C)** No __dict__ per instance saves memory.
#
# </details>

# %% [markdown]
# ### Q633. What does `yield from iter` do?
#
# - A) Delegate to sub-generator
# - B) Yield iter
# - C) Flatten
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q633. A)** yield from delegates to another generator.
#
# </details>

# %% [markdown]
# ### Q634. What does `gen.close()` do?
#
# - A) Raise GeneratorExit
# - B) Delete generator
# - C) Return None
# - D) Pause
#
# <details>
# <summary>Show Answer</summary>
#
# **Q634. A)** close() raises GeneratorExit in generator.
#
# </details>

# %% [markdown]
# ### Q635. What is `async def`?
#
# - A) Coroutine function
# - B) Generator
# - C) Thread
# - D) Process
#
# <details>
# <summary>Show Answer</summary>
#
# **Q635. A)** async def defines coroutine function.
#
# </details>

# %% [markdown]
# ### Q636. What does `ABC` prevent?
#
# - A) Instantiating with unimplemented abstract methods
# - B) Subclassing
# - C) Importing
# - D) Inheritance
#
# <details>
# <summary>Show Answer</summary>
#
# **Q636. A)** Cannot instantiate until abstract methods implemented.
#
# </details>

# %% [markdown]
# ### Q637. What does `__init_subclass__` replace?
#
# - A) Metaclass for simple cases
# - B) __init__
# - C) __new__
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q637. A)** Simpler than metaclass for subclass hooks.
#
# </details>

# %% [markdown]
# ### Q638. What does `typing.Generic` use?
#
# - A) __class_getitem__
# - B) __getitem__
# - C) Metaclass
# - D) Decorator
#
# <details>
# <summary>Show Answer</summary>
#
# **Q638. A)** Generic uses __class_getitem__ for Type[T].
#
# </details>

# %% [markdown]
# ### Q639. What does `@functools.lru_cache(maxsize=128)` do?
#
# - A) Cache up to 128 results
# - B) Cache all
# - C) No cache
# - D) Cache 128 bytes
#
# <details>
# <summary>Show Answer</summary>
#
# **Q639. A)** maxsize limits cache entries.
#
# </details>

# %% [markdown]
# ### Q640. What does `@property` setter look like?
#
# - A) @propname.setter
# - B) @setter
# - C) @property.setter
# - D) def set_prop
#
# <details>
# <summary>Show Answer</summary>
#
# **Q640. A)** Use @propname.setter for setter.
#
# </details>

# %% [markdown]
# ### Q641. What is `__delete__` in descriptor?
#
# - A) Called on del attr
# - B) Delete descriptor
# - C) Remove
# - D) Clear
#
# <details>
# <summary>Show Answer</summary>
#
# **Q641. A)** __delete__ called on del instance.attr.
#
# </details>

# %% [markdown]
# ### Q642. What is `type('MyClass', (), {})`?
#
# - A) Dynamic class
# - B) Type object
# - C) Instance
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q642. A)** Creates class with given name, bases, dict.
#
# </details>

# %% [markdown]
# ### Q643. What does `__new__` return?
#
# - A) New instance
# - B) None
# - C) cls
# - D) self
#
# <details>
# <summary>Show Answer</summary>
#
# **Q643. A)** __new__ must return new instance.
#
# </details>

# %% [markdown]
# ### Q644. Can you add attributes with __slots__?
#
# - A) Only listed ones
# - B) Any
# - C) None
# - D) Only in __init__
#
# <details>
# <summary>Show Answer</summary>
#
# **Q644. A)** Only attributes in __slots__ allowed.
#
# </details>

# %% [markdown]
# ### Q645. What does `for x in gen` do?
#
# - A) Iterate yielded values
# - B) Get generator
# - C) Call gen
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q645. A)** for loop consumes generator.
#
# </details>

# %% [markdown]
# ### Q646. What does `gen.__next__()` do?
#
# - A) Same as next(gen)
# - B) Reset
# - C) Close
# - D) Send
#
# <details>
# <summary>Show Answer</summary>
#
# **Q646. A)** __next__ is what next() calls.
#
# </details>

# %% [markdown]
# ### Q647. What is `@dataclass`?
#
# - A) Auto __init__, __repr__
# - B) Data only
# - C) Both
# - D) Frozen only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q647. C)** dataclass generates boilerplate.
#
# </details>

# %% [markdown]
# ### Q648. What does `__mro__` contain?
#
# - A) Method resolution order
# - B) Methods
# - C) Attributes
# - D) Parents
#
# <details>
# <summary>Show Answer</summary>
#
# **Q648. A)** __mro__ is resolution order tuple.
#
# </details>

# %% [markdown]
# ### Q649. What does `def dec(x): return lambda f: f` create?
#
# - A) Decorator factory
# - B) Simple decorator
# - C) Error
# - D) Closure
#
# <details>
# <summary>Show Answer</summary>
#
# **Q649. A)** Returns decorator; dec(x) gives actual decorator.
#
# </details>

# %% [markdown]
# ### Q650. When is `__get__` called with instance=None?
#
# - A) Access via class
# - B) Never
# - C) On delete
# - D) On set
#
# <details>
# <summary>Show Answer</summary>
#
# **Q650. A)** Class access: instance is None, owner is class.
#
# </details>

# %% [markdown]
# ### Q651. What does `functools.partial(f, 1)(2)` do?
#
# - A) Call f(1, 2)
# - B) Call f(2)
# - C) Error
# - D) Return f
#
# <details>
# <summary>Show Answer</summary>
#
# **Q651. A)** partial fixes first arg, passes 2 as second.
#
# </details>

# %% [markdown]
# ### Q652. What is `StopIteration` in generator?
#
# - A) Signal end of iteration
# - B) Error only
# - C) Pause
# - D) Reset
#
# <details>
# <summary>Show Answer</summary>
#
# **Q652. A)** Raised when generator exhausts (or return).
#
# </details>

# %% [markdown]
# ### Q653. What does `@abstractmethod` require?
#
# - A) ABC base class
# - B) Any class
# - C) Metaclass
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q653. A)** Abstract methods need ABC (or similar) base.
#
# </details>

# %% [markdown]
# ### Q654. What does `__init_subclass__` run?
#
# - A) When subclass is defined
# - B) When instance created
# - C) On import
# - D) Never
#
# <details>
# <summary>Show Answer</summary>
#
# **Q654. A)** Runs at class definition time.
#
# </details>

# %% [markdown]
# ### Q655. What enables `dict[str, int]`?
#
# - A) __class_getitem__
# - B) __getitem__
# - C) typing
# - D) Generic
#
# <details>
# <summary>Show Answer</summary>
#
# **Q655. A)** __class_getitem__ on built-in types.
#
# </details>

# %% [markdown]
# ### Q656. What does `inspect.isfunction(f)` check?
#
# - A) f is user-defined function
# - B) f is callable
# - C) f has __call__
# - D) f is method
#
# <details>
# <summary>Show Answer</summary>
#
# **Q656. A)** Distinguishes function from built-in, etc.
#
# </details>

# %% [markdown]
# ### Q657. What does `yield` without value produce?
#
# - A) None
# - B) Error
# - C) Generator
# - D) StopIteration
#
# <details>
# <summary>Show Answer</summary>
#
# **Q657. A)** yield yields None when no expression.
#
# </details>

# %% [markdown]
# ### Q658. What is `functools.cached_property`?
#
# - A) Property cached per instance
# - B) Class property
# - C) Static cache
# - D) LRU property
#
# <details>
# <summary>Show Answer</summary>
#
# **Q658. A)** Caches computed value on first access.
#
# </details>

# %% [markdown]
# ### Q659. What does `__set_name__` in descriptor do?
#
# - A) Receive attribute name
# - B) Set name
# - C) Rename
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q659. A)** Called when descriptor assigned to class attr.
#
# </details>

# %% [markdown]
# ### Q660. What is `type`'s metaclass?
#
# - A) type
# - B) object
# - C) None
# - D) type.__class__
#
# <details>
# <summary>Show Answer</summary>
#
# **Q660. A)** type is its own metaclass.
#
# </details>

# %% [markdown]
# ### Q661. What does `__new__` receive that `__init__` doesn't?
#
# - A) cls
# - B) Same args
# - C) Nothing extra
# - D) class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q661. A)** __new__ gets cls; __init__ gets self (instance).
#
# </details>

# %% [markdown]
# ### Q662. Can `__slots__` inherit?
#
# - A) Yes, child gets parent slots
# - B) No
# - C) Overrides only
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q662. A)** Subclass inherits; can add more in own __slots__.
#
# </details>

# %% [markdown]
# ### Q663. What does `itertools.islice(gen, 3)` return?
#
# - A) First 3 from gen
# - B) All from gen
# - C) Last 3
# - D) Every 3rd
#
# <details>
# <summary>Show Answer</summary>
#
# **Q663. A)** islice takes first n from iterator.
#
# </details>

# %% [markdown]
# ### Q664. What is `typing.Protocol`?
#
# - A) Structural subtyping
# - B) Nominal inheritance
# - C) Abstract only
# - D) Runtime check
#
# <details>
# <summary>Show Answer</summary>
#
# **Q664. A)** Protocol enables structural typing (duck typing).
#
# </details>

# %% [markdown]
# ### Q665. What does `__prepare__` in metaclass do?
#
# - A) Return namespace for class body
# - B) Prepare instance
# - C) Init class
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q665. A)** __prepare__ returns dict-like for class namespace.
#
# </details>

# %% [markdown]
# ### Q666. What does `generator.gi_frame` hold?
#
# - A) Current frame state
# - B) Return value
# - C) Arguments
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q666. A)** Frame has local vars, etc.
#
# </details>

# %% [markdown]
# ### Q667. What is `@functools.singledispatch`?
#
# - A) Function overload by first arg type
# - B) Single function
# - C) Dispatch table
# - D) Decorator only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q667. A)** Overloads based on type of first argument.
#
# </details>

# %% [markdown]
# ### Q668. What does `__getattribute__` intercept?
#
# - A) All attribute access
# - B) Missing only
# - C) Gets only
# - D) Sets only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q668. A)** __getattribute__ catches every attr access.
#
# </details>

# %% [markdown]
# ### Q669. What does `__getattr__` get when attr not found?
#
# - A) Last resort
# - B) First call
# - C) Never
# - D) Always
#
# <details>
# <summary>Show Answer</summary>
#
# **Q669. A)** __getattr__ only when normal lookup fails.
#
# </details>

# %% [markdown]
# ### Q670. What does `class C(metaclass=M)` do?
#
# - A) Use M to create C
# - B) Inherit M
# - C) M is base
# - D) M is mixin
#
# <details>
# <summary>Show Answer</summary>
#
# **Q670. A)** M is metaclass creating C.
#
# </details>

# %% [markdown]
# ### Q671. What does `object.__new__` require?
#
# - A) Return instance of cls
# - B) Return None
# - C) Call __init__
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q671. A)** __new__ must return new instance (or subclass).
#
# </details>

# %% [markdown]
# ### Q672. What happens with `__slots__` and `__dict__`?
#
# - A) No __dict__ by default
# - B) Both exist
# - C) __dict__ only
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q672. A)** __slots__ removes __dict__ to save memory.
#
# </details>

# %% [markdown]
# ### Q673. What does `gen.send(None)` equal?
#
# - A) next(gen)
# - B) gen.throw()
# - C) Error
# - D) gen.close()
#
# <details>
# <summary>Show Answer</summary>
#
# **Q673. A)** First send must be None (or next()).
#
# </details>

# %% [markdown]
# ### Q674. What is `contextlib.contextmanager`?
#
# - A) Decorator for generator CM
# - B) Base class
# - C) Function
# - D) Protocol
#
# <details>
# <summary>Show Answer</summary>
#
# **Q674. A)** Turns generator into context manager.
#
# </details>

# %% [markdown]
# ### Q675. What does `abc.abstractmethod` combine with?
#
# - A) ABC
# - B) Any class
# - C) object
# - D) type
#
# <details>
# <summary>Show Answer</summary>
#
# **Q675. A)** ABC checks abstract methods at instantiation.
#
# </details>

# %% [markdown]
# ### Q676. What does `__init_subclass__` allow?
#
# - A) Customize subclass at definition
# - B) Only __init__
# - C) Only __new__
# - D) Runtime only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q676. A)** Hook without full metaclass.
#
# </details>

# %% [markdown]
# ### Q677. What does `typing.TypeVar` create?
#
# - A) Generic type variable
# - B) Type alias
# - C) New type
# - D) Protocol
#
# <details>
# <summary>Show Answer</summary>
#
# **Q677. A)** TypeVar for generic type parameters.
#
# </details>

# %% [markdown]
# ### Q678. What does `@decorator` without parens mean?
#
# - A) decorator(func)
# - B) decorator()
# - C) Just decorator
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q678. A)** func passed to decorator directly.
#
# </details>

# %% [markdown]
# ### Q679. What does `@classmethod` allow?
#
# - A) Call without instance
# - B) Instance only
# - C) Static only
# - D) Abstract
#
# <details>
# <summary>Show Answer</summary>
#
# **Q679. A)** Can call via Class.method() or instance.method().
#
# </details>

# %% [markdown]
# ### Q680. What is data descriptor?
#
# - A) Has __set__ or __delete__
# - B) Has __get__ only
# - C) Both
# - D) Property
#
# <details>
# <summary>Show Answer</summary>
#
# **Q680. A)** Data descriptor has __set__ or __delete__.
#
# </details>

# %% [markdown]
# ### Q681. What does custom metaclass inherit from?
#
# - A) type
# - B) object
# - C) None
# - D) Metaclass
#
# <details>
# <summary>Show Answer</summary>
#
# **Q681. A)** Metaclasses typically subclass type.
#
# </details>

# %% [markdown]
# ### Q682. What if `__new__` returns existing instance?
#
# - A) __init__ not called
# - B) __init__ called
# - C) Error
# - D) Both called
#
# <details>
# <summary>Show Answer</summary>
#
# **Q682. A)** __init__ only for new instances.
#
# </details>

# %% [markdown]
# ### Q683. What does `__slots__ = ()` do?
#
# - A) No instance attributes
# - B) All attributes
# - C) Error
# - D) Same as default
#
# <details>
# <summary>Show Answer</summary>
#
# **Q683. A)** Empty __slots__ prevents instance attrs.
#
# </details>

# %% [markdown]
# ### Q684. What does `sum(x**2 for x in range(5))` return?
#
# - A) 30
# - B) 55
# - C) 25
# - D) 10
#
# <details>
# <summary>Show Answer</summary>
#
# **Q684. A)** 0+1+4+9+16=30.
#
# </details>

# %% [markdown]
# ### Q685. What is `typing.runtime_checkable`?
#
# - A) Enable isinstance with Protocol
# - B) Runtime only
# - C) Check Protocol
# - D) Validate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q685. A)** Allows isinstance(obj, Protocol).
#
# </details>

# %% [markdown]
# ### Q686. What does `metaclass.__call__` do?
#
# - A) Create instance when Class() called
# - B) Create class
# - C) Call method
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q686. A)** Metaclass __call__ runs on Class().
#
# </details>

# %% [markdown]
# ### Q687. What does `gen.throw(ValueError)` do?
#
# - A) Raise ValueError at yield
# - B) Catch ValueError
# - C) Return ValueError
# - D) Ignore
#
# <details>
# <summary>Show Answer</summary>
#
# **Q687. A)** Injects exception at yield point.
#
# </details>

# %% [markdown]
# ### Q688. What is `@dataclass(frozen=True)`?
#
# - A) Immutable instances
# - B) Frozen methods
# - C) No init
# - D) Read-only class
#
# <details>
# <summary>Show Answer</summary>
#
# **Q688. A)** frozen makes instances immutable.
#
# </details>

# %% [markdown]
# ### Q689. What does `functools.reduce` do?
#
# - A) Fold iterable to single value
# - B) Reduce size
# - C) Filter
# - D) Map
#
# <details>
# <summary>Show Answer</summary>
#
# **Q689. A)** reduce applies binary function cumulatively.
#
# </details>

# %% [markdown]
# ### Q690. What is non-data descriptor?
#
# - A) __get__ only
# - B) __set__ only
# - C) Both
# - D) Property
#
# <details>
# <summary>Show Answer</summary>
#
# **Q690. A)** Only __get__; lower priority than instance dict.
#
# </details>

# %% [markdown]
# ### Q691. What does `type(obj)` return?
#
# - A) Class of obj
# - B) type
# - C) object
# - D) Class name
#
# <details>
# <summary>Show Answer</summary>
#
# **Q691. A)** type(obj) returns obj's class.
#
# </details>

# %% [markdown]
# ### Q692. What does `super().__new__(cls)` do?
#
# - A) Delegate to parent __new__
# - B) Create parent
# - C) Error
# - D) Call __init__
#
# <details>
# <summary>Show Answer</summary>
#
# **Q692. A)** Calls parent's __new__ for instance creation.
#
# </details>

# %% [markdown]
# ### Q693. What if subclass adds `__dict__` to `__slots__`?
#
# - A) Allow dynamic attrs
# - B) Error
# - C) Override
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q693. A)** Adding __dict__ to __slots__ enables extra attrs.
#
# </details>

# %% [markdown]
# ### Q694. What does `list((i for i in range(3)))` produce?
#
# - A) [0,1,2]
# - B) [0,1,2,3]
# - C) Generator
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q694. A)** Exhausts generator to list.
#
# </details>

# %% [markdown]
# ### Q695. What is `typing.Callable`?
#
# - A) Type for functions
# - B) Callable class
# - C) Decorator
# - D) Protocol
#
# <details>
# <summary>Show Answer</summary>
#
# **Q695. A)** Callable[[ArgTypes], ReturnType] for function types.
#
# </details>

# %% [markdown]
# ### Q696. What does `__build_class__` do?
#
# - A) Build class in exec
# - B) Import class
# - C) Create instance
# - D) Compile
#
# <details>
# <summary>Show Answer</summary>
#
# **Q696. A)** Used internally for class statement.
#
# </details>

# %% [markdown]
# ### Q697. What does `gen.close()` cause generator to do?
#
# - A) Raise GeneratorExit, cleanup
# - B) Return
# - C) Pause
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q697. A)** Generator can catch GeneratorExit for cleanup.
#
# </details>

# %% [markdown]
# ### Q698. What is `@dataclass(order=True)`?
#
# - A) Generate comparison methods
# - B) Sort only
# - C) Order fields
# - D) Sequence
#
# <details>
# <summary>Show Answer</summary>
#
# **Q698. A)** Adds __lt__, __le__, __gt__, __ge__, __eq__.
#
# </details>

# %% [markdown]
# ### Q699. What does `functools.wraps` fix?
#
# - A) Preserve __name__ on wrapper
# - B) Preserve return
# - C) Preserve args
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q699. A)** Without wraps, wrapper shows wrapper name.
#
# </details>

# %% [markdown]
# ### Q700. What is `__doc__` on decorated function?
#
# - A) Lost without wraps
# - B) Always preserved
# - C) From decorator
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q700. A)** wraps copies __doc__ from original.
#
# </details>
