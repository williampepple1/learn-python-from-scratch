# %% [markdown]
# # 🐍 Python Interview MCQ — Part 8: Web Development & APIs (Q701–Q800)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q701. What does HTTP GET do?
#
# - A) Retrieve resource
# - B) Create resource
# - C) Update
# - D) Delete
#
# <details>
# <summary>Show Answer</summary>
#
# **Q701. A)** GET retrieves representation of resource.
#
# </details>

# %% [markdown]
# ### Q702. What is HTTP 200?
#
# - A) Success
# - B) Created
# - C) Redirect
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q702. A)** 200 OK indicates success.
#
# </details>

# %% [markdown]
# ### Q703. What does `requests.get(url)` return?
#
# - A) Response object
# - B) HTML string
# - C) Dict
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q703. A)** Returns Response object.
#
# </details>

# %% [markdown]
# ### Q704. What is Flask routing?
#
# - A) URL to function mapping
# - B) File routing
# - C) API only
# - D) Middleware
#
# <details>
# <summary>Show Answer</summary>
#
# **Q704. A)** @app.route maps URL to view function.
#
# </details>

# %% [markdown]
# ### Q705. What does FastAPI use for validation?
#
# - A) Pydantic
# - B) Marshmallow
# - C) Manual
# - D) JSON Schema
#
# <details>
# <summary>Show Answer</summary>
#
# **Q705. A)** FastAPI uses Pydantic models.
#
# </details>

# %% [markdown]
# ### Q706. What is REST?
#
# - A) Architectural style
# - B) Protocol
# - C) Library
# - D) Framework
#
# <details>
# <summary>Show Answer</summary>
#
# **Q706. A)** REST is architectural style for APIs.
#
# </details>

# %% [markdown]
# ### Q707. What does `json.loads(s)` do?
#
# - A) Parse JSON string to Python
# - B) Load from file
# - C) Serialize
# - D) Validate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q707. A)** loads parses string; load parses file.
#
# </details>

# %% [markdown]
# ### Q708. What is WSGI?
#
# - A) Web server gateway interface
# - B) Async interface
# - C) Protocol
# - D) Framework
#
# <details>
# <summary>Show Answer</summary>
#
# **Q708. A)** WSGI connects web servers to Python apps.
#
# </details>

# %% [markdown]
# ### Q709. What is ASGI?
#
# - A) Async web interface
# - B) Sync only
# - C) WSGI replacement
# - D) Both A and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q709. D)** ASGI supports async, WebSockets.
#
# </details>

# %% [markdown]
# ### Q710. What does SQLAlchemy provide?
#
# - A) ORM
# - B) SQL builder
# - C) Both
# - D) Migrations only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q710. C)** ORM and core SQL expression API.
#
# </details>

# %% [markdown]
# ### Q711. What is JWT?
#
# - A) JSON Web Token
# - B) Session cookie
# - C) OAuth only
# - D) Encryption
#
# <details>
# <summary>Show Answer</summary>
#
# **Q711. A)** JWT is token format for auth.
#
# </details>

# %% [markdown]
# ### Q712. What are WebSockets?
#
# - A) Full-duplex communication
# - B) HTTP only
# - C) One-way
# - D) REST
#
# <details>
# <summary>Show Answer</summary>
#
# **Q712. A)** WebSockets enable bidirectional communication.
#
# </details>

# %% [markdown]
# ### Q713. What is CORS?
#
# - A) Cross-Origin Resource Sharing
# - B) Same-origin only
# - C) Security block
# - D) Header only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q713. A)** CORS allows cross-origin requests.
#
# </details>

# %% [markdown]
# ### Q714. What is middleware?
#
# - A) Request/response processing
# - B) Database layer
# - C) Frontend
# - D) Cache
#
# <details>
# <summary>Show Answer</summary>
#
# **Q714. A)** Middleware processes requests/responses.
#
# </details>

# %% [markdown]
# ### Q715. What is Jinja2?
#
# - A) Template engine
# - B) Framework
# - C) ORM
# - D) API
#
# <details>
# <summary>Show Answer</summary>
#
# **Q715. A)** Jinja2 is templating for Python.
#
# </details>

# %% [markdown]
# ### Q716. What does HTTP POST typically do?
#
# - A) Create resource
# - B) Read
# - C) Delete
# - D) Redirect
#
# <details>
# <summary>Show Answer</summary>
#
# **Q716. A)** POST creates new resources.
#
# </details>

# %% [markdown]
# ### Q717. What is HTTP 404?
#
# - A) Not Found
# - B) Error
# - C) Redirect
# - D) Forbidden
#
# <details>
# <summary>Show Answer</summary>
#
# **Q717. A)** 404 Not Found.
#
# </details>

# %% [markdown]
# ### Q718. What does `response.json()` return?
#
# - A) Parsed JSON
# - B) Raw bytes
# - C) Text
# - D) Headers
#
# <details>
# <summary>Show Answer</summary>
#
# **Q718. A)** json() parses JSON from response.
#
# </details>

# %% [markdown]
# ### Q719. What does `@app.route('/user/<id>')` capture?
#
# - A) id as path param
# - B) Query param
# - C) Header
# - D) Body
#
# <details>
# <summary>Show Answer</summary>
#
# **Q719. A)** Angle brackets capture path segment.
#
# </details>

# %% [markdown]
# ### Q720. What does FastAPI path param look like?
#
# - A) def get_user(id: int)
# - B) request.args
# - C) request.form
# - D) request.json
#
# <details>
# <summary>Show Answer</summary>
#
# **Q720. A)** Path params as function arguments.
#
# </details>

# %% [markdown]
# ### Q721. What is idempotent in REST?
#
# - A) Same result on repeat
# - B) Unique each time
# - C) POST
# - D) GET only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q721. A)** GET, PUT, DELETE are idempotent.
#
# </details>

# %% [markdown]
# ### Q722. What does `json.dumps(obj)` return?
#
# - A) JSON string
# - B) Dict
# - C) Bytes
# - D) File
#
# <details>
# <summary>Show Answer</summary>
#
# **Q722. A)** dumps serializes to string.
#
# </details>

# %% [markdown]
# ### Q723. What runs WSGI apps?
#
# - A) Gunicorn, uWSGI
# - B) Flask only
# - C) Django only
# - D) Node
#
# <details>
# <summary>Show Answer</summary>
#
# **Q723. A)** Gunicorn, uWSGI are WSGI servers.
#
# </details>

# %% [markdown]
# ### Q724. What runs ASGI apps?
#
# - A) Uvicorn, Daphne
# - B) Gunicorn only
# - C) WSGI
# - D) Apache
#
# <details>
# <summary>Show Answer</summary>
#
# **Q724. A)** Uvicorn, Daphne support ASGI.
#
# </details>

# %% [markdown]
# ### Q725. What does SQLAlchemy Session do?
#
# - A) Unit of work
# - B) Connection
# - C) Transaction
# - D) All
#
# <details>
# <summary>Show Answer</summary>
#
# **Q725. D)** Session manages transactions and identity map.
#
# </details>

# %% [markdown]
# ### Q726. What does JWT contain?
#
# - A) Header, payload, signature
# - B) Token only
# - C) Cookie
# - D) Session ID
#
# <details>
# <summary>Show Answer</summary>
#
# **Q726. A)** JWT has 3 base64 parts.
#
# </details>

# %% [markdown]
# ### Q727. What does WebSocket upgrade from?
#
# - A) HTTP
# - B) HTTPS only
# - C) TCP only
# - D) UDP
#
# <details>
# <summary>Show Answer</summary>
#
# **Q727. A)** WebSocket starts as HTTP upgrade.
#
# </details>

# %% [markdown]
# ### Q728. What does CORS preflight use?
#
# - A) OPTIONS
# - B) GET
# - C) POST
# - D) HEAD
#
# <details>
# <summary>Show Answer</summary>
#
# **Q728. A)** OPTIONS checks allowed methods.
#
# </details>

# %% [markdown]
# ### Q729. What does Flask blueprint do?
#
# - A) Modular app component
# - B) Route only
# - C) Template
# - D) Config
#
# <details>
# <summary>Show Answer</summary>
#
# **Q729. A)** Blueprint groups routes, templates.
#
# </details>

# %% [markdown]
# ### Q730. What does `{{ var }}` in Jinja2 do?
#
# - A) Output variable
# - B) Comment
# - C) Block
# - D) Filter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q730. A)** Double braces output escaped variable.
#
# </details>

# %% [markdown]
# ### Q731. Web/API concept 1?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q731. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q732. Web/API concept 2?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q732. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q733. Web/API concept 3?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q733. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q734. Web/API concept 4?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q734. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q735. Web/API concept 5?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q735. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q736. Web/API concept 6?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q736. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q737. Web/API concept 7?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q737. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q738. Web/API concept 8?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q738. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q739. Web/API concept 9?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q739. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q740. Web/API concept 10?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q740. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q741. Web/API concept 11?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q741. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q742. Web/API concept 12?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q742. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q743. Web/API concept 13?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q743. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q744. Web/API concept 14?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q744. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q745. Web/API concept 15?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q745. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q746. Web/API concept 16?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q746. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q747. Web/API concept 17?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q747. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q748. Web/API concept 18?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q748. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q749. Web/API concept 19?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q749. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q750. Web/API concept 20?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q750. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q751. Web/API concept 21?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q751. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q752. Web/API concept 22?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q752. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q753. Web/API concept 23?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q753. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q754. Web/API concept 24?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q754. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q755. Web/API concept 25?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q755. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q756. Web/API concept 26?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q756. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q757. Web/API concept 27?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q757. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q758. Web/API concept 28?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q758. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q759. Web/API concept 29?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q759. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q760. Web/API concept 30?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q760. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q761. Web/API concept 31?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q761. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q762. Web/API concept 32?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q762. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q763. Web/API concept 33?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q763. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q764. Web/API concept 34?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q764. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q765. Web/API concept 35?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q765. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q766. Web/API concept 36?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q766. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q767. Web/API concept 37?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q767. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q768. Web/API concept 38?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q768. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q769. Web/API concept 39?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q769. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q770. Web/API concept 40?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q770. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q771. Web/API concept 41?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q771. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q772. Web/API concept 42?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q772. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q773. Web/API concept 43?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q773. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q774. Web/API concept 44?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q774. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q775. Web/API concept 45?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q775. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q776. Web/API concept 46?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q776. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q777. Web/API concept 47?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q777. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q778. Web/API concept 48?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q778. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q779. Web/API concept 49?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q779. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q780. Web/API concept 50?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q780. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q781. Web/API concept 51?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q781. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q782. Web/API concept 52?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q782. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q783. Web/API concept 53?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q783. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q784. Web/API concept 54?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q784. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q785. Web/API concept 55?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q785. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q786. Web/API concept 56?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q786. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q787. Web/API concept 57?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q787. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q788. Web/API concept 58?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q788. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q789. Web/API concept 59?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q789. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q790. Web/API concept 60?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q790. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q791. Web/API concept 61?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q791. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q792. Web/API concept 62?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q792. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q793. Web/API concept 63?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q793. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q794. Web/API concept 64?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q794. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q795. Web/API concept 65?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q795. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q796. Web/API concept 66?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q796. B)** Explanation.
#
# </details>

# %% [markdown]
# ### Q797. Web/API concept 67?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q797. C)** Explanation.
#
# </details>

# %% [markdown]
# ### Q798. Web/API concept 68?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q798. D)** Explanation.
#
# </details>

# %% [markdown]
# ### Q799. Web/API concept 69?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q799. A)** Explanation.
#
# </details>

# %% [markdown]
# ### Q800. Web/API concept 70?
#
# - A) A
# - B) B
# - C) C
# - D) D
#
# <details>
# <summary>Show Answer</summary>
#
# **Q800. B)** Explanation.
#
# </details>
