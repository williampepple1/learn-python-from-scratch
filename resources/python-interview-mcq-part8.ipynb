# %% [markdown]
# # 🐍 Python Interview MCQ — Part 8: Web Development & APIs (Q701–Q800)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q701. What does HTTP GET do?
#
# - A) Retrieve resource
# - B) Create resource
# - C) Update
# - D) Delete
#
# <details>
# <summary>Show Answer</summary>
#
# **Q701. A)** GET retrieves representation of resource.
#
# </details>

# %% [markdown]
# ### Q702. What is HTTP 200?
#
# - A) Success
# - B) Created
# - C) Redirect
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q702. A)** 200 OK indicates success.
#
# </details>

# %% [markdown]
# ### Q703. What does `requests.get(url)` return?
#
# - A) Response object
# - B) HTML string
# - C) Dict
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q703. A)** Returns Response object.
#
# </details>

# %% [markdown]
# ### Q704. What is Flask routing?
#
# - A) URL to function mapping
# - B) File routing
# - C) API only
# - D) Middleware
#
# <details>
# <summary>Show Answer</summary>
#
# **Q704. A)** @app.route maps URL to view function.
#
# </details>

# %% [markdown]
# ### Q705. What does FastAPI use for validation?
#
# - A) Pydantic
# - B) Marshmallow
# - C) Manual
# - D) JSON Schema
#
# <details>
# <summary>Show Answer</summary>
#
# **Q705. A)** FastAPI uses Pydantic models.
#
# </details>

# %% [markdown]
# ### Q706. What is REST?
#
# - A) Architectural style
# - B) Protocol
# - C) Library
# - D) Framework
#
# <details>
# <summary>Show Answer</summary>
#
# **Q706. A)** REST is architectural style for APIs.
#
# </details>

# %% [markdown]
# ### Q707. What does `json.loads(s)` do?
#
# - A) Parse JSON string to Python
# - B) Load from file
# - C) Serialize
# - D) Validate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q707. A)** loads parses string; load parses file.
#
# </details>

# %% [markdown]
# ### Q708. What is WSGI?
#
# - A) Web server gateway interface
# - B) Async interface
# - C) Protocol
# - D) Framework
#
# <details>
# <summary>Show Answer</summary>
#
# **Q708. A)** WSGI connects web servers to Python apps.
#
# </details>

# %% [markdown]
# ### Q709. What is ASGI?
#
# - A) Async web interface
# - B) Sync only
# - C) WSGI replacement
# - D) Both A and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q709. D)** ASGI supports async, WebSockets.
#
# </details>

# %% [markdown]
# ### Q710. What does SQLAlchemy provide?
#
# - A) ORM
# - B) SQL builder
# - C) Both
# - D) Migrations only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q710. C)** ORM and core SQL expression API.
#
# </details>

# %% [markdown]
# ### Q711. What is JWT?
#
# - A) JSON Web Token
# - B) Session cookie
# - C) OAuth only
# - D) Encryption
#
# <details>
# <summary>Show Answer</summary>
#
# **Q711. A)** JWT is token format for auth.
#
# </details>

# %% [markdown]
# ### Q712. What are WebSockets?
#
# - A) Full-duplex communication
# - B) HTTP only
# - C) One-way
# - D) REST
#
# <details>
# <summary>Show Answer</summary>
#
# **Q712. A)** WebSockets enable bidirectional communication.
#
# </details>

# %% [markdown]
# ### Q713. What is CORS?
#
# - A) Cross-Origin Resource Sharing
# - B) Same-origin only
# - C) Security block
# - D) Header only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q713. A)** CORS allows cross-origin requests.
#
# </details>

# %% [markdown]
# ### Q714. What is middleware?
#
# - A) Request/response processing
# - B) Database layer
# - C) Frontend
# - D) Cache
#
# <details>
# <summary>Show Answer</summary>
#
# **Q714. A)** Middleware processes requests/responses.
#
# </details>

# %% [markdown]
# ### Q715. What is Jinja2?
#
# - A) Template engine
# - B) Framework
# - C) ORM
# - D) API
#
# <details>
# <summary>Show Answer</summary>
#
# **Q715. A)** Jinja2 is templating for Python.
#
# </details>

# %% [markdown]
# ### Q716. What does HTTP POST typically do?
#
# - A) Create resource
# - B) Read
# - C) Delete
# - D) Redirect
#
# <details>
# <summary>Show Answer</summary>
#
# **Q716. A)** POST creates new resources.
#
# </details>

# %% [markdown]
# ### Q717. What is HTTP 404?
#
# - A) Not Found
# - B) Error
# - C) Redirect
# - D) Forbidden
#
# <details>
# <summary>Show Answer</summary>
#
# **Q717. A)** 404 Not Found.
#
# </details>

# %% [markdown]
# ### Q718. What does `response.json()` return?
#
# - A) Parsed JSON
# - B) Raw bytes
# - C) Text
# - D) Headers
#
# <details>
# <summary>Show Answer</summary>
#
# **Q718. A)** json() parses JSON from response.
#
# </details>

# %% [markdown]
# ### Q719. What does `@app.route('/user/<id>')` capture?
#
# - A) id as path param
# - B) Query param
# - C) Header
# - D) Body
#
# <details>
# <summary>Show Answer</summary>
#
# **Q719. A)** Angle brackets capture path segment.
#
# </details>

# %% [markdown]
# ### Q720. What does FastAPI path param look like?
#
# - A) def get_user(id: int)
# - B) request.args
# - C) request.form
# - D) request.json
#
# <details>
# <summary>Show Answer</summary>
#
# **Q720. A)** Path params as function arguments.
#
# </details>

# %% [markdown]
# ### Q721. What is idempotent in REST?
#
# - A) Same result on repeat
# - B) Unique each time
# - C) POST
# - D) GET only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q721. A)** GET, PUT, DELETE are idempotent.
#
# </details>

# %% [markdown]
# ### Q722. What does `json.dumps(obj)` return?
#
# - A) JSON string
# - B) Dict
# - C) Bytes
# - D) File
#
# <details>
# <summary>Show Answer</summary>
#
# **Q722. A)** dumps serializes to string.
#
# </details>

# %% [markdown]
# ### Q723. What runs WSGI apps?
#
# - A) Gunicorn, uWSGI
# - B) Flask only
# - C) Django only
# - D) Node
#
# <details>
# <summary>Show Answer</summary>
#
# **Q723. A)** Gunicorn, uWSGI are WSGI servers.
#
# </details>

# %% [markdown]
# ### Q724. What runs ASGI apps?
#
# - A) Uvicorn, Daphne
# - B) Gunicorn only
# - C) WSGI
# - D) Apache
#
# <details>
# <summary>Show Answer</summary>
#
# **Q724. A)** Uvicorn, Daphne support ASGI.
#
# </details>

# %% [markdown]
# ### Q725. What does SQLAlchemy Session do?
#
# - A) Unit of work
# - B) Connection
# - C) Transaction
# - D) All
#
# <details>
# <summary>Show Answer</summary>
#
# **Q725. D)** Session manages transactions and identity map.
#
# </details>

# %% [markdown]
# ### Q726. What does JWT contain?
#
# - A) Header, payload, signature
# - B) Token only
# - C) Cookie
# - D) Session ID
#
# <details>
# <summary>Show Answer</summary>
#
# **Q726. A)** JWT has 3 base64 parts.
#
# </details>

# %% [markdown]
# ### Q727. What does WebSocket upgrade from?
#
# - A) HTTP
# - B) HTTPS only
# - C) TCP only
# - D) UDP
#
# <details>
# <summary>Show Answer</summary>
#
# **Q727. A)** WebSocket starts as HTTP upgrade.
#
# </details>

# %% [markdown]
# ### Q728. What does CORS preflight use?
#
# - A) OPTIONS
# - B) GET
# - C) POST
# - D) HEAD
#
# <details>
# <summary>Show Answer</summary>
#
# **Q728. A)** OPTIONS checks allowed methods.
#
# </details>

# %% [markdown]
# ### Q729. What does Flask blueprint do?
#
# - A) Modular app component
# - B) Route only
# - C) Template
# - D) Config
#
# <details>
# <summary>Show Answer</summary>
#
# **Q729. A)** Blueprint groups routes, templates.
#
# </details>

# %% [markdown]
# ### Q730. What does `{{ var }}` in Jinja2 do?
#
# - A) Output variable
# - B) Comment
# - C) Block
# - D) Filter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q730. A)** Double braces output escaped variable.
#
# </details>

# %% [markdown]
# ### Q731. What is HTTP 201?
#
# - A) Created
# - B) OK
# - C) Accepted
# - D) No Content
#
# <details>
# <summary>Show Answer</summary>
#
# **Q731. A)** 201 Created for POST success.
#
# </details>

# %% [markdown]
# ### Q732. What does `response.status_code` contain?
#
# - A) HTTP status int
# - B) Message
# - C) Headers
# - D) Body
#
# <details>
# <summary>Show Answer</summary>
#
# **Q732. A)** e.g. 200, 404, 500.
#
# </details>

# %% [markdown]
# ### Q733. What is Flask's `request.method`?
#
# - A) GET, POST, etc.
# - B) URL
# - C) Headers
# - D) Body
#
# <details>
# <summary>Show Answer</summary>
#
# **Q733. A)** HTTP method of request.
#
# </details>

# %% [markdown]
# ### Q734. What does FastAPI auto-generate?
#
# - A) OpenAPI docs
# - B) HTML
# - C) DB schema
# - D) Tests
#
# <details>
# <summary>Show Answer</summary>
#
# **Q734. A)** /docs and /openapi.json.
#
# </details>

# %% [markdown]
# ### Q735. What is HTTP PUT?
#
# - A) Replace resource
# - B) Create
# - C) Partial update
# - D) Delete
#
# <details>
# <summary>Show Answer</summary>
#
# **Q735. A)** PUT replaces entire resource.
#
# </details>

# %% [markdown]
# ### Q736. What does `requests.post(url, json={})` set?
#
# - A) Content-Type: application/json
# - B) Accept header
# - C) Auth
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q736. A)** json= serializes and sets header.
#
# </details>

# %% [markdown]
# ### Q737. What is PATCH?
#
# - A) Partial update
# - B) Full replace
# - C) Create
# - D) Delete
#
# <details>
# <summary>Show Answer</summary>
#
# **Q737. A)** PATCH for partial updates.
#
# </details>

# %% [markdown]
# ### Q738. What does `render_template` do?
#
# - A) Render Jinja2 template
# - B) Return HTML string
# - C) Both
# - D) Load template only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q738. C)** Renders and returns response.
#
# </details>

# %% [markdown]
# ### Q739. What is `request.args` in Flask?
#
# - A) Query parameters
# - B) Path params
# - C) Headers
# - D) Body
#
# <details>
# <summary>Show Answer</summary>
#
# **Q739. A)** URL query string ?key=val.
#
# </details>

# %% [markdown]
# ### Q740. What does `response.raise_for_status()` do?
#
# - A) Raise on 4xx/5xx
# - B) Return status
# - C) Check headers
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q740. A)** Raises HTTPError for bad status.
#
# </details>

# %% [markdown]
# ### Q741. What is HTTP 500?
#
# - A) Server error
# - B) Client error
# - C) Redirect
# - D) OK
#
# <details>
# <summary>Show Answer</summary>
#
# **Q741. A)** 500 Internal Server Error.
#
# </details>

# %% [markdown]
# ### Q742. What does `@app.before_request` do?
#
# - A) Run before each request
# - B) After request
# - C) On startup
# - D) On error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q742. A)** Flask hook before view.
#
# </details>

# %% [markdown]
# ### Q743. What is Pydantic BaseModel?
#
# - A) Data validation
# - B) ORM model
# - C) Template
# - D) Schema only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q743. A)** Validates and parses data.
#
# </details>

# %% [markdown]
# ### Q744. What does `json.dumps` default do with non-ASCII?
#
# - A) Escape as \uXXXX
# - B) Error
# - C) Keep as-is
# - D) Remove
#
# <details>
# <summary>Show Answer</summary>
#
# **Q744. A)** ensure_ascii=True by default.
#
# </details>

# %% [markdown]
# ### Q745. What is HTTP 301?
#
# - A) Permanent redirect
# - B) Temporary redirect
# - C) Found
# - D) Moved
#
# <details>
# <summary>Show Answer</summary>
#
# **Q745. A)** 301 Moved Permanently.
#
# </details>

# %% [markdown]
# ### Q746. What does `Flask(__name__)` need?
#
# - A) Import name for resources
# - B) App name
# - C) Nothing
# - D) Config
#
# <details>
# <summary>Show Answer</summary>
#
# **Q746. A)** Used to find templates, static.
#
# </details>

# %% [markdown]
# ### Q747. What is `request.json` in Flask?
#
# - A) Parsed JSON body
# - B) Raw body
# - C) Headers
# - D) Query
#
# <details>
# <summary>Show Answer</summary>
#
# **Q747. A)** Parsed dict from JSON body.
#
# </details>

# %% [markdown]
# ### Q748. What does `Depends()` in FastAPI do?
#
# - A) Dependency injection
# - B) Deprecate
# - C) Default value
# - D) Validate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q748. A)** Injects dependencies into path functions.
#
# </details>

# %% [markdown]
# ### Q749. What is REST resource?
#
# - A) URL-identified entity
# - B) File only
# - C) Database
# - D) API key
#
# <details>
# <summary>Show Answer</summary>
#
# **Q749. A)** Resource identified by URI.
#
# </details>

# %% [markdown]
# ### Q750. What does `response.headers` contain?
#
# - A) Dict-like of headers
# - B) Status
# - C) Body
# - D) Cookies
#
# <details>
# <summary>Show Answer</summary>
#
# **Q750. A)** Response header key-value pairs.
#
# </details>

# %% [markdown]
# ### Q751. What is HTTP 400?
#
# - A) Bad request
# - B) Unauthorized
# - C) Forbidden
# - D) Not found
#
# <details>
# <summary>Show Answer</summary>
#
# **Q751. A)** 400 Bad Request.
#
# </details>

# %% [markdown]
# ### Q752. What does `redirect(url)` do in Flask?
#
# - A) 302 redirect
# - B) Render
# - C) Abort
# - D) Return
#
# <details>
# <summary>Show Answer</summary>
#
# **Q752. A)** Returns redirect response.
#
# </details>

# %% [markdown]
# ### Q753. What is `{% for %}` in Jinja2?
#
# - A) Loop
# - B) Condition
# - C) Block
# - D) Include
#
# <details>
# <summary>Show Answer</summary>
#
# **Q753. A)** For loop in template.
#
# </details>

# %% [markdown]
# ### Q754. What does `requests.Session()` provide?
#
# - A) Connection pooling, cookies
# - B) Async
# - C) Caching
# - D) Auth only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q754. A)** Reuses connections, persists cookies.
#
# </details>

# %% [markdown]
# ### Q755. What is HTTP 401?
#
# - A) Unauthorized
# - B) Forbidden
# - C) Bad request
# - D) Not found
#
# <details>
# <summary>Show Answer</summary>
#
# **Q755. A)** 401 Unauthorized.
#
# </details>

# %% [markdown]
# ### Q756. What does `make_response` in Flask do?
#
# - A) Create Response object
# - B) Send response
# - C) Parse request
# - D) Set cookie
#
# <details>
# <summary>Show Answer</summary>
#
# **Q756. A)** Build custom response object.
#
# </details>

# %% [markdown]
# ### Q757. What is `Path` in FastAPI?
#
# - A) Path parameter validator
# - B) File path
# - C) Route
# - D) Import
#
# <details>
# <summary>Show Answer</summary>
#
# **Q757. A)** Validates path parameters.
#
# </details>

# %% [markdown]
# ### Q758. What does `json.loads` raise for invalid JSON?
#
# - A) json.JSONDecodeError
# - B) ValueError
# - C) TypeError
# - D) KeyError
#
# <details>
# <summary>Show Answer</summary>
#
# **Q758. A)** JSONDecodeError (subclass of ValueError).
#
# </details>

# %% [markdown]
# ### Q759. What is HTTP 403?
#
# - A) Forbidden
# - B) Unauthorized
# - C) Not found
# - D) Bad request
#
# <details>
# <summary>Show Answer</summary>
#
# **Q759. A)** 403 Forbidden.
#
# </details>

# %% [markdown]
# ### Q760. What does `url_for` in Flask do?
#
# - A) Generate URL for endpoint
# - B) Parse URL
# - C) Redirect
# - D) Validate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q760. A)** Reverse URL building.
#
# </details>

# %% [markdown]
# ### Q761. What is `Query` in FastAPI?
#
# - A) Query param validator
# - B) Database query
# - C) Search
# - D) Filter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q761. A)** Validates query parameters.
#
# </details>

# %% [markdown]
# ### Q762. What does `response.cookies` provide?
#
# - A) Cookie jar
# - B) Set-Cookie
# - C) Both
# - D) Session
#
# <details>
# <summary>Show Answer</summary>
#
# **Q762. A)** Dict-like to set cookies.
#
# </details>

# %% [markdown]
# ### Q763. What is HTTP 204?
#
# - A) No Content
# - B) OK
# - C) Created
# - D) Accepted
#
# <details>
# <summary>Show Answer</summary>
#
# **Q763. A)** 204 No Content for success, no body.
#
# </details>

# %% [markdown]
# ### Q764. What does `g` in Flask hold?
#
# - A) Request-scoped data
# - B) Global
# - C) Config
# - D) Session
#
# <details>
# <summary>Show Answer</summary>
#
# **Q764. A)** Request-scoped storage.
#
# </details>

# %% [markdown]
# ### Q765. What is `Body` in FastAPI?
#
# - A) Request body validator
# - B) Response body
# - C) HTML body
# - D) JSON only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q765. A)** Validates request body.
#
# </details>

# %% [markdown]
# ### Q766. What does `requests.get` timeout do?
#
# - A) Raise on slow response
# - B) Retry
# - C) Cancel
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q766. A)** Raises Timeout after N seconds.
#
# </details>

# %% [markdown]
# ### Q767. What is HTTP 302?
#
# - A) Temporary redirect
# - B) Permanent redirect
# - C) Found
# - D) Moved
#
# <details>
# <summary>Show Answer</summary>
#
# **Q767. A)** 302 Found (temp redirect).
#
# </details>

# %% [markdown]
# ### Q768. What does `flash(message)` do?
#
# - A) Store for next request
# - B) Print
# - C) Log
# - D) Return
#
# <details>
# <summary>Show Answer</summary>
#
# **Q768. A)** Stores message in session for template.
#
# </details>

# %% [markdown]
# ### Q769. What is `Header` in FastAPI?
#
# - A) Header validator
# - B) Response header
# - C) Request header
# - D) Cookie
#
# <details>
# <summary>Show Answer</summary>
#
# **Q769. A)** Extracts and validates headers.
#
# </details>

# %% [markdown]
# ### Q770. What does `json.dump` write to?
#
# - A) File-like object
# - B) String
# - C) Bytes
# - D) Path
#
# <details>
# <summary>Show Answer</summary>
#
# **Q770. A)** dump to file; dumps to string.
#
# </details>

# %% [markdown]
# ### Q771. What is HTTP 405?
#
# - A) Method not allowed
# - B) Not found
# - C) Conflict
# - D) Gone
#
# <details>
# <summary>Show Answer</summary>
#
# **Q771. A)** 405 Method Not Allowed.
#
# </details>

# %% [markdown]
# ### Q772. What does `session` in Flask use?
#
# - A) Signed cookie by default
# - B) Database
# - C) Memory
# - D) File
#
# <details>
# <summary>Show Answer</summary>
#
# **Q772. A)** Client-side session in cookie.
#
# </details>

# %% [markdown]
# ### Q773. What is SQLAlchemy Engine?
#
# - A) DB connection factory
# - B) Query builder
# - C) ORM
# - D) Migration
#
# <details>
# <summary>Show Answer</summary>
#
# **Q773. A)** Engine manages connections.
#
# </details>

# %% [markdown]
# ### Q774. What does `{% if %}` do in Jinja2?
#
# - A) Conditional block
# - B) Loop
# - C) Include
# - D) Extend
#
# <details>
# <summary>Show Answer</summary>
#
# **Q774. A)** Conditional rendering.
#
# </details>

# %% [markdown]
# ### Q775. What is HTTP 409?
#
# - A) Conflict
# - B) Gone
# - C) Length required
# - D) Precondition failed
#
# <details>
# <summary>Show Answer</summary>
#
# **Q775. A)** 409 Conflict.
#
# </details>

# %% [markdown]
# ### Q776. What does `abort(404)` do?
#
# - A) Raise 404 error
# - B) Return 404
# - C) Both
# - D) Log only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q776. C)** Raises exception, returns 404 response.
#
# </details>

# %% [markdown]
# ### Q777. What is `Cookie` in FastAPI?
#
# - A) Cookie parameter
# - B) Set cookie
# - C) Session
# - D) Header
#
# <details>
# <summary>Show Answer</summary>
#
# **Q777. A)** Extracts cookie from request.
#
# </details>

# %% [markdown]
# ### Q778. What does `requests` need for HTTPS?
#
# - A) Nothing extra usually
# - B) SSL cert
# - C) Verify=False only
# - D) Custom adapter
#
# <details>
# <summary>Show Answer</summary>
#
# **Q778. A)** Verifies certs by default.
#
# </details>

# %% [markdown]
# ### Q779. What is HTTP 422?
#
# - A) Unprocessable entity
# - B) Bad request
# - C) Validation error
# - D) Both A and C
#
# <details>
# <summary>Show Answer</summary>
#
# **Q779. D)** 422 for validation/semantic errors.
#
# </details>

# %% [markdown]
# ### Q780. What does `{% block %}` do?
#
# - A) Define template block
# - B) Block content
# - C) Include
# - D) Extend
#
# <details>
# <summary>Show Answer</summary>
#
# **Q780. A)** Defines overridable block.
#
# </details>

# %% [markdown]
# ### Q781. What is SQLAlchemy declarative_base?
#
# - A) Base for ORM models
# - B) DB base
# - C) Schema
# - D) Migration
#
# <details>
# <summary>Show Answer</summary>
#
# **Q781. A)** Base class for mapped classes.
#
# </details>

# %% [markdown]
# ### Q782. What does `{% include 'x.html' %}` do?
#
# - A) Include template
# - B) Import
# - C) Extend
# - D) Block
#
# <details>
# <summary>Show Answer</summary>
#
# **Q782. A)** Embeds another template.
#
# </details>

# %% [markdown]
# ### Q783. What is HTTP 429?
#
# - A) Too many requests
# - B) Upgrade required
# - C) Unavailable
# - D) Timeout
#
# <details>
# <summary>Show Answer</summary>
#
# **Q783. A)** 429 Rate limit exceeded.
#
# </details>

# %% [markdown]
# ### Q784. What does `request.form` contain?
#
# - A) Form data
# - B) JSON
# - C) Query
# - D) Headers
#
# <details>
# <summary>Show Answer</summary>
#
# **Q784. A)** POST form key-value pairs.
#
# </details>

# %% [markdown]
# ### Q785. What is `BackgroundTasks` in FastAPI?
#
# - A) Run after response
# - B) Async task
# - C) Thread pool
# - D) Queue
#
# <details>
# <summary>Show Answer</summary>
#
# **Q785. A)** Run tasks after sending response.
#
# </details>

# %% [markdown]
# ### Q786. What does `|safe` in Jinja2 do?
#
# - A) Mark as safe HTML
# - B) Escape
# - C) Filter
# - D) Validate
#
# <details>
# <summary>Show Answer</summary>
#
# **Q786. A)** Disable auto-escaping (use carefully).
#
# </details>

# %% [markdown]
# ### Q787. What is HTTP 503?
#
# - A) Service unavailable
# - B) Gateway timeout
# - C) Bad gateway
# - D) Internal error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q787. A)** 503 Service Unavailable.
#
# </details>

# %% [markdown]
# ### Q788. How does Flask store session data by default?
#
# - A) Signed cookie (client-side)
# - B) Server-side database
# - C) Redis only
# - D) File system
#
# <details>
# <summary>Show Answer</summary>
#
# **Q788. A)** Flask uses signed cookies for session by default.
#
# </details>

# %% [markdown]
# ### Q789. What does FastAPI's `response_model` parameter do?
#
# - A) Validates request body
# - B) Serializes and documents response schema
# - C) Sets Content-Type only
# - D) Caches response
#
# <details>
# <summary>Show Answer</summary>
#
# **Q789. B)** response_model serializes output and appears in OpenAPI docs.
#
# </details>

# %% [markdown]
# ### Q790. What does the Cache-Control HTTP header control?
#
# - A) Request body size
# - B) Authentication
# - C) Caching behavior (max-age, no-cache, etc.)
# - D) CORS policy
#
# <details>
# <summary>Show Answer</summary>
#
# **Q790. C)** Cache-Control directs how responses may be cached.
#
# </details>

# %% [markdown]
# ### Q791. What is CORS (Cross-Origin Resource Sharing)?
#
# - A) A database protocol
# - B) A caching strategy
# - C) A security feature
# - D) A mechanism allowing cross-origin HTTP requests
#
# <details>
# <summary>Show Answer</summary>
#
# **Q791. D)** CORS lets browsers make cross-origin requests when allowed by server.
#
# </details>

# %% [markdown]
# ### Q792. Which is a common REST API versioning strategy?
#
# - A) URL path (/api/v1/users)
# - B) Query param only
# - C) Header only
# - D) No versioning
#
# <details>
# <summary>Show Answer</summary>
#
# **Q792. A)** URL path versioning is widely used and explicit.
#
# </details>

# %% [markdown]
# ### Q793. How does GraphQL differ from REST?
#
# - A) GraphQL uses only GET
# - B) Client requests exact fields; single endpoint
# - C) REST has no schema
# - D) GraphQL cannot do mutations
#
# <details>
# <summary>Show Answer</summary>
#
# **Q793. B)** GraphQL lets clients specify fields; REST returns fixed resources.
#
# </details>

# %% [markdown]
# ### Q794. What are the main phases of a WebSocket connection?
#
# - A) Connect only
# - B) Request and response
# - C) HTTP upgrade, then bidirectional messaging, then close
# - D) Polling loop
#
# <details>
# <summary>Show Answer</summary>
#
# **Q794. C)** WebSocket upgrades from HTTP, then sends messages both ways until closed.
#
# </details>

# %% [markdown]
# ### Q795. What relationship types does SQLAlchemy support?
#
# - A) One-to-one only
# - B) Many-to-many only
# - C) One-to-one and one-to-many only
# - D) One-to-one, one-to-many, many-to-many
#
# <details>
# <summary>Show Answer</summary>
#
# **Q795. D)** SQLAlchemy supports relationship, backref, and association tables.
#
# </details>

# %% [markdown]
# ### Q796. What is database connection pooling?
#
# - A) Reusing a pool of connections instead of creating new ones
# - B) Storing queries
# - C) Caching results
# - D) Load balancing only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q796. A)** Pooling reuses connections to reduce overhead.
#
# </details>

# %% [markdown]
# ### Q797. How is API rate limiting typically implemented?
#
# - A) Client-side only
# - B) Token bucket, sliding window, or fixed window per client
# - C) Per-request encryption
# - D) Database triggers
#
# <details>
# <summary>Show Answer</summary>
#
# **Q797. B)** Rate limiting uses algorithms like token bucket or sliding window.
#
# </details>

# %% [markdown]
# ### Q798. Which are OAuth2 grant types?
#
# - A) GET and POST only
# - B) Authorization code and client credentials only
# - C) Authorization code, client credentials, password, implicit
# - D) JWT only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q798. C)** OAuth2 defines authorization code, client credentials, password, and implicit grants.
#
# </details>

# %% [markdown]
# ### Q799. How does HTTP/2 differ from HTTP/1.1?
#
# - A) HTTP/2 is slower
# - B) HTTP/2 uses plain text
# - C) HTTP/2 has no multiplexing
# - D) Multiplexing, header compression, binary framing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q799. D)** HTTP/2 multiplexes streams, compresses headers, uses binary framing.
#
# </details>

# %% [markdown]
# ### Q800. What are common API pagination patterns?
#
# - A) Offset/limit and cursor-based
# - B) Random access only
# - C) Full dump only
# - D) No pagination
#
# <details>
# <summary>Show Answer</summary>
#
# **Q800. A)** Offset/limit (page, size) and cursor-based (next_token) are common.
#
# </details>
