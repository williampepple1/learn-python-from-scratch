# %% [markdown]
# # Inheritance and Polymorphism
#
# Welcome! Inheritance lets classes reuse and extend behavior from parent classes. Polymorphism allows different types to be used interchangeably. This guide covers inheritance, `super()`, MRO, ABCs, duck typing, mixins, and composition.

# %% [markdown]
# ## Basic Inheritance
#
# Specify the parent class in parentheses. Child classes inherit attributes and methods.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return "..."

class Dog(Animal):
    def speak(self):
        return "woof!"

dog = Dog("Rex")
print(dog.name, dog.speak())

# %% [markdown]
# ## super()
#
# `super()` delegates to the parent class. Use it to call overridden methods and `__init__`.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

dog = Dog("Rex", "Labrador")
print(dog.name, dog.breed)

# %% [markdown]
# ## Method Resolution Order (MRO)
#
# Python uses C3 linearization for MRO. Use `__mro__` or `mro()` to inspect.

# %%
class A:
    pass

class B(A):
    pass

class C(A):
    pass

class D(B, C):
    pass

print(D.__mro__)
print([c.__name__ for c in D.mro()])

# %% [markdown]
# ## Abstract Base Classes (ABC)
#
# Use `abc` module to define abstract methods. Subclasses must implement them.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

class Rectangle(Shape):
    def __init__(self, w, h):
        self.w = w
        self.h = h

    def area(self):
        return self.w * self.h

    def perimeter(self):
        return 2 * (self.w + self.h)

r = Rectangle(3, 4)
print(r.area(), r.perimeter())
# s = Shape()  # TypeError: cannot instantiate

# %% [markdown]
# ## Duck Typing
#
# "If it walks like a duck and quacks like a duck, it's a duck." Python favors behavior over type.

# %%
def process(iterable):
    for item in iterable:
        print(item)

process([1, 2, 3])
process("hello")
process({"a": 1, "b": 2})

class CustomIter:
    def __iter__(self):
        return iter([1, 2, 3])

process(CustomIter())

# %% [markdown]
# ## Mixins
#
# Mixins are small classes that add behavior. They're not meant to stand alone.

# %%
class JsonMixin:
    def to_json(self):
        import json
        return json.dumps(self.__dict__)

class ReprMixin:
    def __repr__(self):
        return f"{self.__class__.__name__}({self.__dict__})"

class Person(JsonMixin, ReprMixin):
    def __init__(self, name, age):
        self.name = name
        self.age = age

p = Person("Alice", 30)
print(p)
print(p.to_json())

# %% [markdown]
# ## Composition vs Inheritance
#
# Composition: "has-a". Inheritance: "is-a". Prefer composition when it fits better.

# %%
class Engine:
    def start(self):
        return "Engine started"

class Car:
    def __init__(self):
        self.engine = Engine()  # Composition

    def start(self):
        return self.engine.start()

car = Car()
print(car.start())

# %% [markdown]
# ## isinstance and issubclass
#
# `isinstance(obj, cls)` checks if an object is an instance. `issubclass(sub, super)` checks inheritance.

# %%
class Animal:
    pass

class Dog(Animal):
    pass

dog = Dog()
print(isinstance(dog, Dog))
print(isinstance(dog, Animal))
print(issubclass(Dog, Animal))

# %% [markdown]
# ## Summary
#
# You've learned inheritance, `super()`, MRO, ABCs, duck typing, mixins, and composition. Choose the right tool: inheritance for "is-a", composition for "has-a", mixins for reusable behavior.
