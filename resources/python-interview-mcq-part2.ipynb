# %% [markdown]
# # 🐍 Python Interview MCQ — Part 2: Strings, Lists & Tuples (Q101–Q200)
#
# **1000 Multiple-Choice Questions for Python Interview Preparation**
#
# Each question has 4 options (A–D) with the correct answer and explanation immediately below.
#
# ---

# %% [markdown]
# ### Q101. What does `'hello'.upper()` return?
#
# - A) 'HELLO'
# - B) 'hello'
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q101. A)** upper() returns uppercase.
#
# </details>

# %% [markdown]
# ### Q102. What is `'  hi  '.strip()`?
#
# - A) '  hi  '
# - B) 'hi'
# - C) 'hi  '
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q102. B)** strip() removes leading/trailing whitespace.
#
# </details>

# %% [markdown]
# ### Q103. What does `'a,b,c'.split(',')` produce?
#
# - A) ['a','b','c']
# - B) 'abc'
# - C) ('a','b','c')
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q103. A)** split() returns list of substrings.
#
# </details>

# %% [markdown]
# ### Q104. What is `'hello'[1:4]`?
#
# - A) 'hel'
# - B) 'ell'
# - C) 'llo'
# - D) 'ell'
#
# <details>
# <summary>Show Answer</summary>
#
# **Q104. B)** Slicing [1:4] gives indices 1,2,3.
#
# </details>

# %% [markdown]
# ### Q105. What does `'hello'[-1]` return?
#
# - A) 'h'
# - B) 'o'
# - C) 'e'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q105. B)** Negative -1 is last character.
#
# </details>

# %% [markdown]
# ### Q106. What is `'ab' * 3`?
#
# - A) 'ababab'
# - B) 'ab3'
# - C) Error
# - D) 6
#
# <details>
# <summary>Show Answer</summary>
#
# **Q106. A)** String * n repeats the string.
#
# </details>

# %% [markdown]
# ### Q107. What does `'hello'.find('l')` return?
#
# - A) 2
# - B) 3
# - C) -1
# - D) 1
#
# <details>
# <summary>Show Answer</summary>
#
# **Q107. A)** find() returns index of first occurrence.
#
# </details>

# %% [markdown]
# ### Q108. What is `'hello'.replace('l','x')`?
#
# - A) 'hexxo'
# - B) 'hexo'
# - C) 'heo'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q108. A)** replace() replaces all by default.
#
# </details>

# %% [markdown]
# ### Q109. What does `'Hello'.lower()` return?
#
# - A) 'HELLO'
# - B) 'hello'
# - C) 'Hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q109. B)** lower() returns lowercase.
#
# </details>

# %% [markdown]
# ### Q110. What is `f'{2+3}'`?
#
# - A) '2+3'
# - B) '5'
# - C) 5
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q110. B)** f-strings evaluate expressions.
#
# </details>

# %% [markdown]
# ### Q111. What does `'hello'.startswith('he')` return?
#
# - A) True
# - B) False
# - C) 0
# - D) 1
#
# <details>
# <summary>Show Answer</summary>
#
# **Q111. A)** startswith() returns True for prefix match.
#
# </details>

# %% [markdown]
# ### Q112. What is `'hello'.capitalize()`?
#
# - A) 'Hello'
# - B) 'HELLO'
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q112. A)** capitalize() makes first char upper.
#
# </details>

# %% [markdown]
# ### Q113. What does `'  '.join(['a','b'])` produce?
#
# - A) 'a  b'
# - B) 'ab'
# - C) ['a','b']
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q113. A)** join() concatenates with separator.
#
# </details>

# %% [markdown]
# ### Q114. What is `r'\n'`?
#
# - A) Newline
# - B) Literal backslash-n
# - C) Error
# - D) ''
#
# <details>
# <summary>Show Answer</summary>
#
# **Q114. B)** Raw string: backslash is literal.
#
# </details>

# %% [markdown]
# ### Q115. What does `'hello'.count('l')` return?
#
# - A) 1
# - B) 2
# - C) 0
# - D) 5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q115. B)** count() returns occurrences.
#
# </details>

# %% [markdown]
# ### Q116. What is `[1,2,3] + [4,5]`?
#
# - A) [1,2,3,4,5]
# - B) [5,7,8]
# - C) Error
# - D) [1,2,3][4,5]
#
# <details>
# <summary>Show Answer</summary>
#
# **Q116. A)** List + concatenates.
#
# </details>

# %% [markdown]
# ### Q117. What does `[1,2,3].append(4)` return?
#
# - A) [1,2,3,4]
# - B) None
# - C) 4
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q117. B)** append() returns None.
#
# </details>

# %% [markdown]
# ### Q118. What is `[1,2,3][::-1]`?
#
# - A) [1,2,3]
# - B) [3,2,1]
# - C) Error
# - D) []
#
# <details>
# <summary>Show Answer</summary>
#
# **Q118. B)** [::-1] reverses.
#
# </details>

# %% [markdown]
# ### Q119. What does `(1,2) + (3,)` produce?
#
# - A) (1,2,3)
# - B) (4,2)
# - C) Error
# - D) (1,2)(3,)
#
# <details>
# <summary>Show Answer</summary>
#
# **Q119. A)** Tuple + concatenates.
#
# </details>

# %% [markdown]
# ### Q120. What is `a, b = 1, 2`?
#
# - A) Error
# - B) Tuple unpacking
# - C) Comparison
# - D) Tuple only
#
# <details>
# <summary>Show Answer</summary>
#
# **Q120. B)** Multiple assignment unpacks.
#
# </details>

# %% [markdown]
# ### Q121. What does `[x*2 for x in [1,2,3]]` produce?
#
# - A) [2,4,6]
# - B) [1,2,3]
# - C) Generator
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q121. A)** List comprehension doubles.
#
# </details>

# %% [markdown]
# ### Q122. What is `(1,)`?
#
# - A) 1
# - B) Single-element tuple
# - C) Error
# - D) Parentheses
#
# <details>
# <summary>Show Answer</summary>
#
# **Q122. B)** Trailing comma creates tuple.
#
# </details>

# %% [markdown]
# ### Q123. What does `[1,2,2,3].index(2)` return?
#
# - A) 1
# - B) 2
# - C) [1,2]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q123. A)** index() returns first occurrence.
#
# </details>

# %% [markdown]
# ### Q124. What is `'hello'[::2]`?
#
# - A) 'hlo'
# - B) 'hel'
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q124. A)** Step 2: every other char.
#
# </details>

# %% [markdown]
# ### Q125. What does `[1,2,3].pop()` return?
#
# - A) 1
# - B) 3
# - C) [1,2]
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q125. B)** pop() returns last element.
#
# </details>

# %% [markdown]
# ### Q126. What is `'hello'.encode()`?
#
# - A) 'hello'
# - B) b'hello'
# - C) [104,101,...]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q126. B)** encode() converts to bytes.
#
# </details>

# %% [markdown]
# ### Q127. What does `(1,2)[0]=3` do?
#
# - A) Sets to 3
# - B) TypeError
# - C) Creates new tuple
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q127. B)** Tuples are immutable.
#
# </details>

# %% [markdown]
# ### Q128. What is `[1,2,3].extend([4,5])`?
#
# - A) [1,2,3,4,5]
# - B) None
# - C) Error
# - D) [4,5]
#
# <details>
# <summary>Show Answer</summary>
#
# **Q128. B)** extend() returns None.
#
# </details>

# %% [markdown]
# ### Q129. What does `'hello'.islower()` return?
#
# - A) True
# - B) False
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q129. A)** islower() True for all lowercase.
#
# </details>

# %% [markdown]
# ### Q130. What is `'  hello  '.lstrip()`?
#
# - A) 'hello  '
# - B) '  hello'
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q130. A)** lstrip() removes leading space.
#
# </details>

# %% [markdown]
# ### Q131. What does `'hello'.rjust(10)` return?
#
# - A) '     hello'
# - B) 'hello     '
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q131. A)** rjust() pads on left.
#
# </details>

# %% [markdown]
# ### Q132. What is `[1,2,3].insert(0,0)`?
#
# - A) [0,1,2,3]
# - B) None
# - C) 0
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q132. B)** insert() returns None.
#
# </details>

# %% [markdown]
# ### Q133. What does `'hello'.partition('l')` return?
#
# - A) ('he','l','lo')
# - B) ['he','l','lo']
# - C) ('he','lo')
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q133. A)** partition() splits at first match.
#
# </details>

# %% [markdown]
# ### Q134. What is `'hello'.center(9)`?
#
# - A) '  hello  '
# - B) ' hello '
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q134. B)** center(9) pads to length 9.
#
# </details>

# %% [markdown]
# ### Q135. What does `[1,2,3].remove(2)` return?
#
# - A) 2
# - B) None
# - C) [1,3]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q135. B)** remove() returns None.
#
# </details>

# %% [markdown]
# ### Q136. What is `'hello'.swapcase()`?
#
# - A) 'HELLO'
# - B) 'hello'
# - C) 'hELLO'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q136. C)** swapcase() swaps case.
#
# </details>

# %% [markdown]
# ### Q137. What does `'hello'.title()` return?
#
# - A) 'Hello'
# - B) 'HELLO'
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q137. A)** title() capitalizes words.
#
# </details>

# %% [markdown]
# ### Q138. What is `[1,2,3].reverse()`?
#
# - A) [3,2,1]
# - B) None
# - C) reversed obj
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q138. B)** reverse() returns None.
#
# </details>

# %% [markdown]
# ### Q139. What does `'hello'.endswith('lo')` return?
#
# - A) True
# - B) False
# - C) 2
# - D) 5
#
# <details>
# <summary>Show Answer</summary>
#
# **Q139. A)** endswith() checks suffix.
#
# </details>

# %% [markdown]
# ### Q140. What is `'hello'.index('l')`?
#
# - A) 2
# - B) 3
# - C) -1
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q140. A)** index() returns first match.
#
# </details>

# %% [markdown]
# ### Q141. What does `[1,2,3].sort()` return?
#
# - A) [1,2,3]
# - B) None
# - C) sorted list
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q141. B)** sort() returns None.
#
# </details>

# %% [markdown]
# ### Q142. What is `'hello'.zfill(8)`?
#
# - A) '000hello'
# - B) 'hello000'
# - C) '   hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q142. A)** zfill() pads with zeros.
#
# </details>

# %% [markdown]
# ### Q143. What does `'hello'.split()` return?
#
# - A) ['hello']
# - B) ['h','e','l','l','o']
# - C) []
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q143. A)** split() no arg splits on whitespace.
#
# </details>

# %% [markdown]
# ### Q144. What is `[1,2,3].copy()`?
#
# - A) Shallow copy
# - B) Deep copy
# - C) Reference
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q144. A)** copy() creates shallow copy.
#
# </details>

# %% [markdown]
# ### Q145. What does `(1,2)==[1,2]` return?
#
# - A) True
# - B) False
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q145. B)** Different types.
#
# </details>

# %% [markdown]
# ### Q146. What is `'hello'.isalpha()`?
#
# - A) True
# - B) False
# - C) 5
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q146. A)** isalpha() True for letters only.
#
# </details>

# %% [markdown]
# ### Q147. What does `'123'.isdigit()` return?
#
# - A) True
# - B) False
# - C) 3
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q147. A)** isdigit() True for digits.
#
# </details>

# %% [markdown]
# ### Q148. What is `'hello'.isidentifier()`?
#
# - A) True
# - B) False
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q148. A)** Valid Python identifier.
#
# </details>

# %% [markdown]
# ### Q149. What does `'hello'.isprintable()` return?
#
# - A) True
# - B) False
# - C) 5
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q149. A)** isprintable() True for printable.
#
# </details>

# %% [markdown]
# ### Q150. What is `'hello'.isspace()`?
#
# - A) True
# - B) False
# - C) 0
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q150. B)** isspace() False for 'hello'.
#
# </details>

# %% [markdown]
# ### Q151. What does `'Hello'.istitle()` return?
#
# - A) True
# - B) False
# - C) 'Hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q151. A)** istitle() for title case.
#
# </details>

# %% [markdown]
# ### Q152. What is `'hello'.ljust(8)`?
#
# - A) 'hello   '
# - B) '   hello'
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q152. A)** ljust() pads on right.
#
# </details>

# %% [markdown]
# ### Q153. What does `'hello'.rsplit('l',1)` return?
#
# - A) ['he','o']
# - B) ['he','lo']
# - C) ['hel','o']
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q153. A)** rsplit maxsplit=1 from right.
#
# </details>

# %% [markdown]
# ### Q154. What is `'hello'.rpartition('l')`?
#
# - A) ('hel','l','o')
# - B) ('he','l','lo')
# - C) ('he','l','o')
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q154. A)** rpartition at last match.
#
# </details>

# %% [markdown]
# ### Q155. What does `'hello'.rstrip()` return?
#
# - A) 'hello'
# - B) ' hello'
# - C) 'hello '
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q155. A)** rstrip() removes trailing.
#
# </details>

# %% [markdown]
# ### Q156. What is `'hello'.splitlines()`?
#
# - A) ['hello']
# - B) ['h','e','l','l','o']
# - C) []
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q156. A)** No newlines: ['hello'].
#
# </details>

# %% [markdown]
# ### Q157. What does `'hello'.casefold()` return?
#
# - A) 'hello'
# - B) 'HELLO'
# - C) Aggressive lowercase
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q157. C)** casefold() more aggressive than lower().
#
# </details>

# %% [markdown]
# ### Q158. What is `[1,2,3]*2`?
#
# - A) [1,2,3,1,2,3]
# - B) [2,4,6]
# - C) Error
# - D) [1,2,3]
#
# <details>
# <summary>Show Answer</summary>
#
# **Q158. A)** List * n repeats.
#
# </details>

# %% [markdown]
# ### Q159. What does `'hello'.maketrans('el','ip')` return?
#
# - A) Translation dict
# - B) 'hippo'
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q159. A)** maketrans() creates translation table.
#
# </details>

# %% [markdown]
# ### Q160. What is `[].append(1) or []`?
#
# - A) [1]
# - B) []
# - C) None
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q160. B)** append returns None (falsy).
#
# </details>

# %% [markdown]
# ### Q161. What does `(1,2) is (1,2)` return?
#
# - A) True
# - B) False
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q161. B)** Different objects.
#
# </details>

# %% [markdown]
# ### Q162. What is `'hello'[0:100]`?
#
# - A) 'hello'
# - B) Error
# - C) ''
# - D) IndexError
#
# <details>
# <summary>Show Answer</summary>
#
# **Q162. A)** Slicing beyond length is OK.
#
# </details>

# %% [markdown]
# ### Q163. What does `[1,2,3].clear()` return?
#
# - A) []
# - B) None
# - C) [1,2,3]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q163. B)** clear() returns None.
#
# </details>

# %% [markdown]
# ### Q164. What is `'hello'.format()`?
#
# - A) 'hello'
# - B) Error
# - C) ''
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q164. A)** No placeholders: unchanged.
#
# </details>

# %% [markdown]
# ### Q165. What does `'{0} {1}'.format('a','b')` return?
#
# - A) 'a b'
# - B) 'b a'
# - C) Error
# - D) '0 1'
#
# <details>
# <summary>Show Answer</summary>
#
# **Q165. A)** Positional format.
#
# </details>

# %% [markdown]
# ### Q166. What is `'{x}'.format_map({'x':1})`?
#
# - A) '1'
# - B) 'x'
# - C) Error
# - D) 1
#
# <details>
# <summary>Show Answer</summary>
#
# **Q166. A)** format_map uses dict.
#
# </details>

# %% [markdown]
# ### Q167. What does `'hello'.__contains__('he')` return?
#
# - A) True
# - B) False
# - C) 2
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q167. A)** __contains__ for 'in'.
#
# </details>

# %% [markdown]
# ### Q168. What is `[1,2,3][-2]`?
#
# - A) 1
# - B) 2
# - C) 3
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q168. B)** Index -2 is second from end.
#
# </details>

# %% [markdown]
# ### Q169. What does `'hello'.__len__()` return?
#
# - A) 5
# - B) 4
# - C) len
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q169. A)** __len__ returns length.
#
# </details>

# %% [markdown]
# ### Q170. What is namedtuple?
#
# - A) Tuple only
# - B) List only
# - C) Attr and index access
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q170. C)** Named tuples support both.
#
# </details>

# %% [markdown]
# ### Q171. What does `[1,2,3][1:1]=[9]` do?
#
# - A) Inserts 9 at 1
# - B) Replaces 1
# - C) Error
# - D) Nothing
#
# <details>
# <summary>Show Answer</summary>
#
# **Q171. A)** Empty slice inserts.
#
# </details>

# %% [markdown]
# ### Q172. What is `'hello'.encode('utf-8')`?
#
# - A) 'hello'
# - B) b'hello'
# - C) bytes object
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q172. C)** encode returns bytes.
#
# </details>

# %% [markdown]
# ### Q173. What does `b'hello'.decode()` return?
#
# - A) 'hello'
# - B) b'hello'
# - C) bytes
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q173. A)** decode() to str.
#
# </details>

# %% [markdown]
# ### Q174. What is `[x for x in [1,2,3] if x>1]`?
#
# - A) [2,3]
# - B) [1,2,3]
# - C) [1]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q174. A)** Filtering comprehension.
#
# </details>

# %% [markdown]
# ### Q175. What does `[[1],[2]][0].append(3)` do?
#
# - A) [[1,3],[2]]
# - B) [[1],[2,3]]
# - C) Error
# - D) [[3],[2]]
#
# <details>
# <summary>Show Answer</summary>
#
# **Q175. A)** Modifies first sublist.
#
# </details>

# %% [markdown]
# ### Q176. What is `'hello'.join(['a','b'])`?
#
# - A) 'ahellob'
# - B) 'a'
# - C) Error
# - D) 'ab'
#
# <details>
# <summary>Show Answer</summary>
#
# **Q176. A)** join uses separator.
#
# </details>

# %% [markdown]
# ### Q177. What does `(1,)*3` produce?
#
# - A) (1,1,1)
# - B) (1,3)
# - C) Error
# - D) (1,)
#
# <details>
# <summary>Show Answer</summary>
#
# **Q177. A)** Tuple * repeats.
#
# </details>

# %% [markdown]
# ### Q178. What is `'hello'.replace('l','',1)`?
#
# - A) 'helo'
# - B) 'heo'
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q178. A)** Third arg limits replacements.
#
# </details>

# %% [markdown]
# ### Q179. What does `[1,2,3][-1:0:-1]` return?
#
# - A) [3,2]
# - B) [3,2,1]
# - C) []
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q179. A)** Reverse slice from end.
#
# </details>

# %% [markdown]
# ### Q180. What is `'hello'.find('x')`?
#
# - A) -1
# - B) 0
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q180. A)** find returns -1 if not found.
#
# </details>

# %% [markdown]
# ### Q181. What does `'hello'.rfind('l')` return?
#
# - A) 2
# - B) 3
# - C) -1
# - D) 1
#
# <details>
# <summary>Show Answer</summary>
#
# **Q181. B)** rfind last occurrence.
#
# </details>

# %% [markdown]
# ### Q182. What is `[1,2,3].pop(0)`?
#
# - A) 1
# - B) 3
# - C) [2,3]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q182. A)** pop(0) removes first.
#
# </details>

# %% [markdown]
# ### Q183. What does `'hello'.rindex('l')` return?
#
# - A) 2
# - B) 3
# - C) -1
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q183. B)** rindex last occurrence.
#
# </details>

# %% [markdown]
# ### Q184. What is `sorted([3,1,2], reverse=True)`?
#
# - A) [3,2,1]
# - B) [1,2,3]
# - C) [3,1,2]
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q184. A)** reverse=True descending.
#
# </details>

# %% [markdown]
# ### Q185. What does `[1,2,3].count(2)` return?
#
# - A) 1
# - B) 2
# - C) 0
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q185. A)** count() occurrences.
#
# </details>

# %% [markdown]
# ### Q186. What is `'hello'.split('l')`?
#
# - A) ['he','','o']
# - B) ['he','o']
# - C) ['hel','o']
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q186. A)** Split on 'l' gives empty between.
#
# </details>

# %% [markdown]
# ### Q187. What does `tuple([1,2,3])` return?
#
# - A) (1,2,3)
# - B) [1,2,3]
# - C) 1,2,3
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q187. A)** tuple() converts.
#
# </details>

# %% [markdown]
# ### Q188. What is `'hello'.isupper()`?
#
# - A) True
# - B) False
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q188. B)** isupper() False for lowercase.
#
# </details>

# %% [markdown]
# ### Q189. What does `[1,2,3][1:2]` return?
#
# - A) [2]
# - B) [1,2]
# - C) 2
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q189. A)** Slice [1:2] gets index 1.
#
# </details>

# %% [markdown]
# ### Q190. What is `'hello'.isdecimal()`?
#
# - A) True
# - B) False
# - C) 5
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q190. B)** isdecimal() False for letters.
#
# </details>

# %% [markdown]
# ### Q191. What does `[1,2,3]==[1,2,3]` return?
#
# - A) True
# - B) False
# - C) Error
# - D) None
#
# <details>
# <summary>Show Answer</summary>
#
# **Q191. A)** Equal lists.
#
# </details>

# %% [markdown]
# ### Q192. What is `'hello'.isnumeric()`?
#
# - A) True
# - B) False
# - C) 5
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q192. B)** isnumeric() False.
#
# </details>

# %% [markdown]
# ### Q193. What does `[1,2,3].__len__()` return?
#
# - A) 3
# - B) 2
# - C) len
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q193. A)** __len__ for len().
#
# </details>

# %% [markdown]
# ### Q194. What is `'hello'.__getitem__(0)`?
#
# - A) 'h'
# - B) 0
# - C) 'hello'
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q194. A)** __getitem__ for indexing.
#
# </details>

# %% [markdown]
# ### Q195. What does `[1,2,3].__iter__()` return?
#
# - A) list_iterator
# - B) [1,2,3]
# - C) 1
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q195. A)** __iter__ for iteration.
#
# </details>

# %% [markdown]
# ### Q196. What is `'hello'.__eq__('hello')`?
#
# - A) True
# - B) False
# - C) None
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q196. A)** __eq__ for ==.
#
# </details>

# %% [markdown]
# ### Q197. What does `[1,2,3].__contains__(2)` return?
#
# - A) True
# - B) False
# - C) 2
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q197. A)** __contains__ for 'in'.
#
# </details>

# %% [markdown]
# ### Q198. What is `'hello'.__repr__()`?
#
# - A) "'hello'"
# - B) 'hello'
# - C) repr
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q198. A)** __repr__ for repr().
#
# </details>

# %% [markdown]
# ### Q199. What does `[1,2,3].__reversed__()` return?
#
# - A) list_reverseiterator
# - B) [3,2,1]
# - C) reversed
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q199. A)** __reversed__ for reversed().
#
# </details>

# %% [markdown]
# ### Q200. What is `'hello'.__str__()`?
#
# - A) 'hello'
# - B) "'hello'"
# - C) str
# - D) Error
#
# <details>
# <summary>Show Answer</summary>
#
# **Q200. A)** __str__ for str().
#
# </details>
