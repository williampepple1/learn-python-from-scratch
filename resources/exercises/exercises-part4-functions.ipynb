# %% [markdown]
# # 🐍 Python Exercises — Part 4: Functions (E151–E200)
#
# Basic functions, lambda, map/filter/reduce, closures, recursion.

# %% [markdown]
# ### Exercise 151: Define Function
#
# Define function add(a,b) that returns a+b

# %%
def add(a, b):
    # YOUR CODE HERE

# %%
assert add(2, 3) == 5
print('✅ Exercise 151 passed!')

# %% [markdown]
# ### Exercise 152: Function with Return
#
# Define greet(name) returning 'Hello, {name}!'

# %%
def greet(name):
    # YOUR CODE HERE

# %%
assert greet('Alice') == 'Hello, Alice!'
print('✅ Exercise 152 passed!')

# %% [markdown]
# ### Exercise 153: Default Argument
#
# Define power(x, n=2) returning x**n. Default n=2

# %%
def power(x, n=2):
    # YOUR CODE HERE

# %%
assert power(3) == 9 and power(3, 3) == 27
print('✅ Exercise 153 passed!')

# %% [markdown]
# ### Exercise 154: Multiple Returns
#
# Define min_max(a,b) returning (min, max)

# %%
def min_max(a, b):
    # YOUR CODE HERE

# %%
assert min_max(5, 3) == (3, 5)
print('✅ Exercise 154 passed!')

# %% [markdown]
# ### Exercise 155: Variable Arguments *args
#
# Define sum_all(*args) returning sum of all arguments

# %%
def sum_all(*args):
    # YOUR CODE HERE

# %%
assert sum_all(1, 2, 3, 4) == 10
print('✅ Exercise 155 passed!')

# %% [markdown]
# ### Exercise 156: Keyword Arguments **kwargs
#
# Define print_kwargs(**kwargs) returning sorted list of keys

# %%
def print_kwargs(**kwargs):
    # YOUR CODE HERE

# %%
assert set(print_kwargs(a=1, b=2)) == {'a', 'b'}
print('✅ Exercise 156 passed!')

# %% [markdown]
# ### Exercise 157: Docstring
#
# Define double(x) with docstring 'Doubles x' returning 2*x

# %%
def double(x):
    # YOUR CODE HERE

# %%
assert double(5) == 10
print('✅ Exercise 157 passed!')

# %% [markdown]
# ### Exercise 158: Optional Parameter
#
# Define repeat(s, n=1) returning s repeated n times

# %%
def repeat(s, n=1):
    # YOUR CODE HERE

# %%
assert repeat('ab', 3) == 'ababab'
print('✅ Exercise 158 passed!')

# %% [markdown]
# ### Exercise 159: Type Hints
#
# Define add_typed(a: int, b: int) -> int

# %%
def add_typed(a: int, b: int) -> int:
    # YOUR CODE HERE

# %%
assert add_typed(1, 2) == 3
print('✅ Exercise 159 passed!')

# %% [markdown]
# ### Exercise 160: Early Return
#
# Define is_positive(n) returning True if n>0, False otherwise

# %%
def is_positive(n):
    # YOUR CODE HERE

# %%
assert is_positive(5) and not is_positive(-1)
print('✅ Exercise 160 passed!')

# %% [markdown]
# ### Exercise 161: Function Call
#
# Call add(10, 20) and store result in `result`

# %%
def add(a, b): return a + b
result = 
# YOUR CODE HERE

# %%
assert result == 30
print('✅ Exercise 161 passed!')

# %% [markdown]
# ### Exercise 162: Nested Function
#
# Define outer() that defines inner() and returns inner(). inner returns 42

# %%
def outer():
    # YOUR CODE HERE

# %%
assert outer()() == 42
print('✅ Exercise 162 passed!')

# %% [markdown]
# ### Exercise 163: Return None
#
# Define no_op() that explicitly returns None

# %%
def no_op():
    # YOUR CODE HERE

# %%
assert no_op() is None
print('✅ Exercise 163 passed!')

# %% [markdown]
# ### Exercise 164: Multiple Params
#
# Define area(w, h) returning w*h

# %%
def area(w, h):
    # YOUR CODE HERE

# %%
assert area(4, 5) == 20
print('✅ Exercise 164 passed!')

# %% [markdown]
# ### Exercise 165: Keyword Args Call
#
# Call power(base=2, exp=3) and store in `result`

# %%
def power(base, exp): return base ** exp
result = 
# YOUR CODE HERE

# %%
assert result == 8
print('✅ Exercise 165 passed!')

# %% [markdown]
# ### Exercise 166: Args and Kwargs
#
# Define wrapper(*args, **kwargs) that returns (len(args), len(kwargs))

# %%
def wrapper(*args, **kwargs):
    # YOUR CODE HERE

# %%
assert wrapper(1, 2, x=3) == (2, 1)
print('✅ Exercise 166 passed!')

# %% [markdown]
# ### Exercise 167: Mutable Default Fix
#
# Define append_to(element, lst=None). If lst is None, use []. Return lst with element appended

# %%
def append_to(element, lst=None):
    # YOUR CODE HERE

# %%
a = append_to(1); b = append_to(2); assert a == [1] and b == [2]
print('✅ Exercise 167 passed!')

# %% [markdown]
# ### Exercise 168: Unpacking Call
#
# Call add with *[3, 4]. Store in `result`

# %%
def add(a, b): return a + b
result = 
# YOUR CODE HERE

# %%
assert result == 7
print('✅ Exercise 168 passed!')

# %% [markdown]
# ### Exercise 169: Lambda Basics
#
# Create lambda that doubles x. Store in `double`

# %%
double = 
# YOUR CODE HERE

# %%
assert double(5) == 10
print('✅ Exercise 169 passed!')

# %% [markdown]
# ### Exercise 170: Lambda Two Args
#
# Create lambda for a+b. Store in `add`

# %%
add = 
# YOUR CODE HERE

# %%
assert add(2, 3) == 5
print('✅ Exercise 170 passed!')

# %% [markdown]
# ### Exercise 171: Map
#
# Use map to double each element of [1,2,3,4]. Store as list in `doubled`

# %%
nums = [1, 2, 3, 4]
doubled = 
# YOUR CODE HERE

# %%
assert doubled == [2, 4, 6, 8]
print('✅ Exercise 171 passed!')

# %% [markdown]
# ### Exercise 172: Filter
#
# Use filter to get even numbers from [1,2,3,4,5,6]. Store as list in `evens`

# %%
nums = [1, 2, 3, 4, 5, 6]
evens = 
# YOUR CODE HERE

# %%
assert evens == [2, 4, 6]
print('✅ Exercise 172 passed!')

# %% [markdown]
# ### Exercise 173: Reduce
#
# Use reduce (from functools) to compute product of [2,3,4]. Store in `product`

# %%
from functools import reduce
nums = [2, 3, 4]
product = 
# YOUR CODE HERE

# %%
assert product == 24
print('✅ Exercise 173 passed!')

# %% [markdown]
# ### Exercise 174: Sorted with Key
#
# Sort [('b',2),('a',1),('c',3)] by second element. Store in `sorted_pairs`

# %%
pairs = [('b', 2), ('a', 1), ('c', 3)]
sorted_pairs = 
# YOUR CODE HERE

# %%
assert sorted_pairs == [('a', 1), ('b', 2), ('c', 3)]
print('✅ Exercise 174 passed!')

# %% [markdown]
# ### Exercise 175: Higher-Order: Apply Twice
#
# Define apply_twice(f, x) that returns f(f(x)). Test with lambda x: x+1, 0 -> 2

# %%
def apply_twice(f, x):
    # YOUR CODE HERE

# %%
assert apply_twice(lambda x: x + 1, 0) == 2
print('✅ Exercise 175 passed!')

# %% [markdown]
# ### Exercise 176: Map with Lambda
#
# Square each element of [1,2,3,4] using map and lambda. Store in `squares`

# %%
nums = [1, 2, 3, 4]
squares = 
# YOUR CODE HERE

# %%
assert squares == [1, 4, 9, 16]
print('✅ Exercise 176 passed!')

# %% [markdown]
# ### Exercise 177: Filter with Lambda
#
# Filter strings with len > 2 from ['a','ab','abc','abcd']. Store in `long`

# %%
words = ['a', 'ab', 'abc', 'abcd']
long = 
# YOUR CODE HERE

# %%
assert long == ['abc', 'abcd']
print('✅ Exercise 177 passed!')

# %% [markdown]
# ### Exercise 178: Compose
#
# Define compose(f,g) returning lambda x: f(g(x)). Test: compose(lambda x:x*2, lambda x:x+1)(3)=8

# %%
def compose(f, g):
    # YOUR CODE HERE

# %%
assert compose(lambda x: x*2, lambda x: x+1)(3) == 8
print('✅ Exercise 178 passed!')

# %% [markdown]
# ### Exercise 179: Partial
#
# Use functools.partial to create double = partial(mul, 2). mul from operator

# %%
from functools import partial
from operator import mul
double = 
# YOUR CODE HERE

# %%
assert double(5) == 10
print('✅ Exercise 179 passed!')

# %% [markdown]
# ### Exercise 180: Any and All
#
# Return True if all nums are positive. nums=[1,2,3,4]

# %%
nums = [1, 2, 3, 4]
all_positive = 
# YOUR CODE HERE

# %%
assert all_positive == True
print('✅ Exercise 180 passed!')

# %% [markdown]
# ### Exercise 181: Closure: Counter
#
# Define make_counter() returning a function that returns 1,2,3,... on each call

# %%
def make_counter():
    # YOUR CODE HERE

# %%
c = make_counter(); assert c()==1 and c()==2 and c()==3
print('✅ Exercise 181 passed!')

# %% [markdown]
# ### Exercise 182: Closure: Multiplier
#
# Define make_multiplier(n) returning function that multiplies by n

# %%
def make_multiplier(n):
    # YOUR CODE HERE

# %%
assert make_multiplier(3)(4) == 12
print('✅ Exercise 182 passed!')

# %% [markdown]
# ### Exercise 183: Recursion: Factorial
#
# Define factorial(n) recursively. factorial(5)=120

# %%
def factorial(n):
    # YOUR CODE HERE

# %%
assert factorial(5) == 120
print('✅ Exercise 183 passed!')

# %% [markdown]
# ### Exercise 184: Recursion: Sum List
#
# Define sum_list(lst) recursively. sum_list([1,2,3])=6

# %%
def sum_list(lst):
    # YOUR CODE HERE

# %%
assert sum_list([1, 2, 3]) == 6
print('✅ Exercise 184 passed!')

# %% [markdown]
# ### Exercise 185: Recursion: Fibonacci
#
# Define fib(n) returning nth Fibonacci. fib(6)=8

# %%
def fib(n):
    # YOUR CODE HERE

# %%
assert fib(6) == 8
print('✅ Exercise 185 passed!')

# %% [markdown]
# ### Exercise 186: Recursion: Reverse String
#
# Define reverse(s) recursively. reverse('hello')='olleh'

# %%
def reverse(s):
    # YOUR CODE HERE

# %%
assert reverse('hello') == 'olleh'
print('✅ Exercise 186 passed!')

# %% [markdown]
# ### Exercise 187: Recursion: Power
#
# Define power(base, exp) recursively. power(2,3)=8

# %%
def power(base, exp):
    # YOUR CODE HERE

# %%
assert power(2, 3) == 8
print('✅ Exercise 187 passed!')

# %% [markdown]
# ### Exercise 188: Closure: Accumulator
#
# Define make_accumulator() returning a function. Each call adds to total and returns new total. acc(1) returns 1, acc(2) returns 3, acc(3) returns 6

# %%
def make_accumulator():
    # YOUR CODE HERE

# %%
acc = make_accumulator(); assert acc(1)==1 and acc(2)==3 and acc(3)==6
print('✅ Exercise 188 passed!')

# %% [markdown]
# ### Exercise 189: Function as Argument
#
# Define apply_func(f, x, y) returning f(x, y). Test with add

# %%
def apply_func(f, x, y):
    # YOUR CODE HERE

# %%
assert apply_func(lambda a,b: a+b, 3, 4) == 7
print('✅ Exercise 189 passed!')

# %% [markdown]
# ### Exercise 190: Return Function
#
# Define make_adder(n) returning function that adds n to its argument

# %%
def make_adder(n):
    # YOUR CODE HERE

# %%
assert make_adder(5)(3) == 8
print('✅ Exercise 190 passed!')

# %% [markdown]
# ### Exercise 191: Recursion: Count Down
#
# Define count_down(n) returning list [n,n-1,...,1]. count_down(3)=[3,2,1]

# %%
def count_down(n):
    # YOUR CODE HERE

# %%
assert count_down(3) == [3, 2, 1]
print('✅ Exercise 191 passed!')

# %% [markdown]
# ### Exercise 192: Recursion: Flatten
#
# Define flatten(lst) that flattens nested list. flatten([[1],[2,3]])=[1,2,3]

# %%
def flatten(lst):
    # YOUR CODE HERE

# %%
assert flatten([[1], [2, 3]]) == [1, 2, 3]
print('✅ Exercise 192 passed!')

# %% [markdown]
# ### Exercise 193: Max with Key
#
# Define max_by(lst, key) returning element with max key(elem). max_by([-1,2,-3], abs)= -3

# %%
def max_by(lst, key):
    # YOUR CODE HERE

# %%
assert max_by([-1, 2, -3], abs) == -3
print('✅ Exercise 193 passed!')

# %% [markdown]
# ### Exercise 194: Zip with Map
#
# Use map and zip: add corresponding elements of [1,2,3] and [4,5,6]. Result: [5,7,9]

# %%
a, b = [1, 2, 3], [4, 5, 6]
result = 
# YOUR CODE HERE

# %%
assert result == [5, 7, 9]
print('✅ Exercise 194 passed!')

# %% [markdown]
# ### Exercise 195: Nested Function Scope
#
# Define outer(x) with inner(y) returning x+y. outer(10)(5)=15

# %%
def outer(x):
    # YOUR CODE HERE

# %%
assert outer(10)(5) == 15
print('✅ Exercise 195 passed!')

# %% [markdown]
# ### Exercise 196: Recursion: Palindrome
#
# Define is_palindrome(s) recursively. is_palindrome('radar')=True

# %%
def is_palindrome(s):
    # YOUR CODE HERE

# %%
assert is_palindrome('radar') == True
print('✅ Exercise 196 passed!')

# %% [markdown]
# ### Exercise 197: Curry
#
# Define curry2(f) that curries a 2-arg function. curry2(add)(1)(2)=3

# %%
def curry2(f):
    # YOUR CODE HERE

# %%
assert curry2(lambda a,b: a+b)(1)(2) == 3
print('✅ Exercise 197 passed!')

# %% [markdown]
# ### Exercise 198: Memoization Pattern
#
# Define memoize(f) that caches results. Cached function returns same result for same args without recomputing

# %%
def memoize(f):
    cache = {}
    def inner(*args):
        # YOUR CODE HERE
    return inner
memo_double = memoize(lambda x: x*2)

# %%
assert memo_double(5) == 10 and memo_double(5) == 10
print('✅ Exercise 198 passed!')

# %% [markdown]
# ### Exercise 199: Pipe
#
# Define pipe(*funcs) returning lambda x: f1(f2(...(fn(x)))). pipe(lambda x:x+1, lambda x:x*2)(3)=8

# %%
def pipe(*funcs):
    # YOUR CODE HERE

# %%
assert pipe(lambda x: x+1, lambda x: x*2)(3) == 8
print('✅ Exercise 199 passed!')

# %% [markdown]
# ### Exercise 200: Function Composition Chain
#
# Define chain(f, g, h) returning lambda x: f(g(h(x))). chain(lambda x:x+1, lambda x:x*2, lambda x:x-1)(5)=11

# %%
def chain(f, g, h):
    # YOUR CODE HERE

# %%
assert chain(lambda x: x+1, lambda x: x*2, lambda x: x-1)(5) == 11
print('✅ Exercise 200 passed!')
