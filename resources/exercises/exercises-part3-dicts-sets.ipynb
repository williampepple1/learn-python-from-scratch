# %% [markdown]
# # 🐍 Python Exercises — Part 3: Dictionaries and Sets (E101–E150)
#
# Dict operations, set operations, mixed challenges.

# %% [markdown]
# ### Exercise 101: Create Dictionary
#
# Create dict {'a':1, 'b':2, 'c':3}. Store in `d`

# %%
d = 
# YOUR CODE HERE

# %%
assert d == {'a': 1, 'b': 2, 'c': 3}
print('✅ Exercise 101 passed!')

# %% [markdown]
# ### Exercise 102: Access Dict Value
#
# Get value for key 'b' from {'a':1,'b':2,'c':3}. Store in `val`

# %%
d = {'a': 1, 'b': 2, 'c': 3}
val = 
# YOUR CODE HERE

# %%
assert val == 2
print('✅ Exercise 102 passed!')

# %% [markdown]
# ### Exercise 103: Dict Get with Default
#
# Get 'x' from d with default 0. d={'a':1}. Store in `val`

# %%
d = {'a': 1}
val = 
# YOUR CODE HERE

# %%
assert val == 0
print('✅ Exercise 103 passed!')

# %% [markdown]
# ### Exercise 104: Merge Dictionaries
#
# Merge {'a':1} and {'b':2}. Result: {'a':1,'b':2}

# %%
d1, d2 = {'a': 1}, {'b': 2}
merged = 
# YOUR CODE HERE

# %%
assert merged == {'a': 1, 'b': 2}
print('✅ Exercise 104 passed!')

# %% [markdown]
# ### Exercise 105: Invert Dictionary
#
# Invert {'a':1,'b':2} to {1:'a',2:'b'}. Store in `inverted`

# %%
d = {'a': 1, 'b': 2}
inverted = 
# YOUR CODE HERE

# %%
assert inverted == {1: 'a', 2: 'b'}
print('✅ Exercise 105 passed!')

# %% [markdown]
# ### Exercise 106: Dict Keys and Values
#
# Get list of keys from {'x':1,'y':2}. Store in `keys`

# %%
d = {'x': 1, 'y': 2}
keys = 
# YOUR CODE HERE

# %%
assert set(keys) == {'x', 'y'} and len(keys) == 2
print('✅ Exercise 106 passed!')

# %% [markdown]
# ### Exercise 107: Group By First Letter
#
# Group words ['apple','ant','banana'] by first letter. Result: {'a':['apple','ant'],'b':['banana']}

# %%
words = ['apple', 'ant', 'banana']
grouped = 
# YOUR CODE HERE

# %%
assert grouped['a'] == ['apple', 'ant'] and grouped['b'] == ['banana']
print('✅ Exercise 107 passed!')

# %% [markdown]
# ### Exercise 108: Frequency Count
#
# Count frequency of each char in 'aabbbc'. Result: {'a':2,'b':3,'c':1}

# %%
s = 'aabbbc'
freq = 
# YOUR CODE HERE

# %%
assert freq == {'a': 2, 'b': 3, 'c': 1}
print('✅ Exercise 108 passed!')

# %% [markdown]
# ### Exercise 109: Nested Dict Access
#
# Get value at d['a']['b']. d={'a':{'b':42}}

# %%
d = {'a': {'b': 42}}
val = 
# YOUR CODE HERE

# %%
assert val == 42
print('✅ Exercise 109 passed!')

# %% [markdown]
# ### Exercise 110: Update Dict
#
# Add key 'c' with value 3 to {'a':1,'b':2}. Modify in place

# %%
d = {'a': 1, 'b': 2}
# YOUR CODE HERE

# %%
assert d == {'a': 1, 'b': 2, 'c': 3}
print('✅ Exercise 110 passed!')

# %% [markdown]
# ### Exercise 111: Dict Pop
#
# Remove key 'b' from d and get its value. d={'a':1,'b':2,'c':3}

# %%
d = {'a': 1, 'b': 2, 'c': 3}
removed = 
# YOUR CODE HERE

# %%
assert removed == 2 and 'b' not in d
print('✅ Exercise 111 passed!')

# %% [markdown]
# ### Exercise 112: Dict Comprehension
#
# Create {x: x**2 for x in [1,2,3]}. Result: {1:1,2:4,3:9}

# %%
squares = 
# YOUR CODE HERE

# %%
assert squares == {1: 1, 2: 4, 3: 9}
print('✅ Exercise 112 passed!')

# %% [markdown]
# ### Exercise 113: Filter Dict by Value
#
# Get keys where value > 2 from {'a':1,'b':3,'c':2,'d':5}. Result: ['b','d']

# %%
d = {'a': 1, 'b': 3, 'c': 2, 'd': 5}
keys_gt_2 = 
# YOUR CODE HERE

# %%
assert set(keys_gt_2) == {'b', 'd'}
print('✅ Exercise 113 passed!')

# %% [markdown]
# ### Exercise 114: Default Dict Pattern
#
# Count words: for each word in ['a','b','a','c','a'], increment count. Use dict

# %%
words = ['a', 'b', 'a', 'c', 'a']
counts = {}
# YOUR CODE HERE

# %%
assert counts == {'a': 3, 'b': 1, 'c': 1}
print('✅ Exercise 114 passed!')

# %% [markdown]
# ### Exercise 115: Dict Items Iteration
#
# Sum all values in {'a':10,'b':20,'c':30}. Store in `total`

# %%
d = {'a': 10, 'b': 20, 'c': 30}
total = 
# YOUR CODE HERE

# %%
assert total == 60
print('✅ Exercise 115 passed!')

# %% [markdown]
# ### Exercise 116: Two Dicts Same Keys
#
# Check if d1 and d2 have same keys. d1={'a':1}, d2={'a':2,'b':3} -> False

# %%
d1, d2 = {'a': 1}, {'a': 2, 'b': 3}
same_keys = 
# YOUR CODE HERE

# %%
assert same_keys == False
print('✅ Exercise 116 passed!')

# %% [markdown]
# ### Exercise 117: Dict from Two Lists
#
# Create dict from keys=['x','y'] and values=[1,2]. Result: {'x':1,'y':2}

# %%
keys = ['x', 'y']
values = [1, 2]
d = 
# YOUR CODE HERE

# %%
assert d == {'x': 1, 'y': 2}
print('✅ Exercise 117 passed!')

# %% [markdown]
# ### Exercise 118: Deep Copy Dict
#
# Create a copy of {'a':1,'b':2} that won't affect original when modified

# %%
d = {'a': 1, 'b': 2}
copy = 
# YOUR CODE HERE

# %%
assert copy == d and copy is not d
print('✅ Exercise 118 passed!')

# %% [markdown]
# ### Exercise 119: Sort Dict by Value
#
# Get list of keys sorted by value. d={'a':3,'b':1,'c':2}. Result: ['b','c','a']

# %%
d = {'a': 3, 'b': 1, 'c': 2}
sorted_keys = 
# YOUR CODE HERE

# %%
assert sorted_keys == ['b', 'c', 'a']
print('✅ Exercise 119 passed!')

# %% [markdown]
# ### Exercise 120: Nested Dict Update
#
# Set d['a']['x'] = 10. d={'a':{}}

# %%
d = {'a': {}}
# YOUR CODE HERE

# %%
assert d == {'a': {'x': 10}}
print('✅ Exercise 120 passed!')

# %% [markdown]
# ### Exercise 121: Set Creation
#
# Create set from [1,2,2,3,3,3]. Result: {1,2,3}

# %%
lst = [1, 2, 2, 3, 3, 3]
s = 
# YOUR CODE HERE

# %%
assert s == {1, 2, 3}
print('✅ Exercise 121 passed!')

# %% [markdown]
# ### Exercise 122: Set Intersection
#
# Intersection of {1,2,3} and {2,3,4}. Result: {2,3}

# %%
a, b = {1, 2, 3}, {2, 3, 4}
inter = 
# YOUR CODE HERE

# %%
assert inter == {2, 3}
print('✅ Exercise 122 passed!')

# %% [markdown]
# ### Exercise 123: Set Union
#
# Union of {1,2} and {2,3}. Result: {1,2,3}

# %%
a, b = {1, 2}, {2, 3}
union = 
# YOUR CODE HERE

# %%
assert union == {1, 2, 3}
print('✅ Exercise 123 passed!')

# %% [markdown]
# ### Exercise 124: Set Difference
#
# Elements in a but not b. a={1,2,3}, b={2,3}. Result: {1}

# %%
a, b = {1, 2, 3}, {2, 3}
diff = 
# YOUR CODE HERE

# %%
assert diff == {1}
print('✅ Exercise 124 passed!')

# %% [markdown]
# ### Exercise 125: Symmetric Difference
#
# Elements in either set but not both. a={1,2}, b={2,3}. Result: {1,3}

# %%
a, b = {1, 2}, {2, 3}
sym_diff = 
# YOUR CODE HERE

# %%
assert sym_diff == {1, 3}
print('✅ Exercise 125 passed!')

# %% [markdown]
# ### Exercise 126: Subset Check
#
# Return True if {1,2} is subset of {1,2,3}

# %%
a, b = {1, 2}, {1, 2, 3}
is_subset = 
# YOUR CODE HERE

# %%
assert is_subset == True
print('✅ Exercise 126 passed!')

# %% [markdown]
# ### Exercise 127: Set Add
#
# Add 4 to set {1,2,3}. Modify in place

# %%
s = {1, 2, 3}
# YOUR CODE HERE

# %%
assert s == {1, 2, 3, 4}
print('✅ Exercise 127 passed!')

# %% [markdown]
# ### Exercise 128: Set Remove Duplicates
#
# Remove duplicates from [1,2,2,3,1,4] using set. Preserve order via list

# %%
lst = [1, 2, 2, 3, 1, 4]
unique = 
# YOUR CODE HERE

# %%
assert unique == [1, 2, 3, 4]
print('✅ Exercise 128 passed!')

# %% [markdown]
# ### Exercise 129: Set Comprehension
#
# Create set of squares of [1,2,3,4]. Result: {1,4,9,16}

# %%
nums = [1, 2, 3, 4]
squares = 
# YOUR CODE HERE

# %%
assert squares == {1, 4, 9, 16}
print('✅ Exercise 129 passed!')

# %% [markdown]
# ### Exercise 130: Frozen Set
#
# Create frozenset from (1,2,3). Store in `fs`

# %%
fs = 
# YOUR CODE HERE

# %%
assert fs == frozenset({1, 2, 3})
print('✅ Exercise 130 passed!')

# %% [markdown]
# ### Exercise 131: Disjoint Check
#
# Return True if {1,2} and {3,4} have no common elements

# %%
a, b = {1, 2}, {3, 4}
disjoint = 
# YOUR CODE HERE

# %%
assert disjoint == True
print('✅ Exercise 131 passed!')

# %% [markdown]
# ### Exercise 132: Superset Check
#
# Return True if {1,2,3} is superset of {1,2}

# %%
a, b = {1, 2, 3}, {1, 2}
is_superset = 
# YOUR CODE HERE

# %%
assert is_superset == True
print('✅ Exercise 132 passed!')

# %% [markdown]
# ### Exercise 133: Set Length
#
# Get number of elements in {1,2,3,4,5}. Store in `size`

# %%
s = {1, 2, 3, 4, 5}
size = 
# YOUR CODE HERE

# %%
assert size == 5
print('✅ Exercise 133 passed!')

# %% [markdown]
# ### Exercise 134: Set Discard
#
# Discard 2 from {1,2,3}. Use discard (no error if missing)

# %%
s = {1, 2, 3}
# YOUR CODE HERE

# %%
assert s == {1, 3}
print('✅ Exercise 134 passed!')

# %% [markdown]
# ### Exercise 135: Set Update
#
# Add elements from [4,5,6] to {1,2,3}. Modify in place

# %%
s = {1, 2, 3}
# YOUR CODE HERE

# %%
assert s == {1, 2, 3, 4, 5, 6}
print('✅ Exercise 135 passed!')

# %% [markdown]
# ### Exercise 136: Word Count
#
# Count each word in 'the cat sat on the mat'. Store in dict `counts`

# %%
s = 'the cat sat on the mat'
counts = 
# YOUR CODE HERE

# %%
assert counts.get('the', 0) == 2 and counts.get('cat', 0) == 1
print('✅ Exercise 136 passed!')

# %% [markdown]
# ### Exercise 137: Student Grades
#
# Given {'Alice':85,'Bob':92,'Charlie':78}, return name of student with highest grade

# %%
grades = {'Alice': 85, 'Bob': 92, 'Charlie': 78}
top_student = 
# YOUR CODE HERE

# %%
assert top_student == 'Bob'
print('✅ Exercise 137 passed!')

# %% [markdown]
# ### Exercise 138: Inventory Merge
#
# Merge inventories: inv1={'a':2,'b':1}, inv2={'a':1,'c':3}. Sum values for same key. Result: {'a':3,'b':1,'c':3}

# %%
inv1, inv2 = {'a': 2, 'b': 1}, {'a': 1, 'c': 3}
merged = 
# YOUR CODE HERE

# %%
assert merged == {'a': 3, 'b': 1, 'c': 3}
print('✅ Exercise 138 passed!')

# %% [markdown]
# ### Exercise 139: Common Keys
#
# Find keys in both d1 and d2. d1={'a':1,'b':2}, d2={'a':0,'c':3}. Result: {'a'}

# %%
d1, d2 = {'a': 1, 'b': 2}, {'a': 0, 'c': 3}
common = 
# YOUR CODE HERE

# %%
assert common == {'a'}
print('✅ Exercise 139 passed!')

# %% [markdown]
# ### Exercise 140: Dict Values Sum
#
# Sum all values in nested dict {'a':{'x':1,'y':2},'b':{'x':3}}. Result: 6

# %%
d = {'a': {'x': 1, 'y': 2}, 'b': {'x': 3}}
total = 
# YOUR CODE HERE

# %%
assert total == 6
print('✅ Exercise 140 passed!')

# %% [markdown]
# ### Exercise 141: Set from String
#
# Get unique chars from 'hello'. Result: {'h','e','l','o'}

# %%
s = 'hello'
unique_chars = 
# YOUR CODE HERE

# %%
assert unique_chars == {'h', 'e', 'l', 'o'}
print('✅ Exercise 141 passed!')

# %% [markdown]
# ### Exercise 142: Key with Max Value
#
# Find key with max value in {'a':1,'b':3,'c':2}. Result: 'b'

# %%
d = {'a': 1, 'b': 3, 'c': 2}
max_key = 
# YOUR CODE HERE

# %%
assert max_key == 'b'
print('✅ Exercise 142 passed!')

# %% [markdown]
# ### Exercise 143: Flatten Dict Keys
#
# Get all keys from nested dict as list. d={'a':1,'b':{'c':2}}. Result: ['a','b','c'] or similar

# %%
d = {'a': 1, 'b': {'c': 2}}
keys = 
# YOUR CODE HERE

# %%
assert 'a' in keys and 'b' in keys and 'c' in keys
print('✅ Exercise 143 passed!')

# %% [markdown]
# ### Exercise 144: Set Operations Chain
#
# From a={1,2,3}, b={2,3,4}: (a|b) - (a&b). Result: {1,4}

# %%
a, b = {1, 2, 3}, {2, 3, 4}
result = 
# YOUR CODE HERE

# %%
assert result == {1, 4}
print('✅ Exercise 144 passed!')

# %% [markdown]
# ### Exercise 145: Dict Default
#
# For each key in ['a','b','a'], increment count. Start with {}. Result: {'a':2,'b':1}

# %%
keys = ['a', 'b', 'a']
counts = {}
# YOUR CODE HERE

# %%
assert counts == {'a': 2, 'b': 1}
print('✅ Exercise 145 passed!')

# %% [markdown]
# ### Exercise 146: List to Dict
#
# Convert [('a',1),('b',2)] to {'a':1,'b':2}

# %%
pairs = [('a', 1), ('b', 2)]
d = 
# YOUR CODE HERE

# %%
assert d == {'a': 1, 'b': 2}
print('✅ Exercise 146 passed!')

# %% [markdown]
# ### Exercise 147: Dict to List of Tuples
#
# Convert {'a':1,'b':2} to [('a',1),('b',2)]

# %%
d = {'a': 1, 'b': 2}
pairs = 
# YOUR CODE HERE

# %%
assert sorted(pairs) == [('a', 1), ('b', 2)]
print('✅ Exercise 147 passed!')

# %% [markdown]
# ### Exercise 148: Count Distinct
#
# Count distinct elements in [1,2,2,3,1,4]. Store in `distinct_count`

# %%
lst = [1, 2, 2, 3, 1, 4]
distinct_count = 
# YOUR CODE HERE

# %%
assert distinct_count == 4
print('✅ Exercise 148 passed!')

# %% [markdown]
# ### Exercise 149: Merge with Override
#
# Merge d2 into d1 (d2 overrides). d1={'a':1}, d2={'a':2,'b':3}. Result: {'a':2,'b':3}

# %%
d1, d2 = {'a': 1}, {'a': 2, 'b': 3}
merged = 
# YOUR CODE HERE

# %%
assert merged == {'a': 2, 'b': 3}
print('✅ Exercise 149 passed!')

# %% [markdown]
# ### Exercise 150: Set of Tuples
#
# Create set of tuples (i,i+1) for i in 1,2,3. Result: {(1,2),(2,3),(3,4)}

# %%
s = 
# YOUR CODE HERE

# %%
assert s == {(1, 2), (2, 3), (3, 4)}
print('✅ Exercise 150 passed!')
