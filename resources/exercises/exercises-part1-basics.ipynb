# %% [markdown]
# # 🐍 Python Exercises — Part 1: Basics (E1–E50)
#
# Variables, types, operators, control flow, loops.

# %% [markdown]
# ### Exercise 1: Declare a Variable
#
# Declare a variable named `greeting` and assign it the string 'Hello, World!'

# %%
greeting = 
# YOUR CODE HERE

# %%
assert greeting == 'Hello, World!'
print('✅ Exercise 1 passed!')

# %% [markdown]
# ### Exercise 2: Type Conversion
#
# Convert the string '42' to an integer and store it in `num`

# %%
num = 
# YOUR CODE HERE

# %%
assert num == 42 and type(num) == int
print('✅ Exercise 2 passed!')

# %% [markdown]
# ### Exercise 3: Arithmetic Operators
#
# Compute `a + b * 2` where a=5 and b=3. Store result in `result`

# %%
a, b = 5, 3
result = 
# YOUR CODE HERE

# %%
assert result == 11
print('✅ Exercise 3 passed!')

# %% [markdown]
# ### Exercise 4: String Concatenation
#
# Concatenate first='John' and last='Doe' with a space. Store in `full_name`

# %%
first, last = 'John', 'Doe'
full_name = 
# YOUR CODE HERE

# %%
assert full_name == 'John Doe'
print('✅ Exercise 4 passed!')

# %% [markdown]
# ### Exercise 5: Boolean AND
#
# Return True if both x and y are positive. x=5, y=-2

# %%
x, y = 5, -2
both_positive = 
# YOUR CODE HERE

# %%
assert both_positive == False
print('✅ Exercise 5 passed!')

# %% [markdown]
# ### Exercise 6: Boolean OR
#
# Return True if at least one of a or b is even. a=3, b=5

# %%
a, b = 3, 5
at_least_one_even = 
# YOUR CODE HERE

# %%
assert at_least_one_even == False
print('✅ Exercise 6 passed!')

# %% [markdown]
# ### Exercise 7: Comparison Operators
#
# Check if score (85) is >= 80. Store in `passed`

# %%
score = 85
passed = 
# YOUR CODE HERE

# %%
assert passed == True
print('✅ Exercise 7 passed!')

# %% [markdown]
# ### Exercise 8: None Check
#
# Return True if value is None, else False. value=None

# %%
value = None
is_none = 
# YOUR CODE HERE

# %%
assert is_none == True
print('✅ Exercise 8 passed!')

# %% [markdown]
# ### Exercise 9: Chained Comparison
#
# Check if n is between 1 and 10 inclusive. n=5

# %%
n = 5
in_range = 
# YOUR CODE HERE

# %%
assert in_range == True
print('✅ Exercise 9 passed!')

# %% [markdown]
# ### Exercise 10: Boolean Not
#
# Return the negation of flag. flag=True

# %%
flag = True
negated = 
# YOUR CODE HERE

# %%
assert negated == False
print('✅ Exercise 10 passed!')

# %% [markdown]
# ### Exercise 11: Simple If
#
# If age >= 18, set status='adult', else 'minor'. age=20

# %%
age = 20
status = 
# YOUR CODE HERE

# %%
assert status == 'adult'
print('✅ Exercise 11 passed!')

# %% [markdown]
# ### Exercise 12: If-Elif-Else
#
# Return 'child' if age<13, 'teen' if age<20, else 'adult'. age=15

# %%
age = 15
category = 
# YOUR CODE HERE

# %%
assert category == 'teen'
print('✅ Exercise 12 passed!')

# %% [markdown]
# ### Exercise 13: Multiple Conditions
#
# Return True if year is divisible by 4 and not by 100, or divisible by 400. year=2024

# %%
year = 2024
is_leap = 
# YOUR CODE HERE

# %%
assert is_leap == True
print('✅ Exercise 13 passed!')

# %% [markdown]
# ### Exercise 14: Ternary Expression
#
# Use ternary: max_val = a if a>b else b. a=7, b=12

# %%
a, b = 7, 12
max_val = 
# YOUR CODE HERE

# %%
assert max_val == 12
print('✅ Exercise 14 passed!')

# %% [markdown]
# ### Exercise 15: Nested If
#
# If x>0: if x>10 return 'large' else 'small'. Else 'non-positive'. x=5

# %%
x = 5
size = 
# YOUR CODE HERE

# %%
assert size == 'small'
print('✅ Exercise 15 passed!')

# %% [markdown]
# ### Exercise 16: Elif Chain
#
# Grade: A if >=90, B if >=80, C if >=70, D if >=60, else F. score=85

# %%
score = 85
grade = 
# YOUR CODE HERE

# %%
assert grade == 'B'
print('✅ Exercise 16 passed!')

# %% [markdown]
# ### Exercise 17: Truthiness Check
#
# Return 'empty' if items is falsy, else 'has_items'. items=[]

# %%
items = []
result = 
# YOUR CODE HERE

# %%
assert result == 'empty'
print('✅ Exercise 17 passed!')

# %% [markdown]
# ### Exercise 18: In Operator
#
# Check if 'a' is in the string 'banana'. Store in `contains`

# %%
contains = 
# YOUR CODE HERE

# %%
assert contains == True
print('✅ Exercise 18 passed!')

# %% [markdown]
# ### Exercise 19: Conditional Assignment
#
# Set sign to 1 if n>0, -1 if n<0, else 0. n=-5

# %%
n = -5
sign = 
# YOUR CODE HERE

# %%
assert sign == -1
print('✅ Exercise 19 passed!')

# %% [markdown]
# ### Exercise 20: Compound Condition
#
# Return True if password length >= 8 and has digit. password='secret12'

# %%
password = 'secret12'
valid = 
# YOUR CODE HERE

# %%
assert valid == True
print('✅ Exercise 20 passed!')

# %% [markdown]
# ### Exercise 21: For Loop Sum
#
# Sum all numbers from 1 to 10 using a for loop. Store in `total`

# %%
total = 0
# YOUR CODE HERE

# %%
assert total == 55
print('✅ Exercise 21 passed!')

# %% [markdown]
# ### Exercise 22: For Loop Over List
#
# Count how many items in [1,2,3,4,5] are greater than 3. Store in `count`

# %%
nums = [1, 2, 3, 4, 5]
count = 
# YOUR CODE HERE

# %%
assert count == 2
print('✅ Exercise 22 passed!')

# %% [markdown]
# ### Exercise 23: Range Basics
#
# Create a list of numbers from 0 to 4 using range(). Store in `numbers`

# %%
numbers = 
# YOUR CODE HERE

# %%
assert numbers == [0, 1, 2, 3, 4]
print('✅ Exercise 23 passed!')

# %% [markdown]
# ### Exercise 24: Range with Step
#
# Create list of even numbers from 2 to 10 using range. Store in `evens`

# %%
evens = 
# YOUR CODE HERE

# %%
assert evens == [2, 4, 6, 8, 10]
print('✅ Exercise 24 passed!')

# %% [markdown]
# ### Exercise 25: While Loop
#
# Use while to build list [1,2,3,4,5]. Start from 1, stop at 5

# %%
result = []
# YOUR CODE HERE

# %%
assert result == [1, 2, 3, 4, 5]
print('✅ Exercise 25 passed!')

# %% [markdown]
# ### Exercise 26: Loop with Index
#
# Build list of (index, value) for ['a','b','c']. Use enumerate

# %%
items = ['a', 'b', 'c']
pairs = 
# YOUR CODE HERE

# %%
assert pairs == [(0, 'a'), (1, 'b'), (2, 'c')]
print('✅ Exercise 26 passed!')

# %% [markdown]
# ### Exercise 27: Iterate String
#
# Count vowels (a,e,i,o,u) in 'hello'. Store in `vowel_count`

# %%
s = 'hello'
vowel_count = 
# YOUR CODE HERE

# %%
assert vowel_count == 2
print('✅ Exercise 27 passed!')

# %% [markdown]
# ### Exercise 28: Range Reverse
#
# Create list [5,4,3,2,1] using range

# %%
reversed_nums = 
# YOUR CODE HERE

# %%
assert reversed_nums == [5, 4, 3, 2, 1]
print('✅ Exercise 28 passed!')

# %% [markdown]
# ### Exercise 29: Loop Accumulator
#
# Compute product of [2,3,4]. Store in `product`

# %%
nums = [2, 3, 4]
product = 1
# YOUR CODE HERE

# %%
assert product == 24
print('✅ Exercise 29 passed!')

# %% [markdown]
# ### Exercise 30: Loop with Condition
#
# Sum only positive numbers from [-1, 2, -3, 4, 5]. Store in `pos_sum`

# %%
nums = [-1, 2, -3, 4, 5]
pos_sum = 
# YOUR CODE HERE

# %%
assert pos_sum == 11
print('✅ Exercise 30 passed!')

# %% [markdown]
# ### Exercise 31: Nested Loop
#
# Build 2x2 matrix [[1,2],[3,4]] using nested loops

# %%
matrix = []
# YOUR CODE HERE

# %%
assert matrix == [[1, 2], [3, 4]]
print('✅ Exercise 31 passed!')

# %% [markdown]
# ### Exercise 32: Break in Loop
#
# Find first index where nums[i] > 5. nums=[1,3,7,2,9]. Use break

# %%
nums = [1, 3, 7, 2, 9]
first_index = -1
# YOUR CODE HERE

# %%
assert first_index == 2
print('✅ Exercise 32 passed!')

# %% [markdown]
# ### Exercise 33: Continue in Loop
#
# Sum nums skipping negatives. nums=[1,-2,3,-4,5]

# %%
nums = [1, -2, 3, -4, 5]
sum_positive = 0
# YOUR CODE HERE

# %%
assert sum_positive == 9
print('✅ Exercise 33 passed!')

# %% [markdown]
# ### Exercise 34: Nested Loop Pattern
#
# Print-like: build list of 'i*j' for i in 1..2, j in 1..2. Result: ['1*1','1*2','2*1','2*2']

# %%
result = []
# YOUR CODE HERE

# %%
assert result == ['1*1', '1*2', '2*1', '2*2']
print('✅ Exercise 34 passed!')

# %% [markdown]
# ### Exercise 35: Loop with Else
#
# Find if 7 is in [1,2,3,4,5]. Use for-else: found=False, break sets found=True

# %%
nums = [1, 2, 3, 4, 5]
found = False
# YOUR CODE HERE

# %%
assert found == False
print('✅ Exercise 35 passed!')

# %% [markdown]
# ### Exercise 36: Double Loop Sum
#
# Sum all elements of [[1,2],[3,4]]. Use nested loops

# %%
matrix = [[1, 2], [3, 4]]
total = 0
# YOUR CODE HERE

# %%
assert total == 10
print('✅ Exercise 36 passed!')

# %% [markdown]
# ### Exercise 37: Early Exit
#
# Return first even number from [1,3,5,6,7] or None. Use loop with return/break

# %%
nums = [1, 3, 5, 6, 7]
first_even = None
# YOUR CODE HERE

# %%
assert first_even == 6
print('✅ Exercise 37 passed!')

# %% [markdown]
# ### Exercise 38: Loop Counter
#
# Count occurrences of 2 in [1,2,2,3,2,4]. Store in `count`

# %%
nums = [1, 2, 2, 3, 2, 4]
count = 0
# YOUR CODE HERE

# %%
assert count == 3
print('✅ Exercise 38 passed!')

# %% [markdown]
# ### Exercise 39: Pattern: Multiplication Table Row
#
# Build list [3,6,9,12] (3*1 through 3*4) using loop

# %%
row = []
# YOUR CODE HERE

# %%
assert row == [3, 6, 9, 12]
print('✅ Exercise 39 passed!')

# %% [markdown]
# ### Exercise 40: Loop with Range and Condition
#
# Build list of squares of even numbers from 0 to 8: [0,4,16,36,64]

# %%
squares = []
# YOUR CODE HERE

# %%
assert squares == [0, 4, 16, 36, 64]
print('✅ Exercise 40 passed!')

# %% [markdown]
# ### Exercise 41: Swap Variables
#
# Swap values of a and b. a=1, b=2. Result: a=2, b=1

# %%
a, b = 1, 2
# YOUR CODE HERE

# %%
assert a == 2 and b == 1
print('✅ Exercise 41 passed!')

# %% [markdown]
# ### Exercise 42: Multiple Assignment
#
# Unpack (10, 20, 30) into x, y, z

# %%
t = (10, 20, 30)
x, y, z = 
# YOUR CODE HERE

# %%
assert x == 10 and y == 20 and z == 30
print('✅ Exercise 42 passed!')

# %% [markdown]
# ### Exercise 43: Modulo Check
#
# Return True if n is divisible by 7. n=21

# %%
n = 21
divisible_by_7 = 
# YOUR CODE HERE

# %%
assert divisible_by_7 == True
print('✅ Exercise 43 passed!')

# %% [markdown]
# ### Exercise 44: Integer Division
#
# Compute how many times 3 fits into 10. Store in `times`

# %%
times = 
# YOUR CODE HERE

# %%
assert times == 3
print('✅ Exercise 44 passed!')

# %% [markdown]
# ### Exercise 45: Power Operator
#
# Compute 2**10. Store in `result`

# %%
result = 
# YOUR CODE HERE

# %%
assert result == 1024
print('✅ Exercise 45 passed!')

# %% [markdown]
# ### Exercise 46: Sum of Digits
#
# Sum digits of 123 (1+2+3). Store in `digit_sum`

# %%
n = 123
digit_sum = 
# YOUR CODE HERE

# %%
assert digit_sum == 6
print('✅ Exercise 46 passed!')

# %% [markdown]
# ### Exercise 47: Factorial Loop
#
# Compute 5! (5*4*3*2*1) using a loop. Store in `factorial`

# %%
n = 5
factorial = 1
# YOUR CODE HERE

# %%
assert factorial == 120
print('✅ Exercise 47 passed!')

# %% [markdown]
# ### Exercise 48: Fibonacci First N
#
# First 6 Fibonacci numbers: [1,1,2,3,5,8]. Store in `fib`

# %%
n = 6
fib = []
# YOUR CODE HERE

# %%
assert fib == [1, 1, 2, 3, 5, 8]
print('✅ Exercise 48 passed!')

# %% [markdown]
# ### Exercise 49: Prime Check
#
# Return True if n is prime. n=17

# %%
n = 17
is_prime = 
# YOUR CODE HERE

# %%
assert is_prime == True
print('✅ Exercise 49 passed!')

# %% [markdown]
# ### Exercise 50: GCD of Two Numbers
#
# Compute GCD of 48 and 18 using loop. Result: 6

# %%
a, b = 48, 18
gcd = 
# YOUR CODE HERE

# %%
assert gcd == 6
print('✅ Exercise 50 passed!')
