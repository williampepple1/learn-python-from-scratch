# %% [markdown]
# # 🐍 Python Exercises — Part 5: OOP and Classes (E201–E250)
#
# Classes, magic methods, inheritance, dataclasses.

# %% [markdown]
# ### Exercise 201: Create Class
#
# Define empty class Person

# %%
class Person:
    pass
# YOUR CODE HERE

# %%
p = Person(); assert p is not None
print('✅ Exercise 201 passed!')

# %% [markdown]
# ### Exercise 202: Class with __init__
#
# Define class Dog with __init__(self, name) storing name

# %%
class Dog:
    def __init__(self, name):
        # YOUR CODE HERE

# %%
d = Dog('Rex'); assert d.name == 'Rex'
print('✅ Exercise 202 passed!')

# %% [markdown]
# ### Exercise 203: Instance Method
#
# Define class Counter with increment(self) method that increments self.count

# %%
class Counter:
    def __init__(self):
        self.count = 0
    def increment(self):
        # YOUR CODE HERE

# %%
c = Counter(); c.increment(); c.increment(); assert c.count == 2
print('✅ Exercise 203 passed!')

# %% [markdown]
# ### Exercise 204: Multiple Attributes
#
# Define class Rectangle with __init__(self, width, height)

# %%
class Rectangle:
    def __init__(self, width, height):
        # YOUR CODE HERE

# %%
r = Rectangle(4, 5); assert r.width == 4 and r.height == 5
print('✅ Exercise 204 passed!')

# %% [markdown]
# ### Exercise 205: Method with Return
#
# Add area(self) method to Rectangle returning width*height

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        # YOUR CODE HERE

# %%
assert Rectangle(4, 5).area() == 20
print('✅ Exercise 205 passed!')

# %% [markdown]
# ### Exercise 206: Self Parameter
#
# Define class Greeter with greet(self, name) returning 'Hello, {name}'

# %%
class Greeter:
    def greet(self, name):
        # YOUR CODE HERE

# %%
assert Greeter().greet('Alice') == 'Hello, Alice'
print('✅ Exercise 206 passed!')

# %% [markdown]
# ### Exercise 207: Class Attribute
#
# Define class Config with class attribute VERSION = '1.0'

# %%
class Config:
    # YOUR CODE HERE

# %%
assert Config.VERSION == '1.0'
print('✅ Exercise 207 passed!')

# %% [markdown]
# ### Exercise 208: Instance vs Class
#
# Define class Box with instance attr value. Create Box(42), check value

# %%
class Box:
    def __init__(self, value):
        # YOUR CODE HERE

# %%
assert Box(42).value == 42
print('✅ Exercise 208 passed!')

# %% [markdown]
# ### Exercise 209: Method Chaining
#
# Define class Builder with add(self, x) returning self for chaining

# %%
class Builder:
    def __init__(self):
        self.items = []
    def add(self, x):
        # YOUR CODE HERE

# %%
b = Builder().add(1).add(2); assert b.items == [1, 2]
print('✅ Exercise 209 passed!')

# %% [markdown]
# ### Exercise 210: String Representation
#
# Define class Point with __str__(self) returning 'Point(x,y)'

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __str__(self):
        # YOUR CODE HERE

# %%
assert 'Point' in str(Point(1, 2)) and '1' in str(Point(1, 2))
print('✅ Exercise 210 passed!')

# %% [markdown]
# ### Exercise 211: __repr__
#
# Add __repr__ to Point returning 'Point(x, y)'

# %%
class Point:
    def __init__(self, x, y):
        self.x, self.y = x, y
    def __repr__(self):
        # YOUR CODE HERE

# %%
assert 'Point' in repr(Point(1, 2))
print('✅ Exercise 211 passed!')

# %% [markdown]
# ### Exercise 212: __len__
#
# Define class Stack with __len__(self) returning length of internal list

# %%
class Stack:
    def __init__(self):
        self._items = []
    def __len__(self):
        # YOUR CODE HERE

# %%
s = Stack(); s._items = [1,2,3]; assert len(s) == 3
print('✅ Exercise 212 passed!')

# %% [markdown]
# ### Exercise 213: __eq__
#
# Define class Point2 with __eq__ comparing x and y

# %%
class Point2:
    def __init__(self, x, y):
        self.x, self.y = x, y
    def __eq__(self, other):
        # YOUR CODE HERE

# %%
assert Point2(1, 2) == Point2(1, 2) and Point2(1, 2) != Point2(1, 3)
print('✅ Exercise 213 passed!')

# %% [markdown]
# ### Exercise 214: __add__
#
# Define class Vector with __add__(self, other) adding x and y components

# %%
class Vector:
    def __init__(self, x, y):
        self.x, self.y = x, y
    def __add__(self, other):
        # YOUR CODE HERE

# %%
assert (Vector(1, 2) + Vector(3, 4)).x == 4
print('✅ Exercise 214 passed!')

# %% [markdown]
# ### Exercise 215: __getitem__
#
# Define class MyList with __getitem__(self, i) for indexing

# %%
class MyList:
    def __init__(self, data):
        self.data = data
    def __getitem__(self, i):
        # YOUR CODE HERE

# %%
assert MyList([10, 20, 30])[1] == 20
print('✅ Exercise 215 passed!')

# %% [markdown]
# ### Exercise 216: Property
#
# Define class Circle with radius property and area property (read-only)

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius
    @property
    def area(self):
        # YOUR CODE HERE

# %%
import math; assert abs(Circle(1).area - math.pi) < 0.01
print('✅ Exercise 216 passed!')

# %% [markdown]
# ### Exercise 217: Property Setter
#
# Add setter for Circle.radius that validates radius > 0

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius
    @property
    def radius(self):
        return self._radius
    @radius.setter
    def radius(self, value):
        # YOUR CODE HERE

# %%
c = Circle(1); c.radius = 5; assert c.radius == 5
print('✅ Exercise 217 passed!')

# %% [markdown]
# ### Exercise 218: Inheritance
#
# Define class Animal with speak() returning 'sound'. Dog extends Animal, speak returns 'bark'

# %%
class Animal:
    def speak(self):
        return 'sound'
class Dog(Animal):
    def speak(self):
        # YOUR CODE HERE

# %%
assert Dog().speak() == 'bark'
print('✅ Exercise 218 passed!')

# %% [markdown]
# ### Exercise 219: super()
#
# Define class Vehicle with __init__(self, name). Car extends Vehicle, calls super().__init__

# %%
class Vehicle:
    def __init__(self, name):
        self.name = name
class Car(Vehicle):
    def __init__(self, name, wheels=4):
        # YOUR CODE HERE

# %%
c = Car('Tesla'); assert c.name == 'Tesla'
print('✅ Exercise 219 passed!')

# %% [markdown]
# ### Exercise 220: Polymorphism
#
# Define interface-like: Animal.speak(). Dog and Cat override. Call speak on each

# %%
class Animal:
    def speak(self):
        raise NotImplementedError
class Dog(Animal):
    def speak(self):
        return 'bark'
class Cat(Animal):
    def speak(self):
        return 'meow'
def make_sound(animal):
    # YOUR CODE HERE

# %%
assert make_sound(Dog()) == 'bark' and make_sound(Cat()) == 'meow'
print('✅ Exercise 220 passed!')

# %% [markdown]
# ### Exercise 221: Abstract Method
#
# Use ABC: define abstract class Shape with abstract area()

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Square(Shape):
    def __init__(self, side):
        self.side = side
    def area(self):
        # YOUR CODE HERE

# %%
assert Square(4).area() == 16
print('✅ Exercise 221 passed!')

# %% [markdown]
# ### Exercise 222: Multiple Inheritance
#
# Define class A with method a(), B with b(). C(A,B). c.a() and c.b() work

# %%
class A:
    def a(self): return 'A'
class B:
    def b(self): return 'B'
class C(A, B):
    pass
# YOUR CODE HERE

# %%
c = C(); assert c.a() == 'A' and c.b() == 'B'
print('✅ Exercise 222 passed!')

# %% [markdown]
# ### Exercise 223: isinstance
#
# Check if obj is instance of list. obj=[1,2,3]

# %%
obj = [1, 2, 3]
is_list = 
# YOUR CODE HERE

# %%
assert is_list == True
print('✅ Exercise 223 passed!')

# %% [markdown]
# ### Exercise 224: hasattr
#
# Check if obj has attribute 'append'. obj=[]

# %%
obj = []
has_append = 
# YOUR CODE HERE

# %%
assert has_append == True
print('✅ Exercise 224 passed!')

# %% [markdown]
# ### Exercise 225: getattr
#
# Get 'upper' attribute of 'hello' and call it. Store result in `result`

# %%
s = 'hello'
result = 
# YOUR CODE HERE

# %%
assert result == 'HELLO'
print('✅ Exercise 225 passed!')

# %% [markdown]
# ### Exercise 226: Dataclass
#
# Define dataclass Point with x and y fields

# %%
from dataclasses import dataclass

@dataclass
class Point:
    # YOUR CODE HERE

# %%
p = Point(1, 2); assert p.x == 1 and p.y == 2
print('✅ Exercise 226 passed!')

# %% [markdown]
# ### Exercise 227: Dataclass Default
#
# Define dataclass Config with name and enabled=True

# %%
from dataclasses import dataclass

@dataclass
class Config:
    # YOUR CODE HERE

# %%
c = Config('test'); assert c.enabled == True
print('✅ Exercise 227 passed!')

# %% [markdown]
# ### Exercise 228: Dataclass with Method
#
# Add distance(self, other) to Point dataclass

# %%
from dataclasses import dataclass
import math

@dataclass
class Point:
    x: float
    y: float
    def distance(self, other):
        # YOUR CODE HERE

# %%
assert abs(Point(0,0).distance(Point(3,4)) - 5) < 0.01
print('✅ Exercise 228 passed!')

# %% [markdown]
# ### Exercise 229: Class Method
#
# Define class Factory with @classmethod create(cls) returning cls()

# %%
class Factory:
    @classmethod
    def create(cls):
        # YOUR CODE HERE

# %%
f = Factory.create(); assert isinstance(f, Factory)
print('✅ Exercise 229 passed!')

# %% [markdown]
# ### Exercise 230: Static Method
#
# Define class Math with @staticmethod add(a,b) returning a+b

# %%
class Math:
    @staticmethod
    def add(a, b):
        # YOUR CODE HERE

# %%
assert Math.add(2, 3) == 5
print('✅ Exercise 230 passed!')

# %% [markdown]
# ### Exercise 231: Private Convention
#
# Define class Secret with _private_attr. Access it

# %%
class Secret:
    def __init__(self):
        self._private_attr = 42
# YOUR CODE HERE

# %%
s = Secret(); val = s._private_attr; assert val == 42
print('✅ Exercise 231 passed!')

# %% [markdown]
# ### Exercise 232: Name Mangling
#
# Define class A with __private. Access from method

# %%
class A:
    def __init__(self):
        self.__private = 10
    def get_private(self):
        # YOUR CODE HERE

# %%
assert A().get_private() == 10
print('✅ Exercise 232 passed!')

# %% [markdown]
# ### Exercise 233: Slots
#
# Define class SlotDemo with __slots__ = ['x','y']

# %%
class SlotDemo:
    __slots__ = ['x', 'y']
    def __init__(self, x, y):
        # YOUR CODE HERE

# %%
s = SlotDemo(1, 2); assert s.x == 1 and s.y == 2
print('✅ Exercise 233 passed!')

# %% [markdown]
# ### Exercise 234: Context Manager Protocol
#
# Define class Timer with __enter__ and __exit__

# %%
class Timer:
    def __enter__(self):
        return self
    def __exit__(self, *args):
        return False
# YOUR CODE HERE

# %%
with Timer() as t: pass; assert t is not None
print('✅ Exercise 234 passed!')

# %% [markdown]
# ### Exercise 235: Iterator Protocol
#
# Define class CountDown with __iter__ and __next__. CountDown(3) yields 3,2,1

# %%
class CountDown:
    def __init__(self, n):
        self.n = n
    def __iter__(self):
        return self
    def __next__(self):
        # YOUR CODE HERE

# %%
assert list(CountDown(3)) == [3, 2, 1]
print('✅ Exercise 235 passed!')

# %% [markdown]
# ### Exercise 236: Bank Account
#
# Define class BankAccount with balance, deposit(amount), withdraw(amount)

# %%
class BankAccount:
    def __init__(self):
        self.balance = 0
    def deposit(self, amount):
        # YOUR CODE HERE
    def withdraw(self, amount):
        # YOUR CODE HERE

# %%
a = BankAccount(); a.deposit(100); a.withdraw(30); assert a.balance == 70
print('✅ Exercise 236 passed!')

# %% [markdown]
# ### Exercise 237: Student Record
#
# Define class Student with name, grades list. Add add_grade, average methods

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.grades = []
    def add_grade(self, grade):
        # YOUR CODE HERE
    def average(self):
        # YOUR CODE HERE

# %%
s = Student('Alice'); s.add_grade(80); s.add_grade(90); assert s.average() == 85
print('✅ Exercise 237 passed!')

# %% [markdown]
# ### Exercise 238: Singleton Pattern
#
# Implement singleton: only one instance of class Logger exists

# %%
class Logger:
    _instance = None
    def __new__(cls):
        # YOUR CODE HERE

# %%
a, b = Logger(), Logger(); assert a is b
print('✅ Exercise 238 passed!')

# %% [markdown]
# ### Exercise 239: Composition
#
# Define class Engine and class Car that has an Engine

# %%
class Engine:
    def start(self):
        return 'started'
class Car:
    def __init__(self):
        self.engine = Engine()
    def start(self):
        # YOUR CODE HERE

# %%
assert Car().start() == 'started'
print('✅ Exercise 239 passed!')

# %% [markdown]
# ### Exercise 240: Strategy Pattern
#
# Define Strategy with execute(). Add AddStrategy, MultiplyStrategy. Context uses strategy

# %%
class AddStrategy:
    def execute(self, a, b): return a + b
class MultiplyStrategy:
    def execute(self, a, b): return a * b
class Context:
    def __init__(self, strategy):
        self.strategy = strategy
    def run(self, a, b):
        # YOUR CODE HERE

# %%
assert Context(AddStrategy()).run(2, 3) == 5 and Context(MultiplyStrategy()).run(2, 3) == 6
print('✅ Exercise 240 passed!')

# %% [markdown]
# ### Exercise 241: Dataclass Ordering
#
# Add order=True to Point dataclass. Compare Point(1,2) < Point(2,1)

# %%
from dataclasses import dataclass

@dataclass(order=True)
class Point:
    x: int
    y: int
# YOUR CODE HERE

# %%
assert Point(1, 2) < Point(2, 1)
print('✅ Exercise 241 passed!')

# %% [markdown]
# ### Exercise 242: Frozen Dataclass
#
# Define frozen dataclass ImmutablePoint

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class ImmutablePoint:
    # YOUR CODE HERE

# %%
p = ImmutablePoint(1, 2); assert p.x == 1
print('✅ Exercise 242 passed!')

# %% [markdown]
# ### Exercise 243: Dataclass asdict
#
# Use asdict on Point(1,2) dataclass

# %%
from dataclasses import dataclass, asdict

@dataclass
class Point:
    x: int
    y: int
# YOUR CODE HERE

# %%
d = asdict(Point(1, 2)); assert d == {'x': 1, 'y': 2}
print('✅ Exercise 243 passed!')

# %% [markdown]
# ### Exercise 244: Class Design: TodoItem
#
# Define TodoItem with title, done. Add toggle() method

# %%
class TodoItem:
    def __init__(self, title):
        self.title = title
        self.done = False
    def toggle(self):
        # YOUR CODE HERE

# %%
t = TodoItem('task'); t.toggle(); assert t.done == True
print('✅ Exercise 244 passed!')

# %% [markdown]
# ### Exercise 245: Class Design: ShoppingCart
#
# Define ShoppingCart with items, add(item), total()

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []
    def add(self, item):
        # YOUR CODE HERE
    def total(self):
        # YOUR CODE HERE

# %%
c = ShoppingCart(); c.add({'name':'a','price':10}); c.add({'name':'b','price':20}); assert c.total() == 30
print('✅ Exercise 245 passed!')

# %% [markdown]
# ### Exercise 246: __contains__
#
# Define class MyRange with __contains__(self, x) for 'x in myrange'

# %%
class MyRange:
    def __init__(self, start, end):
        self.start = start
        self.end = end
    def __contains__(self, x):
        # YOUR CODE HERE

# %%
r = MyRange(1, 5); assert 3 in r and 6 not in r
print('✅ Exercise 246 passed!')

# %% [markdown]
# ### Exercise 247: __bool__
#
# Define class Truthy with __bool__ returning True when value != 0

# %%
class Truthy:
    def __init__(self, value):
        self.value = value
    def __bool__(self):
        # YOUR CODE HERE

# %%
assert bool(Truthy(1)) and not bool(Truthy(0))
print('✅ Exercise 247 passed!')

# %% [markdown]
# ### Exercise 248: __call__
#
# Define class Multiplier with __call__(self, x) returning self.factor * x

# %%
class Multiplier:
    def __init__(self, factor):
        self.factor = factor
    def __call__(self, x):
        # YOUR CODE HERE

# %%
assert Multiplier(3)(4) == 12
print('✅ Exercise 248 passed!')

# %% [markdown]
# ### Exercise 249: __iter__ Generator
#
# Define class Range with __iter__ as generator yielding start to end

# %%
class Range:
    def __init__(self, start, end):
        self.start = start
        self.end = end
    def __iter__(self):
        # YOUR CODE HERE

# %%
assert list(Range(1, 4)) == [1, 2, 3]
print('✅ Exercise 249 passed!')

# %% [markdown]
# ### Exercise 250: Full OOP: Library
#
# Define class Book (title, author) and Library (books list, add_book, find_by_author)

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
class Library:
    def __init__(self):
        self.books = []
    def add_book(self, book):
        # YOUR CODE HERE
    def find_by_author(self, author):
        # YOUR CODE HERE

# %%
lib = Library(); lib.add_book(Book('A', 'X')); lib.add_book(Book('B', 'X')); assert len(lib.find_by_author('X')) == 2
print('✅ Exercise 250 passed!')
