# %% [markdown]
# # 🐍 Python Exercises — Part 2: Strings and Lists (E51–E100)
#
# String operations, list operations, tuples, mixed challenges.

# %% [markdown]
# ### Exercise 51: Reverse a String
#
# Reverse the string 'hello' and store in `reversed_s`

# %%
s = 'hello'
reversed_s = 
# YOUR CODE HERE

# %%
assert reversed_s == 'olleh'
print('✅ Exercise 51 passed!')

# %% [markdown]
# ### Exercise 52: Palindrome Check
#
# Return True if s is a palindrome. s='radar'

# %%
s = 'radar'
is_palindrome = 
# YOUR CODE HERE

# %%
assert is_palindrome == True
print('✅ Exercise 52 passed!')

# %% [markdown]
# ### Exercise 53: Count Character
#
# Count occurrences of 'l' in 'hello'. Store in `count`

# %%
s = 'hello'
char = 'l'
count = 
# YOUR CODE HERE

# %%
assert count == 2
print('✅ Exercise 53 passed!')

# %% [markdown]
# ### Exercise 54: Title Case
#
# Convert 'hello world' to title case. Store in `title_s`

# %%
s = 'hello world'
title_s = 
# YOUR CODE HERE

# %%
assert title_s == 'Hello World'
print('✅ Exercise 54 passed!')

# %% [markdown]
# ### Exercise 55: Strip Whitespace
#
# Remove leading/trailing spaces from '  python  '. Store in `cleaned`

# %%
s = '  python  '
cleaned = 
# YOUR CODE HERE

# %%
assert cleaned == 'python'
print('✅ Exercise 55 passed!')

# %% [markdown]
# ### Exercise 56: Replace Substring
#
# Replace all 'a' with 'o' in 'banana'. Store in `result`

# %%
s = 'banana'
result = 
# YOUR CODE HERE

# %%
assert result == 'bonono'
print('✅ Exercise 56 passed!')

# %% [markdown]
# ### Exercise 57: Split and Join
#
# Split 'a-b-c' by '-' then join with '.'. Store in `result`

# %%
s = 'a-b-c'
result = 
# YOUR CODE HERE

# %%
assert result == 'a.b.c'
print('✅ Exercise 57 passed!')

# %% [markdown]
# ### Exercise 58: String Slicing
#
# Extract chars from index 2 to 5 (excl) of 'python'. Store in `sub`

# %%
s = 'python'
sub = 
# YOUR CODE HERE

# %%
assert sub == 'tho'
print('✅ Exercise 58 passed!')

# %% [markdown]
# ### Exercise 59: Check Start/End
#
# Return True if s starts with 'py'. s='python'

# %%
s = 'python'
starts_py = 
# YOUR CODE HERE

# %%
assert starts_py == True
print('✅ Exercise 59 passed!')

# %% [markdown]
# ### Exercise 60: String Length
#
# Get length of 'hello world'. Store in `length`

# %%
s = 'hello world'
length = 
# YOUR CODE HERE

# %%
assert length == 11
print('✅ Exercise 60 passed!')

# %% [markdown]
# ### Exercise 61: Upper and Lower
#
# Convert 'Python' to uppercase, then take first 3 chars and convert to lowercase. Store in `result`

# %%
s = 'Python'
result = 
# YOUR CODE HERE

# %%
assert result == 'pyt'
print('✅ Exercise 61 passed!')

# %% [markdown]
# ### Exercise 62: Find Substring Index
#
# Find index of 'world' in 'hello world'. Store in `idx`

# %%
s = 'hello world'
idx = 
# YOUR CODE HERE

# %%
assert idx == 6
print('✅ Exercise 62 passed!')

# %% [markdown]
# ### Exercise 63: Count Words
#
# Count words in 'one two three'. Store in `word_count`

# %%
s = 'one two three'
word_count = 
# YOUR CODE HERE

# %%
assert word_count == 3
print('✅ Exercise 63 passed!')

# %% [markdown]
# ### Exercise 64: Remove Vowels
#
# Remove all vowels from 'hello'. Store in `result`

# %%
s = 'hello'
result = 
# YOUR CODE HERE

# %%
assert result == 'hll'
print('✅ Exercise 64 passed!')

# %% [markdown]
# ### Exercise 65: String Repetition
#
# Repeat 'ab' 3 times. Store in `result`

# %%
s = 'ab'
n = 3
result = 
# YOUR CODE HERE

# %%
assert result == 'ababab'
print('✅ Exercise 65 passed!')

# %% [markdown]
# ### Exercise 66: Flatten Nested List
#
# Flatten [[1,2],[3,4],[5]] to [1,2,3,4,5]. Store in `flat`

# %%
nested = [[1, 2], [3, 4], [5]]
flat = 
# YOUR CODE HERE

# %%
assert flat == [1, 2, 3, 4, 5]
print('✅ Exercise 66 passed!')

# %% [markdown]
# ### Exercise 67: Rotate List
#
# Rotate [1,2,3,4,5] left by 2. Result: [3,4,5,1,2]

# %%
lst = [1, 2, 3, 4, 5]
k = 2
rotated = 
# YOUR CODE HERE

# %%
assert rotated == [3, 4, 5, 1, 2]
print('✅ Exercise 67 passed!')

# %% [markdown]
# ### Exercise 68: Chunk List
#
# Split [1,2,3,4,5,6] into chunks of 2. Result: [[1,2],[3,4],[5,6]]

# %%
lst = [1, 2, 3, 4, 5, 6]
size = 2
chunks = 
# YOUR CODE HERE

# %%
assert chunks == [[1, 2], [3, 4], [5, 6]]
print('✅ Exercise 68 passed!')

# %% [markdown]
# ### Exercise 69: Deduplicate Preserving Order
#
# Remove duplicates from [1,2,2,3,1,4] preserving order. Result: [1,2,3,4]

# %%
lst = [1, 2, 2, 3, 1, 4]
unique = 
# YOUR CODE HERE

# %%
assert unique == [1, 2, 3, 4]
print('✅ Exercise 69 passed!')

# %% [markdown]
# ### Exercise 70: List Sum
#
# Sum all elements of [10, 20, 30]. Store in `total`

# %%
lst = [10, 20, 30]
total = 
# YOUR CODE HERE

# %%
assert total == 60
print('✅ Exercise 70 passed!')

# %% [markdown]
# ### Exercise 71: List Max and Min
#
# Find max and min of [3,1,4,1,5]. Store in `max_val`, `min_val`

# %%
lst = [3, 1, 4, 1, 5]
max_val = 
min_val = 
# YOUR CODE HERE

# %%
assert max_val == 5 and min_val == 1
print('✅ Exercise 71 passed!')

# %% [markdown]
# ### Exercise 72: Append and Extend
#
# Start with [1,2]. Append 3, then extend with [4,5]. Result: [1,2,3,4,5]

# %%
lst = [1, 2]
# YOUR CODE HERE

# %%
assert lst == [1, 2, 3, 4, 5]
print('✅ Exercise 72 passed!')

# %% [markdown]
# ### Exercise 73: List Slicing
#
# Get every 2nd element from [0,1,2,3,4,5]. Result: [0,2,4]

# %%
lst = [0, 1, 2, 3, 4, 5]
every_second = 
# YOUR CODE HERE

# %%
assert every_second == [0, 2, 4]
print('✅ Exercise 73 passed!')

# %% [markdown]
# ### Exercise 74: Reverse List
#
# Reverse [1,2,3,4,5] in place. Result: [5,4,3,2,1]

# %%
lst = [1, 2, 3, 4, 5]
# YOUR CODE HERE

# %%
assert lst == [5, 4, 3, 2, 1]
print('✅ Exercise 74 passed!')

# %% [markdown]
# ### Exercise 75: Insert at Index
#
# Insert 99 at index 2 in [1,2,3,4]. Result: [1,2,99,3,4]

# %%
lst = [1, 2, 3, 4]
# YOUR CODE HERE

# %%
assert lst == [1, 2, 99, 3, 4]
print('✅ Exercise 75 passed!')

# %% [markdown]
# ### Exercise 76: Remove Element
#
# Remove first occurrence of 2 from [1,2,3,2,4]. Result: [1,3,2,4]

# %%
lst = [1, 2, 3, 2, 4]
# YOUR CODE HERE

# %%
assert lst == [1, 3, 2, 4]
print('✅ Exercise 76 passed!')

# %% [markdown]
# ### Exercise 77: List Comprehension Squares
#
# Create list of squares of [1,2,3,4,5]. Result: [1,4,9,16,25]

# %%
nums = [1, 2, 3, 4, 5]
squares = 
# YOUR CODE HERE

# %%
assert squares == [1, 4, 9, 16, 25]
print('✅ Exercise 77 passed!')

# %% [markdown]
# ### Exercise 78: Filter Even Numbers
#
# Filter even numbers from [1,2,3,4,5,6]. Result: [2,4,6]

# %%
nums = [1, 2, 3, 4, 5, 6]
evens = 
# YOUR CODE HERE

# %%
assert evens == [2, 4, 6]
print('✅ Exercise 78 passed!')

# %% [markdown]
# ### Exercise 79: List Copy
#
# Create a shallow copy of [1,2,3]. Store in `copy` (modifying copy shouldn't affect original)

# %%
original = [1, 2, 3]
copy = 
# YOUR CODE HERE

# %%
assert copy == [1, 2, 3] and copy is not original
print('✅ Exercise 79 passed!')

# %% [markdown]
# ### Exercise 80: Merge Sorted Lists
#
# Merge sorted [1,3,5] and [2,4,6] into one sorted list. Result: [1,2,3,4,5,6]

# %%
a, b = [1, 3, 5], [2, 4, 6]
merged = 
# YOUR CODE HERE

# %%
assert merged == [1, 2, 3, 4, 5, 6]
print('✅ Exercise 80 passed!')

# %% [markdown]
# ### Exercise 81: Tuple Creation
#
# Create tuple (1, 2, 3) and store in `t`

# %%
t = 
# YOUR CODE HERE

# %%
assert t == (1, 2, 3)
print('✅ Exercise 81 passed!')

# %% [markdown]
# ### Exercise 82: Tuple Unpacking
#
# Unpack (10, 20) into variables a and b

# %%
t = (10, 20)
a, b = 
# YOUR CODE HERE

# %%
assert a == 10 and b == 20
print('✅ Exercise 82 passed!')

# %% [markdown]
# ### Exercise 83: Tuple Concatenation
#
# Concatenate (1,2) and (3,4). Result: (1,2,3,4)

# %%
t1, t2 = (1, 2), (3, 4)
combined = 
# YOUR CODE HERE

# %%
assert combined == (1, 2, 3, 4)
print('✅ Exercise 83 passed!')

# %% [markdown]
# ### Exercise 84: Tuple Index
#
# Get index of 3 in (1,2,3,4). Store in `idx`

# %%
t = (1, 2, 3, 4)
idx = 
# YOUR CODE HERE

# %%
assert idx == 2
print('✅ Exercise 84 passed!')

# %% [markdown]
# ### Exercise 85: Tuple to List
#
# Convert tuple (1,2,3) to list. Store in `lst`

# %%
t = (1, 2, 3)
lst = 
# YOUR CODE HERE

# %%
assert lst == [1, 2, 3]
print('✅ Exercise 85 passed!')

# %% [markdown]
# ### Exercise 86: Swap with Tuple
#
# Swap x and y using tuple unpacking. x=1, y=2

# %%
x, y = 1, 2
# YOUR CODE HERE

# %%
assert x == 2 and y == 1
print('✅ Exercise 86 passed!')

# %% [markdown]
# ### Exercise 87: Named Tuple Style
#
# Create a simple point as tuple (x,y). x=3, y=4. Store in `point`

# %%
x, y = 3, 4
point = 
# YOUR CODE HERE

# %%
assert point == (3, 4) and point[0] == 3
print('✅ Exercise 87 passed!')

# %% [markdown]
# ### Exercise 88: Tuple Count
#
# Count occurrences of 2 in (1,2,2,3,2). Store in `count`

# %%
t = (1, 2, 2, 3, 2)
count = 
# YOUR CODE HERE

# %%
assert count == 3
print('✅ Exercise 88 passed!')

# %% [markdown]
# ### Exercise 89: Tuple Slicing
#
# Get first 3 elements of (1,2,3,4,5). Result: (1,2,3)

# %%
t = (1, 2, 3, 4, 5)
first_three = 
# YOUR CODE HERE

# %%
assert first_three == (1, 2, 3)
print('✅ Exercise 89 passed!')

# %% [markdown]
# ### Exercise 90: Tuple Unpacking with *
#
# Unpack (1,2,3,4,5): first=1, rest=[2,3,4,5]

# %%
t = (1, 2, 3, 4, 5)
first, *rest = 
# YOUR CODE HERE

# %%
assert first == 1 and rest == [2, 3, 4, 5]
print('✅ Exercise 90 passed!')

# %% [markdown]
# ### Exercise 91: Anagram Check
#
# Return True if 'listen' and 'silent' are anagrams

# %%
s1, s2 = 'listen', 'silent'
is_anagram = 
# YOUR CODE HERE

# %%
assert is_anagram == True
print('✅ Exercise 91 passed!')

# %% [markdown]
# ### Exercise 92: Word Frequency
#
# Count frequency of each word in 'the cat and the dog'. Store in dict `freq`

# %%
s = 'the cat and the dog'
freq = 
# YOUR CODE HERE

# %%
assert freq.get('the', 0) == 2 and freq.get('cat', 0) == 1
print('✅ Exercise 92 passed!')

# %% [markdown]
# ### Exercise 93: Longest Word
#
# Find longest word in 'hello world python'. Store in `longest`

# %%
s = 'hello world python'
longest = 
# YOUR CODE HERE

# %%
assert longest == 'python'
print('✅ Exercise 93 passed!')

# %% [markdown]
# ### Exercise 94: List of Word Lengths
#
# Create list of word lengths for 'hi hello world'. Result: [2,5,5]

# %%
s = 'hi hello world'
lengths = 
# YOUR CODE HERE

# %%
assert lengths == [2, 5, 5]
print('✅ Exercise 94 passed!')

# %% [markdown]
# ### Exercise 95: Capitalize First Letters
#
# Capitalize first letter of each word in 'hello world'. Result: 'Hello World'

# %%
s = 'hello world'
result = 
# YOUR CODE HERE

# %%
assert result == 'Hello World'
print('✅ Exercise 95 passed!')

# %% [markdown]
# ### Exercise 96: Zip Lists
#
# Zip [1,2,3] and ['a','b','c'] into list of tuples. Result: [(1,'a'),(2,'b'),(3,'c')]

# %%
nums = [1, 2, 3]
letters = ['a', 'b', 'c']
zipped = 
# YOUR CODE HERE

# %%
assert zipped == [(1, 'a'), (2, 'b'), (3, 'c')]
print('✅ Exercise 96 passed!')

# %% [markdown]
# ### Exercise 97: Alternating List
#
# Interleave [1,3,5] and [2,4,6]. Result: [1,2,3,4,5,6]

# %%
a, b = [1, 3, 5], [2, 4, 6]
interleaved = 
# YOUR CODE HERE

# %%
assert interleaved == [1, 2, 3, 4, 5, 6]
print('✅ Exercise 97 passed!')

# %% [markdown]
# ### Exercise 98: String to List of Chars
#
# Convert 'abc' to ['a','b','c']

# %%
s = 'abc'
chars = 
# YOUR CODE HERE

# %%
assert chars == ['a', 'b', 'c']
print('✅ Exercise 98 passed!')

# %% [markdown]
# ### Exercise 99: List to String
#
# Join ['a','b','c'] with ''. Result: 'abc'

# %%
lst = ['a', 'b', 'c']
result = 
# YOUR CODE HERE

# %%
assert result == 'abc'
print('✅ Exercise 99 passed!')

# %% [markdown]
# ### Exercise 100: First and Last
#
# Get first and last elements of [10,20,30,40]. Store in `first`, `last`

# %%
lst = [10, 20, 30, 40]
first = 
last = 
# YOUR CODE HERE

# %%
assert first == 10 and last == 40
print('✅ Exercise 100 passed!')
