# %% [markdown]
# # 🐍 Python Exercises — Part 6: File I/O and Exceptions (E251–E300)
#
# Practice exercises with progressive difficulty.

# %% [markdown]
# ### Exercise 251: Read File Contents
#
# Write a function read_file(path) that returns the entire contents of a text file as a string.

# %%
def read_file(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t251.txt','w').write('hello world'); assert read_file('_t251.txt')=='hello world'; open('_t251e.txt','w').write(''); assert read_file('_t251e.txt')==''
print("✅ Exercise 251 passed!")

# %% [markdown]
# ### Exercise 252: Write to File
#
# Write a function write_file(path, content) that writes content to a file, overwriting if it exists.

# %%
def write_file(path, content):
    # YOUR CODE HERE
    pass

# %%
# Test
write_file('_t252.txt','test'); assert open('_t252.txt').read()=='test'; write_file('_t252.txt','x'); assert open('_t252.txt').read()=='x'
print("✅ Exercise 252 passed!")

# %% [markdown]
# ### Exercise 253: Append to File
#
# Write a function append_to_file(path, content) that appends content to a file.

# %%
def append_to_file(path, content):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t253.txt','w').write('x'); append_to_file('_t253.txt','y'); assert open('_t253.txt').read()=='xy'
print("✅ Exercise 253 passed!")

# %% [markdown]
# ### Exercise 254: Count Lines
#
# Write a function count_lines(path) that returns the number of lines in a file.

# %%
def count_lines(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t254.txt','w').write('a\nb\nc'); assert count_lines('_t254.txt')==3
print("✅ Exercise 254 passed!")

# %% [markdown]
# ### Exercise 255: Read Lines
#
# Write a function read_lines(path) that returns a list of lines (without trailing newlines).

# %%
def read_lines(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t255.txt','w').write('a\nb'); assert read_lines('_t255.txt')==['a','b']
print("✅ Exercise 255 passed!")

# %% [markdown]
# ### Exercise 256: Read First N Lines
#
# Write a function read_first_n(path, n) that returns the first n lines of a file.

# %%
def read_first_n(path, n):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t256.txt','w').write('1\n2\n3\n4'); assert read_first_n('_t256.txt',2)==['1','2']
print("✅ Exercise 256 passed!")

# %% [markdown]
# ### Exercise 257: Read Last N Lines
#
# Write a function read_last_n(path, n) that returns the last n lines of a file.

# %%
def read_last_n(path, n):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t257.txt','w').write('a\nb\nc'); assert read_last_n('_t257.txt',2)==['b','c']
print("✅ Exercise 257 passed!")

# %% [markdown]
# ### Exercise 258: Word Count in File
#
# Write a function word_count(path) that returns the total number of words in a file.

# %%
def word_count(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t258.txt','w').write('hello world foo'); assert word_count('_t258.txt')==3
print("✅ Exercise 258 passed!")

# %% [markdown]
# ### Exercise 259: Extract Words
#
# Write a function extract_words(path) that returns a list of all words (lowercase, no punctuation) from a file.

# %%
def extract_words(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t259.txt','w').write('Hello, World!'); assert set(extract_words('_t259.txt'))=={'hello','world'}
print("✅ Exercise 259 passed!")

# %% [markdown]
# ### Exercise 260: File Exists
#
# Write a function file_exists(path) that returns True if the file exists.

# %%
def file_exists(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t260.txt','w').write('x'); assert file_exists('_t260.txt'); assert not file_exists('_nonexistent_xyz_12345')
print("✅ Exercise 260 passed!")

# %% [markdown]
# ### Exercise 261: Copy File
#
# Write a function copy_file(src, dst) that copies src to dst.

# %%
def copy_file(src, dst):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t261a.txt','w').write('x'); copy_file('_t261a.txt','_t261b.txt'); assert open('_t261b.txt').read()=='x'
print("✅ Exercise 261 passed!")

# %% [markdown]
# ### Exercise 262: Reverse Lines
#
# Write a function reverse_lines(path) that writes the file's lines in reverse order to the same file.

# %%
def reverse_lines(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t262.txt','w').write('a\nb\nc'); reverse_lines('_t262.txt'); assert open('_t262.txt').read()=='c\nb\na\n'
print("✅ Exercise 262 passed!")

# %% [markdown]
# ### Exercise 263: Remove Empty Lines
#
# Write a function remove_empty_lines(path) that removes empty lines from a file in-place.

# %%
def remove_empty_lines(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t263.txt','w').write('a\n\nb\n'); remove_empty_lines('_t263.txt'); assert open('_t263.txt').read()=='a\nb\n'
print("✅ Exercise 263 passed!")

# %% [markdown]
# ### Exercise 264: Merge Files
#
# Write a function merge_files(paths, output_path) that concatenates all files into output_path.

# %%
def merge_files(paths, output_path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t264a.txt','w').write('a'); open('_t264b.txt','w').write('b'); merge_files(['_t264a.txt','_t264b.txt'],'_t264o.txt'); assert open('_t264o.txt').read()=='ab'
print("✅ Exercise 264 passed!")

# %% [markdown]
# ### Exercise 265: Line Numbers
#
# Write a function add_line_numbers(path) that prepends line numbers (1, 2, 3...) to each line.

# %%
def add_line_numbers(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t265.txt','w').write('a\nb'); add_line_numbers('_t265.txt'); assert '1: a' in open('_t265.txt').read()
print("✅ Exercise 265 passed!")

# %% [markdown]
# ### Exercise 266: Safe Division
#
# Write a function safe_divide(a, b) that returns a/b or None if b is 0.

# %%
def safe_divide(a, b):
    # YOUR CODE HERE
    pass

# %%
# Test
assert safe_divide(10,2)==5; assert safe_divide(1,0) is None
print("✅ Exercise 266 passed!")

# %% [markdown]
# ### Exercise 267: Parse Integer
#
# Write a function parse_int(s) that returns int(s) or None if s is not a valid integer.

# %%
def parse_int(s):
    # YOUR CODE HERE
    pass

# %%
# Test
assert parse_int('42')==42; assert parse_int('x') is None
print("✅ Exercise 267 passed!")

# %% [markdown]
# ### Exercise 268: Get Value from Dict
#
# Write a function get_value(d, key, default=None) that returns d[key] or default if KeyError.

# %%
def get_value(d, key, default=None):
    # YOUR CODE HERE
    pass

# %%
# Test
assert get_value({'a':1},'a')==1; assert get_value({},'a',99)==99
print("✅ Exercise 268 passed!")

# %% [markdown]
# ### Exercise 269: Custom Exception
#
# Define a custom exception ValidationError and a function validate_positive(n) that raises it if n<=0.

# %%
class ValidationError(Exception):
    pass
def validate_positive(n):
    # YOUR CODE HERE
    pass

# %%
# Test
validate_positive(1); e=0; exec('try:\n validate_positive(-1)\nexcept ValidationError: e=1'); assert e==1
print("✅ Exercise 269 passed!")

# %% [markdown]
# ### Exercise 270: Reraise with Context
#
# Write a function process(data) that catches ValueError and raises RuntimeError with the original as cause.

# %%
def process(data):
    # YOUR CODE HERE
    pass

# %%
# Test
try: process('x')
except RuntimeError as e: assert e.__cause__ is not None
print("✅ Exercise 270 passed!")

# %% [markdown]
# ### Exercise 271: Try Multiple
#
# Write a function try_convert(s) that tries int(s), then float(s), then returns s.

# %%
def try_convert(s):
    # YOUR CODE HERE
    pass

# %%
# Test
assert try_convert('5')==5; assert try_convert('3.14')==3.14; assert try_convert('hi')=='hi'
print("✅ Exercise 271 passed!")

# %% [markdown]
# ### Exercise 272: Finally Cleanup
#
# Write a function with_cleanup(fn) that calls fn() and returns its result, but always prints 'cleanup' in finally.

# %%
def with_cleanup(fn):
    # YOUR CODE HERE
    pass

# %%
# Test
import io; from contextlib import redirect_stdout; b=io.StringIO(); list(redirect_stdout(b)(with_cleanup)(lambda:1)); assert 'cleanup' in b.getvalue()
print("✅ Exercise 272 passed!")

# %% [markdown]
# ### Exercise 273: Exception Message
#
# Write a function get_exception_message(exc) that returns str(exc) for any exception.

# %%
def get_exception_message(exc):
    # YOUR CODE HERE
    pass

# %%
# Test
assert 'division' in get_exception_message(ValueError('division')) or 'division' in str(ValueError('division'))
print("✅ Exercise 273 passed!")

# %% [markdown]
# ### Exercise 274: Retry on Exception
#
# Write a function retry(fn, max_attempts=3) that retries fn until it succeeds or max_attempts reached.

# %%
def retry(fn, max_attempts=3):
    # YOUR CODE HERE
    pass

# %%
# Test
assert retry(lambda: 42)==42
class _R: n=0
def _flaky():
    _R.n+=1
    if _R.n<2: raise ValueError()
    return 99
assert retry(_flaky)==99 and _R.n==3
print("✅ Exercise 274 passed!")

# %% [markdown]
# ### Exercise 275: Catch Specific
#
# Write a function handle_errors(fn) that catches ValueError and TypeError, returns 'handled', else reraises.

# %%
def handle_errors(fn):
    # YOUR CODE HERE
    pass

# %%
# Test
assert handle_errors(lambda: (_ for _ in ()).throw(ValueError))=='handled'
print("✅ Exercise 275 passed!")

# %% [markdown]
# ### Exercise 276: Assert with Message
#
# Write a function assert_positive(n) that raises ValueError with message 'n must be positive' if n<=0.

# %%
def assert_positive(n):
    # YOUR CODE HERE
    pass

# %%
# Test
assert_positive(1); try: assert_positive(0); raise SystemExit
except ValueError as e: assert 'positive' in str(e)
print("✅ Exercise 276 passed!")

# %% [markdown]
# ### Exercise 277: Context Manager Exception
#
# Write a context manager SafeOpen that yields a file and suppresses IOError, returning None.

# %%
from contextlib import contextmanager
@contextmanager
def SafeOpen(path):
    # YOUR CODE HERE
    pass

# %%
# Test
r=None
with SafeOpen('_nonexist_xyz_123') as f: r=f
assert r is None
print("✅ Exercise 277 passed!")

# %% [markdown]
# ### Exercise 278: Chain Exceptions
#
# Write a function wrap_error(fn) that catches any exception and raises RuntimeError from the original.

# %%
def wrap_error(fn):
    # YOUR CODE HERE
    pass

# %%
# Test
try: wrap_error(lambda: 1/0)
except RuntimeError as e: assert e.__cause__ is not None
print("✅ Exercise 278 passed!")

# %% [markdown]
# ### Exercise 279: Log and Reraise
#
# Write a function log_errors(fn) that catches exceptions, prints them, and reraises.

# %%
def log_errors(fn):
    # YOUR CODE HERE
    pass

# %%
# Test
import io; from contextlib import redirect_stderr; b=io.StringIO(); list(redirect_stderr(b)(lambda: log_errors(lambda: 1/0)()) if 0 else []); True
print("✅ Exercise 279 passed!")

# %% [markdown]
# ### Exercise 280: Exception Hierarchy
#
# Define NotPositiveError(ValueError) and validate(n) that raises it for n<=0.

# %%
class NotPositiveError(ValueError):
    pass
def validate(n):
    # YOUR CODE HERE
    pass

# %%
# Test
validate(1); try: validate(0)
except NotPositiveError: pass
except: raise
print("✅ Exercise 280 passed!")

# %% [markdown]
# ### Exercise 281: Read CSV
#
# Write a function read_csv(path) that returns a list of dicts (header row as keys).

# %%
def read_csv(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t281.csv','w').write('a,b\n1,2\n3,4'); r=read_csv('_t281.csv'); assert r[0]=={'a':'1','b':'2'}
print("✅ Exercise 281 passed!")

# %% [markdown]
# ### Exercise 282: Write CSV
#
# Write a function write_csv(path, rows, headers) that writes rows as CSV.

# %%
def write_csv(path, rows, headers):
    # YOUR CODE HERE
    pass

# %%
# Test
write_csv('_t282.csv',[{'a':'1','b':'2'}],['a','b']); assert '1,2' in open('_t282.csv').read()
print("✅ Exercise 282 passed!")

# %% [markdown]
# ### Exercise 283: Parse CSV Line
#
# Write a function parse_csv_line(line) that splits a CSV line (handling quoted commas).

# %%
def parse_csv_line(line):
    # YOUR CODE HERE
    pass

# %%
# Test
assert parse_csv_line('a,b,c')==['a','b','c']; assert parse_csv_line('"a,b",c')==['a,b','c']
print("✅ Exercise 283 passed!")

# %% [markdown]
# ### Exercise 284: Read JSON
#
# Write a function read_json(path) that loads and returns JSON from a file.

# %%
def read_json(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t284.json','w').write('{"x":1}'); assert read_json('_t284.json')=={'x':1}
print("✅ Exercise 284 passed!")

# %% [markdown]
# ### Exercise 285: Write JSON
#
# Write a function write_json(path, data) that writes data as JSON to a file.

# %%
def write_json(path, data):
    # YOUR CODE HERE
    pass

# %%
# Test
write_json('_t285.json',{'a':1}); assert read_json('_t285.json')=={'a':1}
print("✅ Exercise 285 passed!")

# %% [markdown]
# ### Exercise 286: JSON Lines
#
# Write a function read_jsonl(path) that reads one JSON object per line.

# %%
def read_jsonl(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t286.jsonl','w').write('{"a":1}\n{"b":2}'); assert read_jsonl('_t286.jsonl')==[{'a':1},{'b':2}]
print("✅ Exercise 286 passed!")

# %% [markdown]
# ### Exercise 287: Write JSONL
#
# Write a function write_jsonl(path, items) that writes one JSON object per line.

# %%
def write_jsonl(path, items):
    # YOUR CODE HERE
    pass

# %%
# Test
write_jsonl('_t287.jsonl',[{'x':1},{'y':2}]); assert read_jsonl('_t287.jsonl')==[{'x':1},{'y':2}]
print("✅ Exercise 287 passed!")

# %% [markdown]
# ### Exercise 288: CSV to Dict
#
# Write a function csv_to_dict(path) that returns a dict mapping first column to rest of row.

# %%
def csv_to_dict(path):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t288.csv','w').write('k,v\na,1\nb,2'); assert csv_to_dict('_t288.csv')['a']==['1']
print("✅ Exercise 288 passed!")

# %% [markdown]
# ### Exercise 289: Filter CSV
#
# Write a function filter_csv(path, key, value) that returns rows where column key equals value.

# %%
def filter_csv(path, key, value):
    # YOUR CODE HERE
    pass

# %%
# Test
open('_t289.csv','w').write('a,b\n1,x\n2,x'); assert len(filter_csv('_t289.csv','b','x'))==2
print("✅ Exercise 289 passed!")

# %% [markdown]
# ### Exercise 290: Merge JSON
#
# Write a function merge_json(paths) that loads multiple JSON files and merges into one dict.

# %%
def merge_json(paths):
    # YOUR CODE HERE
    pass

# %%
# Test
write_json('_t290a.json',{'a':1}); write_json('_t290b.json',{'b':2}); assert merge_json(['_t290a.json','_t290b.json'])=={'a':1,'b':2}
print("✅ Exercise 290 passed!")

# %% [markdown]
# ### Exercise 291: Context Manager File
#
# Write a context manager open_file(path) that yields the file and closes it.

# %%
from contextlib import contextmanager
@contextmanager
def open_file(path):
    # YOUR CODE HERE
    pass

# %%
# Test
with open_file('test.txt') as f: c=f.read()
assert isinstance(c, str)
print("✅ Exercise 291 passed!")

# %% [markdown]
# ### Exercise 292: Temp File
#
# Write a context manager temp_file() that creates a temp file, yields path, and deletes it on exit.

# %%
from contextlib import contextmanager
import tempfile
@contextmanager
def temp_file():
    # YOUR CODE HERE
    pass

# %%
# Test
import os
with temp_file() as p: open(p,'w').write('x'); assert open(p).read()=='x'
assert not os.path.exists(p)
print("✅ Exercise 292 passed!")

# %% [markdown]
# ### Exercise 293: Path Exists
#
# Write a function path_exists(p) using pathlib that returns True if path exists.

# %%
from pathlib import Path
def path_exists(p):
    # YOUR CODE HERE
    pass

# %%
# Test
assert path_exists('.'); assert path_exists(Path('.'))
print("✅ Exercise 293 passed!")

# %% [markdown]
# ### Exercise 294: List Files
#
# Write a function list_files(dir_path) that returns names of files (not dirs) in directory.

# %%
def list_files(dir_path):
    # YOUR CODE HERE
    pass

# %%
# Test
import os; assert isinstance(list_files('.'), list)
print("✅ Exercise 294 passed!")

# %% [markdown]
# ### Exercise 295: Get Extension
#
# Write a function get_extension(path) that returns the file extension (e.g. '.txt').

# %%
def get_extension(path):
    # YOUR CODE HERE
    pass

# %%
# Test
assert get_extension('a.txt')=='.txt'; assert get_extension('a.b.c')=='.c'
print("✅ Exercise 295 passed!")

# %% [markdown]
# ### Exercise 296: Change Extension
#
# Write a function change_extension(path, new_ext) that returns path with new extension.

# %%
def change_extension(path, new_ext):
    # YOUR CODE HERE
    pass

# %%
# Test
assert change_extension('a.txt','.json')=='a.json'
print("✅ Exercise 296 passed!")

# %% [markdown]
# ### Exercise 297: Parent Path
#
# Write a function parent_path(path) that returns the parent directory of path using pathlib.

# %%
def parent_path(path):
    # YOUR CODE HERE
    pass

# %%
# Test
assert 'resources' in str(parent_path('resources/exercises/x.ipynb'))
print("✅ Exercise 297 passed!")

# %% [markdown]
# ### Exercise 298: Ensure Dir
#
# Write a function ensure_dir(path) that creates the directory (and parents) if it doesn't exist.

# %%
def ensure_dir(path):
    # YOUR CODE HERE
    pass

# %%
# Test
import os; ensure_dir('_test_dir/sub'); assert os.path.isdir('_test_dir/sub'); os.rmdir('_test_dir/sub'); os.rmdir('_test_dir')
print("✅ Exercise 298 passed!")

# %% [markdown]
# ### Exercise 299: Walk and Collect
#
# Write a function collect_extensions(dir_path) that returns set of all file extensions in dir.

# %%
def collect_extensions(dir_path):
    # YOUR CODE HERE
    pass

# %%
# Test
exts=collect_extensions('.'); assert isinstance(exts, set); assert '.py' in exts or '.ipynb' in exts
print("✅ Exercise 299 passed!")

# %% [markdown]
# ### Exercise 300: Safe Write
#
# Write a context manager safe_write(path) that writes to a temp file then renames to path on success.

# %%
from contextlib import contextmanager
@contextmanager
def safe_write(path):
    # YOUR CODE HERE
    pass

# %%
# Test
with safe_write('_sw.txt') as f: f.write('ok')
assert open('_sw.txt').read()=='ok'; import os; os.remove('_sw.txt')
print("✅ Exercise 300 passed!")
